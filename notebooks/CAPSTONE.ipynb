# %%
import pandas as pd
import re
import requests
from bs4 import BeautifulSoup as BS
from IPython.core.display import display, HTML
from tqdm.notebook import tqdm
import json
import numpy as np
from itertools import chain

# %% [markdown]
# # Stock Categorization

# %%
stocks = pd.read_csv('../data/all_sectors.csv')
stocks = stocks.drop(columns=['Unnamed: 0'])
stocks
# Out:
#      Ticker                          Company           Sector
# 0      FEAM        5E Advanced Materials Inc  Basic Materials
# 1      ASIX                     AdvanSix Inc  Basic Materials
# 2       AEM       Agnico Eagle Mines Limited  Basic Materials
# 3       APD  Air Products and Chemicals, Inc  Basic Materials
# 4       AGI                  Alamos Gold Inc  Basic Materials
# ...     ...                              ...              ...
# 6104    VIA     Via Renewables Inc - Class A        Utilities
# 6105   VWTR       Vidler Water Resources Inc        Utilities
# 6106    VST               Vistra Energy Corp        Utilities
# 6107    WEC            WEC Energy Group, Inc        Utilities
# 6108    XEL                  Xcel Energy Inc        Utilities
#
# [6109 rows x 3 columns]

# %%
basic_materials = list(stocks[stocks.Sector == 'Basic Materials']['Ticker'])
communication_services = list(stocks[stocks.Sector == 'Communication Services']['Ticker'])
consumer_defensive = list(stocks[stocks.Sector == 'Consumer Cyclical']['Ticker'])
consumer_cyclical = list(stocks[stocks.Sector == 'Consumer Defensive']['Ticker'])
energy = list(stocks[stocks.Sector == 'Energy']['Ticker'])
financial_services = list(stocks[stocks.Sector == 'Financial Services']['Ticker'])
healthcare = list(stocks[stocks.Sector == 'Healthcare']['Ticker'])
industrials = list(stocks[stocks.Sector == 'Industrials']['Ticker'])
technology = list(stocks[stocks.Sector == 'Technology']['Ticker'])
utilities = list(stocks[stocks.Sector == 'Utilities']['Ticker'])

# %%
sector_dict = {'Basic Materials':basic_materials, 'Communication Services':communication_services, 'Consumer Defensive':consumer_defensive, 'Consumer Cyclical':consumer_cyclical, 'Energy':energy, 'Financial Services':financial_services, 'Healthcare':healthcare, 'Industrials':industrials, 'Technology':technology, 'Utilities':utilities}

# %%
sector_dict
# Out:
# {'Basic Materials': ['FEAM',
#   'ASIX',
#   'AEM',
#   'APD',
#   'AGI',
#   'ALB',
#   'AA',
#   'AXU',
#   'ASTL',
#   'AAU',
#   'AMR',
#   'ALTO',
#   'ACH',
#   'AREC',
#   'AVD',
#   'USAS',
#   'AMRS',
#   'AU',
#   'RKDA',
#   'MT',
#   'ASH',
#   'AVTR',
#   'AVNT',
#   'ASM',
#   'AXTA',
#   'BTG',
#   'BCPC',
#   'GOLD',
#   'BHIL',
#   'BHP',
#   'BIOX',
#   'BCC',
#   'BAK',
#   'CBT',
#   'CMCL',
#   'CE',
#   'CPAC',
#   'CX',
#   'CGAU',
#   'CENX',
#   'CF',
#   'CCF',
#   'CGA',
#   'CHNR',
#   'CXDC',
#   'CINR',
#   'CLW',
#   'CLF',
#   'CNEY',
#   'CCNC',
#   'CDE',
#   'CMC',
#   'SID',
#   'BVN',
#   'CMP',
#   'CSTM',
#   'CTGO',
#   'CMT',
#   'CTVA',
#   'CRH',
#   'CRKN',
#   'UAN',
#   'DNMR',
#   'DOW',
#   'DRD',
#   'DD',
#   'EXP',
#   'EMN',
#   'ECL',
#   'ECVT',
#   'EGO',
#   'ESI',
#   'EMX',
#   'EXK',
#   'EVA',
#   'EQX',
#   'ERO',
#   'EXN',
#   'FOE',
#   'GSM',
#   'AG',
#   'FSI',
#   'FMC',
#   'FSM',
#   'FNV',
#   'FCX',
#   'FRD',
#   'FURY',
#   'FF',
#   'GAU',
#   'GATO',
#   'GCP',
#   'GGB',
#   'GEVO',
#   'AUMN',
#   'GFI',
#   'GLDG',
#   'GORO',
#   'GROY',
#   'GSV',
#   'GPL',
#   'GPRE',
#   'SIM',
#   'GURE',
#   'HMY',
#   'HWKN',
#   'FUL',
#   'HL',
#   'HUDI',
#   'HBM',
#   'HDSN',
#   'HUN',
#   'HYMC',
#   'IAG',
#   'NGVT',
#   'IOSP',
#   'ITRG',
#   'IFF',
#   'THM',
#   'IPI',
#   'ICL',
#   'ITP',
#   'JHX',
#   'JCTCF',
#   'KALU',
#   'KGC',
#   'KOP',
#   'KRO',
#   'LGO',
#   'LWLG',
#   'LIN',
#   'LAC',
#   'LTHM',
#   'LOMA',
#   'LOOP',
#   'LXU',
#   'LYB',
#   'MAG',
#   'MBII',
#   'MLM',
#   'MTRN',
#   'MMX',
#   'MUX',
#   'MTL',
#   'MERC',
#   'MSB',
#   'MTA',
#   'MEOH',
#   'MTX',
#   'MKD',
#   'MP',
#   'MULG',
#   'NP',
#   'NFGC',
#   'NGD',
#   'NEU',
#   'NEM',
#   'NEWP',
#   'NEXA',
#   'NSR',
#   'NAK',
#   'NTIC',
#   'NMG',
#   'NG',
#   'NUE',
#   'NTR',
#   'ODC',
#   'OLN',
#   'ZEUS',
#   'SEED',
#   'ORGN',
#   'OEC',
#   'ORLA',
#   'OR',
#   'PAAS',
#   'PZG',
#   'PRM',
#   'PPTA',
#   'GLT',
#   'PLL',
#   'PDO',
#   'PLG',
#   'PLM',
#   'PKX',
#   'PPG',
#   'KWR',
#   'METC',
#   'RYAM',
#   'RS',
#   'RFP',
#   'RETO',
#   'REX',
#   'RIO',
#   'RGLD',
#   'RPM',
#   'SAND',
#   'SSL',
#   'SVFD',
#   'SCHN',
#   'SWM',
#   'SA',
#   'SNES',
#   'SXT',
#   'SBSW',
#   'SMTS',
#   'SGML',
#   'SVM',
#   'SILV',
#   'SKE',
#   'SMID',
#   'LITM',
#   'SQM',
#   'XPL',
#   'SCCO',
#   'SSRM',
#   'SLI',
#   'STLD',
#   'SCL',
#   'SUM',
#   'SXC',
#   'SUZ',
#   'SLVM',
#   'SYNL',
#   'TRX',
#   'TGB',
#   'TECK',
#   'TGLS',
#   'TX',
#   'CC',
#   'MOS',
#   'SMG',
#   'SHW',
#   'TMST',
#   'TMC',
#   'TREC',
#   'TMQ',
#   'TSE',
#   'TROX',
#   'TRQ',
#   'UAMY',
#   'USLM',
#   'X',
#   'UNVR',
#   'UFPI',
#   'USAP',
#   'USAU',
#   'VALE',
#   'VHI',
#   'VNTR',
#   'VGZ',
#   'VZLA',
#   'VMC',
#   'HCC',
#   'WDFC',
#   'WRN',
#   'WFG',
#   'WLK',
#   'WLKP',
#   'WWR',
#   'WPM',
#   'AUY',
#   'YTEN',
#   'ZKIN',
#   'ZY'],
#  'Communication Services': ['KRKR',
#   'ATVI',
#   'ATY',
#   'ADTH',
#   'ADV',
#   'ANTE',
#   'MIMO',
#   'AESE',
#   'GOOGL',
#   'GOOG',
#   'ATUS',
#   'AMC',
#   'AMCX',
#   'AMX',
#   'AMOV',
#   'ANGH',
#   'ANGI',
#   'ATEX',
#   'AREN',
#   'ASTS',
#   'ATNI',
#   'T',
#   'AUD',
#   'ATHM',
#   'AUTO',
#   'AVID',
#   'BIDU',
#   'BAOS',
#   'BCE',
#   'BODY',
#   'BBGI',
#   'BILI',
#   'BLCT',
#   'BOC',
#   'BOMN',
#   'BOWL',
#   'BRAG',
#   'BZFD',
#   'CABO',
#   'CDLX',
#   'CARG',
#   'LUMN',
#   'CHTR',
#   'CMCM',
#   'CSSE',
#   'CNET',
#   'CHT',
#   'CMPR',
#   'CIDM',
#   'CNK',
#   'CCO',
#   'CCOI',
#   'CSCW',
#   'CMCSA',
#   'SCOR',
#   'COMS',
#   'CNSL',
#   'CRTD',
#   'CXDO',
#   'CRTO',
#   'CMLS',
#   'CURI',
#   'DALN',
#   'PLAY',
#   'DLX',
#   'DMS',
#   'DRCT',
#   'DISH',
#   'DLPN',
#   'DASH',
#   'DDI',
#   'DOYU',
#   'LYL',
#   'EDUC',
#   'EA',
#   'EEX',
#   'EMMS',
#   'EDR',
#   'GAME',
#   'EGLX',
#   'EVC',
#   'ESGC',
#   'EVER',
#   'FB',
#   'SFUN',
#   'FNGR',
#   'FVRR',
#   'FLNT',
#   'FWONK',
#   'FWONA',
#   'FOX',
#   'FOXA',
#   'FYBR',
#   'FUBO',
#   'BHAT',
#   'GAIA',
#   'GMGT',
#   'GCI',
#   'GNUS',
#   'GENI',
#   'GIGM',
#   'GSAT',
#   'GSMG',
#   'GOGO',
#   'GMGI',
#   'GRVY',
#   'GTN.A',
#   'GTN',
#   'GROM',
#   'GRPN',
#   'TV',
#   'HOFV',
#   'HHS',
#   'HMTV',
#   'HUYA',
#   'IAC',
#   'ICLK',
#   'IDT',
#   'IDW',
#   'IHRT',
#   'IHS',
#   'IMAX',
#   'CTV',
#   'ISIG',
#   'IAS',
#   'IDCC',
#   'INUV',
#   'IQ',
#   'IRDM',
#   'IZEA',
#   'JFIN',
#   'JW.A',
#   'JW.B',
#   'WLY',
#   'WLYB',
#   'KT',
#   'KUKE',
#   'LEE',
#   'LZ',
#   'LBRDK',
#   'LBRDA',
#   'LBTYK',
#   'LBTYA',
#   'LBTYB',
#   'LILA',
#   'LILAK',
#   'LTRPB',
#   'LTRPA',
#   'LGF.B',
#   'LGF.A',
#   'YVR',
#   'LYV',
#   'LVO',
#   'LIZI',
#   'LCFY',
#   'LKCO',
#   'MSGE',
#   'MSGS',
#   'MGNI',
#   'MANU',
#   'MCHX',
#   'MTCH',
#   'MAX',
#   'MDIA',
#   'TIGO',
#   'MBT',
#   'MOBQ',
#   'MOMO',
#   'MSGM',
#   'MOXC',
#   'NCMI',
#   'NGMS',
#   'NTES',
#   'NFLX',
#   'NWS',
#   'NWSA',
#   'NXST',
#   'KIND',
#   'GDEV',
#   'NN',
#   'OMC',
#   'OOMA',
#   'OPRA',
#   'ORAN',
#   'OB',
#   'PARAA',
#   'PARA',
#   'PTNR',
#   'PSO',
#   'PERI',
#   'TLK',
#   'FENG',
#   'PINS',
#   'MYPS',
#   'PLTK',
#   'PHI',
#   'PCOM',
#   'CPOP',
#   'QTEK',
#   'QNST',
#   'QUOT',
#   'QTT',
#   'RDCM',
#   'RADI',
#   'RDIB',
#   'RDI',
#   'RNWK',
#   'RELX',
#   'RSVR',
#   'RBBN',
#   'RBLX',
#   'RCI',
#   'ROKU',
#   'SGA',
#   'SALM',
#   'SCHL',
#   'SJ',
#   'SCPL',
#   'SE',
#   'SJR',
#   'SHEN',
#   'SSTK',
#   'SIFY',
#   'SMWB',
#   'SBGI',
#   'SIRI',
#   'SKLZ',
#   'SKM',
#   'SNAP',
#   'SOHU',
#   'LOV',
#   'SPOT',
#   'SRAX',
#   'STGW',
#   'STRY',
#   'STCN',
#   'STRN',
#   'SLGG',
#   'TBLA',
#   'TTWO',
#   'TTGT',
#   'TGNA',
#   'TEO',
#   'VIV',
#   'TEF',
#   'TDS',
#   'TU',
#   'TME',
#   'NCTY',
#   'SSP',
#   'IPG',
#   'BATRA',
#   'BATRK',
#   'LSXMK',
#   'LSXMA',
#   'LSXMB',
#   'MCS',
#   'NYT',
#   'DIS',
#   'THRY',
#   'TIMB',
#   'TMUS',
#   'TSQ',
#   'TZOO',
#   'TRMR',
#   'TRVG',
#   'TRKA',
#   'TRUE',
#   'TC',
#   'TKC',
#   'TWLO',
#   'TWTR',
#   'UCL',
#   'USM',
#   'UONEK',
#   'UONE',
#   'UXIN',
#   'VEON',
#   'VZ',
#   'VS',
#   'VIACA',
#   'SEAT',
#   'VOD',
#   'VG',
#   'WMG',
#   'WB',
#   'WOW',
#   'WIMI',
#   'WWE',
#   'WPP',
#   'XNET',
#   'YNDX',
#   'YELP',
#   'YY',
#   'ZDGE',
#   'ZH',
#   'ZD',
#   'ZG',
#   'Z',
#   'ZNGA'],
#  'Consumer Defensive': ['FLWS',
#   'GOED',
#   'DIBS',
#   'AAN',
#   'ANF',
#   'ASO',
#   'ACEL',
#   'GOLF',
#   'ADNT',
#   'AAP',
#   'AEVA',
#   'LIDR',
#   'RERE',
#   'ABNB',
#   'AKA',
#   'AIN',
#   'BABA',
#   'BIRD',
#   'ALLG',
#   'ALSN',
#   'AMZN',
#   'AMCR',
#   'AXL',
#   'AEO',
#   'AOUT',
#   'AREB',
#   'AMWD',
#   'CRMT',
#   'AUVI',
#   'APTV',
#   'FUV',
#   'ARCO',
#   'AMBP',
#   'ARHS',
#   'ARKO',
#   'ARKR',
#   'ARVL',
#   'ABG',
#   'ATER',
#   'ALV',
#   'AN',
#   'AZO',
#   'AYRO',
#   'BTN',
#   'BLL',
#   'BALY',
#   'BZUN',
#   'BNED',
#   'BSET',
#   'BBWI',
#   'BBQ',
#   'BZH',
#   'BBBY',
#   'BERY',
#   'BBY',
#   'BWMX',
#   'BGFV',
#   'BH',
#   'BH.A',
#   'BGI',
#   'BTB',
#   'BJRI',
#   'BLMN',
#   'APRN',
#   'BLBD',
#   'BVH',
#   'BKNG',
#   'BOOT',
#   'BQ',
#   'BWA',
#   'BOXD',
#   'BYD',
#   'BFAM',
#   'BRLT',
#   'EAT',
#   'DOOO',
#   'BC',
#   'BTBD',
#   'BBW',
#   'BFI',
#   'BURL',
#   'CZR',
#   'CAL',
#   'ELY',
#   'CWH',
#   'GOOS',
#   'CNNE',
#   'GOEV',
#   'CPHC',
#   'CPRI',
#   'LOTZ',
#   'KMX',
#   'CUK',
#   'CCL',
#   'CSV',
#   'TAST',
#   'CARS',
#   'CRI',
#   'CVNA',
#   'CASY',
#   'CVCO',
#   'FUN',
#   'CENN',
#   'CNTY',
#   'CCS',
#   'CHPT',
#   'CTHR',
#   'CHWY',
#   'CHS',
#   'CAAS',
#   'CMG',
#   'CHH',
#   'CHDN',
#   'CHUY',
#   'CTRN',
#   'CLAR',
#   'CDRO',
#   'COLM',
#   'CVGI',
#   'CBD',
#   'CONN',
#   'WISH',
#   'CPS',
#   'CPRT',
#   'CPNG',
#   'CBRL',
#   'CROX',
#   'CRWS',
#   'CCK',
#   'CTIB',
#   'CULP',
#   'DADA',
#   'DAN',
#   'DRI',
#   'DECK',
#   'DLA',
#   'DENN',
#   'DBI',
#   'DESP',
#   'DXLG',
#   'DKS',
#   'DBGI',
#   'DDS',
#   'DIN',
#   'DSEY',
#   'HEPS',
#   'DSS',
#   'DPZ',
#   'DORM',
#   'PLOW',
#   'DKNG',
#   'DFH',
#   'DHI',
#   'DRVN',
#   'DS',
#   'DLTH',
#   'BROS',
#   'EBAY',
#   'MOHO',
#   'EJH',
#   'SOLO',
#   'ELMS',
#   'LOCO',
#   'ELYS',
#   'EFOI',
#   'ENJY',
#   'ELA',
#   'ZGN',
#   'ESCA',
#   'GMBL',
#   'EBET',
#   'ETD',
#   'ETSY',
#   'EVK',
#   'EVRI',
#   'EVGO',
#   'EXPE',
#   'EXPR',
#   'EZGO',
#   'FXLV',
#   'FFIE',
#   'FTCH',
#   'FAT',
#   'FATBB',
#   'RACE',
#   'FGI',
#   'FRGI',
#   'FIGS',
#   'FWRG',
#   'FSR',
#   'FIVE',
#   'BDL',
#   'FLXS',
#   'FND',
#   'FL',
#   'F',
#   'FRSX',
#   'FBHS',
#   'FORD',
#   'FOSL',
#   'FOXF',
#   'FRG',
#   'FTDR',
#   'FLL',
#   'FNKO',
#   'FFHL',
#   'GAMB',
#   'GME',
#   'GAN',
#   'GTX',
#   'GM',
#   'GCO',
#   'GNTX',
#   'THRM',
#   'GPC',
#   'GIII',
#   'GIL',
#   'GLBE',
#   'GGR',
#   'GDEN',
#   'GNOG',
#   'GTIM',
#   'GPK',
#   'GRBK',
#   'GP',
#   'GHG',
#   'GEF.B',
#   'GEF',
#   'GPI',
#   'GRWG',
#   'GRUB',
#   'GES',
#   'HBB',
#   'HBI',
#   'HOG',
#   'HAS',
#   'HVT.A',
#   'HVT',
#   'HLBZ',
#   'HIBB',
#   'HGV',
#   'HLT',
#   'HLLY',
#   'HMC',
#   'HNST',
#   'HOFT',
#   'HZN',
#   'HOUR',
#   'HOV',
#   'HRB',
#   'HTHT',
#   'H',
#   'HYLN',
#   'HYZN',
#   'IMBI',
#   'INVZ',
#   'ISPO',
#   'INSE',
#   'IHG',
#   'TILE',
#   'IGT',
#   'IP',
#   'IPW',
#   'IRBT',
#   'JACK',
#   'JAKK',
#   'JD',
#   'JRSH',
#   'JZXN',
#   'JILL',
#   'JOAN',
#   'JOUT',
#   'JWEL',
#   'JMIA',
#   'LLL',
#   'KXIN',
#   'KNDI',
#   'KRT',
#   'KAR',
#   'KBH',
#   'KEQU',
#   'PIK',
#   'KBAL',
#   'KFS',
#   'KIRK',
#   'KSS',
#   'KTB',
#   'KRUS',
#   'LAKE',
#   'LE',
#   'LVS',
#   'LZB',
#   'LAZY',
#   'LCII',
#   'LEA',
#   'LEGH',
#   'LEG',
#   'LEN.B',
#   'LEN',
#   'LESL',
#   'LEVI',
#   'LGIH',
#   'LI',
#   'LCUT',
#   'LTH',
#   'LITB',
#   'LIND',
#   'LQDT',
#   'LAD',
#   'LIVE',
#   'LKQ',
#   'LMPX',
#   'RIDE',
#   'LTRY',
#   'LOW',
#   'LUB',
#   'LCID',
#   'LULU',
#   'LVLU',
#   'LL',
#   'LAZR',
#   'M',
#   'MGA',
#   'MMYT',
#   'MBUU',
#   'HZO',
#   'MPX',
#   'MAR',
#   'VAC',
#   'MCFT',
#   'MAT',
#   'MCD',
#   'MDC',
#   'MED',
#   'MRM',
#   'MLCO',
#   'MCG',
#   'MELI',
#   'MTH',
#   'MTOR',
#   'MGM',
#   'MHO',
#   'MLR',
#   'MLKN',
#   'MNSO',
#   'MCW',
#   'MOD',
#   'MOGU',
#   'MHK',
#   'MCRI',
#   'MNRO',
#   'MPAA',
#   'MOV',
#   'MULN',
#   'MUSA',
#   'GRIL',
#   'MYE',
#   'MYTE',
#   'NATH',
#   'EYE',
#   'NHTC',
#   'NTZ',
#   'NLS',
#   'NEGG',
#   'NKE',
#   'NIO',
#   'NIU',
#   'NDLS',
#   'JWN',
#   'NCLH',
#   'NVFY',
#   'NVVE',
#   'NVR',
#   'ODP',
#   'OLPX',
#   'OSW',
#   'ONEW',
#   'ONON',
#   'ORLY',
#   'OCG',
#   'BARK',
#   'OSTK',
#   'OI',
#   'OXM',
#   'OZON',
#   'PKG',
#   'PTVE',
#   'PZZA',
#   'ID',
#   'PRTY',
#   'PATK',
#   'PTON',
#   'PENN',
#   'PAG',
#   'WOOF',
#   'PDD',
#   'PLNT',
#   'AGS',
#   'PLYA',
#   'PLBY',
#   'PII',
#   'POOL',
#   'PTLO',
#   'POSH',
#   'PBPB',
#   'PTRA',
#   'PHM',
#   'PRPL',
#   'PVH',
#   'QS',
#   'QRTEB',
#   'QRTEA',
#   'RL',
#   'PACK',
#   'RAVE',
#   'RICK',
#   'RRGB',
#   'RRR',
#   'REE',
#   'RGS',
#   'RENN',
#   'RENT',
#   'QSR',
#   'RVLV',
#   'REYN',
#   'RH',
#   'RIVN',
#   'RCKY',
#   'ROL',
#   'RMO',
#   'ROST',
#   'ROVR',
#   'RCL',
#   'RMBL',
#   'RUSHA',
#   'RUSHB',
#   'RSI',
#   'RUTH',
#   'SABR',
#   'SBH',
#   'SGMS',
#   'SEE',
#   'SEAS',
#   'SECO',
#   'SCI',
#   'SHAK',
#   'SBET',
#   'SFT',
#   'SCVL',
#   'SSU',
#   'SIG',
#   'SLGN',
#   'SG',
#   'SIX',
#   'SKX',
#   'SKY',
#   'SNBR',
#   'EM',
#   'DTC',
#   'SOND',
#   'SAH',
#   'SON',
#   'SEV',
#   'SPWH',
#   'SMP',
#   'SBUX',
#   'STLA',
#   'SHOO',
#   'SFIX',
#   'STON',
#   'SRI',
#   'STRT',
#   'MSC',
#   'SGHC',
#   'SGC',
#   'SUP',
#   'SES',
#   'SYPR',
#   'TKAT',
#   'TPR',
#   'TTM',
#   'TMHC',
#   'TPX',
#   'TEN',
#   'TMX',
#   'TSLA',
#   'TXRH',
#   'BKE',
#   'CATO',
#   'CAKE',
#   'PLCE',
#   'TCS',
#   'DXYN',
#   'GPS',
#   'GT',
#   'HD',
#   'INTG',
#   'LOVE',
#   'STKS',
#   'REAL',
#   'TJX',
#   'WEN',
#   'THO',
#   'TDUP',
#   'TTSH',
#   'TLYS',
#   'TOL',
#   'CURV',
#   'TM',
#   'TSCO',
#   'COOK',
#   'TA',
#   'TNL',
#   'TRIP',
#   'TCOM',
#   'TPH',
#   'TOUR',
#   'TUP',
#   'VEEE',
#   'ULTA',
#   'UA',
#   'UAA',
#   'UFI',
#   'UFAB',
#   'URBN',
#   'PRTS',
#   'MTN',
#   'VRA',
#   'VFC',
#   'VEV',
#   'VSCO',
#   'VNCE',
#   'BBIG',
#   'VIOT',
#   'VIPS',
#   'VIRC',
#   'VMAR',
#   'VSTO',
#   'VC',
#   'VLCN',
#   'VLTA',
#   'VRM',
#   'W',
#   'WEBR',
#   'WPRT',
#   'WRK',
#   'WEYS',
#   'WHR',
#   'WSM',
#   'WING',
#   'WINA',
#   'WGO',
#   'WWW',
#   'WKHS',
#   'WKSP',
#   'WNW',
#   'WW',
#   'WH',
#   'WYNN',
#   'XELB',
#   'XL',
#   'XPEL',
#   'XPEV',
#   'XPOF',
#   'XSPA',
#   'YTRA',
#   'YSG',
#   'YETI',
#   'YUM',
#   'YUMC',
#   'YJ',
#   'ZUMZ'],
#  'Consumer Cyclical': ['YQ',
#   'XXII',
#   'TWOU',
#   'ACU',
#   'AGRO',
#   'ATGE',
#   'AFYA',
#   'AGRI',
#   'AGFS',
#   'ACI',
#   'ALCO',
#   'MO',
#   'ABEV',
#   'AMBO',
#   'DIT',
#   'APEI',
#   'BUD',
#   'APPH',
#   'AQB',
#   'ADM',
#   'ARCE',
#   'ASPU',
#   'AACG',
#   'BRFH',
#   'SKIN',
#   'BRBR',
#   'BTTR',
#   'BYND',
#   'BGS',
#   'BIG',
#   'BJ',
#   'BSFC',
#   'BON',
#   'LND',
#   'BRCC',
#   'BRFS',
#   'BRID',
#   'BEDU',
#   'BTI',
#   'BF.A',
#   'BF.B',
#   'BG',
#   'BRCN',
#   'CVGW',
#   'CALM',
#   'CLXT',
#   'CPB',
#   'CELH',
#   'CENTA',
#   'CENT',
#   'CHGG',
#   'CLEU',
#   'COE',
#   'BTOG',
#   'CHD',
#   'COKE',
#   'CCEP',
#   'KOF',
#   'JVA',
#   'CL',
#   'CCU',
#   'CAG',
#   'STZ',
#   'STZ.B',
#   'COST',
#   'COTY',
#   'COUR',
#   'CYAN',
#   'DAR',
#   'DTEA',
#   'DEO',
#   'DDL',
#   'DOGZ',
#   'DOLE',
#   'DG',
#   'DLTR',
#   'EAST',
#   'EPC',
#   'ELF',
#   'EEIQ',
#   'AKO.B',
#   'AKO.A',
#   'EWCZ',
#   'FARM',
#   'FAMI',
#   'FHS',
#   'FLO',
#   'FMX',
#   'FEDU',
#   'FDP',
#   'FRPT',
#   'VINE',
#   'GIS',
#   'GHC',
#   'LOPE',
#   'GNLN',
#   'GO',
#   'GOTU',
#   'WILC',
#   'HLG',
#   'HAPP',
#   'HELE',
#   'HLF',
#   'HFFG',
#   'HIMS',
#   'HRL',
#   'TWNK',
#   'IFMK',
#   'IH',
#   'IBA',
#   'IMKTA',
#   'INGR',
#   'IPAR',
#   'JJSF',
#   'JBSS',
#   'LRN',
#   'KAVL',
#   'K',
#   'KDP',
#   'KMB',
#   'DNUT',
#   'LSF',
#   'LW',
#   'LANC',
#   'LNDC',
#   'LAUR',
#   'LFVN',
#   'LWAY',
#   'LMNR',
#   'LINC',
#   'LXEH',
#   'LOCL',
#   'MMMB',
#   'MTEX',
#   'MKC',
#   'MKC.V',
#   'MITC',
#   'METX',
#   'MGPI',
#   'MF',
#   'AVO',
#   'TAP.A',
#   'TAP',
#   'MDLZ',
#   'MNST',
#   'FIZZ',
#   'NTCO',
#   'NAII',
#   'NGVC',
#   'NATR',
#   'NBEV',
#   'NWL',
#   'EDU',
#   'NOMD',
#   'NUS',
#   'NUZE',
#   'OTLY',
#   'OLLI',
#   'ONE',
#   'PEP',
#   'PRDO',
#   'PFGC',
#   'PM',
#   'PPC',
#   'PME',
#   'PLAG',
#   'POST',
#   'PSMT',
#   'PRMW',
#   'NEW',
#   'RGF',
#   'REED',
#   'REV',
#   'RIBT',
#   'REDU',
#   'RLX',
#   'RMCF',
#   'RYB',
#   'SAFM',
#   'ASAI',
#   'SENEA',
#   'SENEB',
#   'EDTK',
#   'SKIL',
#   'SMFL',
#   'SOVO',
#   'SPTN',
#   'SPB',
#   'SBEV',
#   'SFM',
#   'STRA',
#   'SNAX',
#   'SUMR',
#   'STG',
#   'STKL',
#   'SANW',
#   'SYY',
#   'TAL',
#   'TANH',
#   'TEDU',
#   'TGT',
#   'TTCF',
#   'PETZ',
#   'WTER',
#   'ANDE',
#   'SAM',
#   'CHEF',
#   'CLX',
#   'KO',
#   'NAPA',
#   'EL',
#   'HAIN',
#   'HSY',
#   'SJM',
#   'KHC',
#   'KR',
#   'PG',
#   'SMPL',
#   'UL',
#   'THRN',
#   'TR',
#   'THS',
#   'TUEM',
#   'TPB',
#   'TSN',
#   'UDMY',
#   'UG',
#   'UNFI',
#   'UVV',
#   'UTI',
#   'USNA',
#   'USFD',
#   'UTZ',
#   'VSTA',
#   'VGR',
#   'VGFC',
#   'VFF',
#   'VLGEA',
#   'VWE',
#   'COCO',
#   'VITL',
#   'VTRU',
#   'WAFU',
#   'WMT',
#   'WMK',
#   'FREE',
#   'WVVI',
#   'WBEV',
#   'TKLF',
#   'YGYI',
#   'ZVIA',
#   'ZME',
#   'ZVO'],
#  'Energy': ['AXAS',
#   'AE',
#   'AMTX',
#   'ARLP',
#   'AMPY',
#   'AM',
#   'AR',
#   'APA',
#   'ARCH',
#   'AROC',
#   'BKR',
#   'BRN',
#   'BATL',
#   'BRY',
#   'BSM',
#   'BKEP',
#   'BORR',
#   'BP',
#   'BPT',
#   'MNRL',
#   'VTOL',
#   'WHD',
#   'CRC',
#   'CPE',
#   'CLMT',
#   'CEI',
#   'CCJ',
#   'CNQ',
#   'CVE',
#   'CDEV',
#   'LEU',
#   'CHX',
#   'LNG',
#   'CQP',
#   'OJSCY',
#   'CHK',
#   'CHKR',
#   'CVX',
#   'SNP',
#   'CIVI',
#   'CKX',
#   'CLNE',
#   'CNX',
#   'CRK',
#   'COP',
#   'CEIX',
#   'CLR',
#   'CTRA',
#   'CLB',
#   'CSAN',
#   'CRGY',
#   'CPG',
#   'CEQP',
#   'CAPL',
#   'CRT',
#   'CCLP',
#   'CVI',
#   'CELP',
#   'DWSN',
#   'DCP',
#   'DKL',
#   'DK',
#   'DEN',
#   'DNN',
#   'DVN',
#   'DHT',
#   'FANG',
#   'DO',
#   'BOOM',
#   'DMLP',
#   'LPG',
#   'DRQ',
#   'DTM',
#   'DLNG',
#   'ESTE',
#   'ZEST',
#   'EC',
#   'EP',
#   'ENB',
#   'UUUU',
#   'ET',
#   'ERF',
#   'E',
#   'ENLC',
#   'ENSV',
#   'EPD',
#   'EOG',
#   'EPSN',
#   'EQT',
#   'EQNR',
#   'ETRN',
#   'EURN',
#   'EPM',
#   'XPRO',
#   'EXTN',
#   'XOM',
#   'FLMN',
#   'FLNG',
#   'FTK',
#   'FET',
#   'FRO',
#   'GLOP',
#   'GEL',
#   'GPRK',
#   'GEOS',
#   'GLP',
#   'GLNG',
#   'GTE',
#   'GPP',
#   'GPOR',
#   'HNRG',
#   'HAL',
#   'HLX',
#   'HP',
#   'HES',
#   'HESM',
#   'DINO',
#   'HPK',
#   'HMLP',
#   'HEP',
#   'HUSA',
#   'IMO',
#   'IMPP',
#   'ICD',
#   'INDO',
#   'INSW',
#   'IO',
#   'KRP',
#   'KMI',
#   'KNTK',
#   'KLXE',
#   'KOS',
#   'LPI',
#   'LBRT',
#   'MMP',
#   'MGY',
#   'MRO',
#   'MPC',
#   'MARPS',
#   'MMLP',
#   'MTDR',
#   'MTR',
#   'MXC',
#   'MPLX',
#   'MRC',
#   'MUR',
#   'MVO',
#   'NBR',
#   'NC',
#   'NESR',
#   'NFG',
#   'NOV',
#   'NGS',
#   'NRP',
#   'NVGS',
#   'NCSM',
#   'NR',
#   'NXE',
#   'NEXT',
#   'NEX',
#   'NGL',
#   'NINE',
#   'NE',
#   'NOA',
#   'NOG',
#   'NRT',
#   'DNOW',
#   'NS',
#   'OAS',
#   'OBE',
#   'OXY',
#   'OII',
#   'OIS',
#   'OKE',
#   'OSG',
#   'OVV',
#   'PHX',
#   'PARR',
#   'PTEN',
#   'PBF',
#   'PBFX',
#   'PDCE',
#   'BTU',
#   'PED',
#   'PBA',
#   'PBT',
#   'PVL',
#   'PRT',
#   'PTR',
#   'PBR.A',
#   'PBR',
#   'PSX',
#   'PXD',
#   'PAA',
#   'PAGP',
#   'PDS',
#   'PNRG',
#   'PFIE',
#   'PUMP',
#   'RNGR',
#   'RRC',
#   'RTLR',
#   'RCON',
#   'REGI',
#   'REPX',
#   'REI',
#   'ROCC',
#   'RES',
#   'SBR',
#   'SNMP',
#   'SD',
#   'SJT',
#   'SLB',
#   'STNG',
#   'WTTR',
#   'SHLX',
#   'SHEL',
#   'SBOW',
#   'SHI',
#   'SND',
#   'SM',
#   'SOI',
#   'SWN',
#   'SRLP',
#   'SLNG',
#   'SGU',
#   'SMLP',
#   'SU',
#   'SUN',
#   'SDPI',
#   'TALO',
#   'TRGP',
#   'TRNX',
#   'TRP',
#   'FTI',
#   'TK',
#   'TNK',
#   'TELL',
#   'TS',
#   'TTI',
#   'TPL',
#   'WMB',
#   'TDW',
#   'TRMD',
#   'TTE',
#   'TGA',
#   'RIG',
#   'TGS',
#   'TNP',
#   'BROG',
#   'UGP',
#   'UEC',
#   'UROY',
#   'URG',
#   'USAC',
#   'USEG',
#   'SLCA',
#   'USWS',
#   'EGY',
#   'VAL',
#   'VLO',
#   'VVV',
#   'VET',
#   'VTNR',
#   'VNOM',
#   'VIST',
#   'VIVK',
#   'VOC',
#   'WFRD',
#   'WES',
#   'WLL',
#   'INT',
#   'WTI',
#   'YPF'],
#  'Financial Services': ['VCXA',
#   'VCXB',
#   'TURN',
#   'BCOW',
#   'SRCE',
#   'ADER',
#   'QFIN',
#   'FVAM',
#   'SVNA',
#   'VII',
#   'LAX',
#   'AEF',
#   'FCO',
#   'ABGI',
#   'ASPA',
#   'AAQC',
#   'ENER',
#   'ACEV',
#   'ACBA',
#   'ACNB',
#   'ACRO',
#   'ADRA',
#   'ADEX',
#   'AMPI',
#   'IMPX',
#   'AEG',
#   'ARBG',
#   'AEHA',
#   'GMFI',
#   'AFAQ',
#   'AMG',
#   'AFBI',
#   'AFL',
#   'AGAC',
#   'AFTR',
#   'AGBA',
#   'AGGR',
#   'RICO',
#   'AHRN',
#   'AIB',
#   'AHG',
#   'ALAC',
#   'ALRS',
#   'Y',
#   'ABTX',
#   'AB',
#   'ADS',
#   'ALLY',
#   'ASPC',
#   'ALPA',
#   'APTM',
#   'ALSA',
#   'REVE',
#   'ACAX',
#   'ALOR',
#   'ALCC',
#   'AEAE',
#   'ATAQ',
#   'AGCB',
#   'AAMC',
#   'ASPS',
#   'ALTU',
#   'AMAL',
#   'AMRK',
#   'AMBC',
#   'AMCI',
#   'AMTB',
#   'ATAX',
#   'AMAO',
#   'AEL',
#   'AXP',
#   'AFG',
#   'AIG',
#   'AMNB',
#   'ANAT',
#   'ATA',
#   'AMP',
#   'AMSF',
#   'ABCB',
#   'ASRV',
#   'ATLO',
#   'WNNR',
#   'POND',
#   'ADAL',
#   'ANZU',
#   'AON',
#   'APCA',
#   'APN',
#   'APO',
#   'AINV',
#   'APSG',
#   'APGB',
#   'APXI',
#   'ARCK',
#   'ACGL',
#   'ACTD',
#   'ANAC',
#   'AFAC',
#   'AAC',
#   'ARCC',
#   'ARES',
#   'ARBK',
#   'ARGO',
#   'ARGU',
#   'RAM',
#   'ARIZ',
#   'AACI',
#   'AOGO',
#   'AROW',
#   'ARRW',
#   'ARTE',
#   'AJG',
#   'ARTA',
#   'APAM',
#   'ARYD',
#   'ARYE',
#   'ASA',
#   'ACDI',
#   'AINC',
#   'AMK',
#   'ASB',
#   'AC',
#   'AIZ',
#   'AGO',
#   'ASAX',
#   'ACAQ',
#   'ATEK',
#   'SWET',
#   'ATIF',
#   'AAME',
#   'ASAQ',
#   'ACAH',
#   'ACAB',
#   'AUB',
#   'ATLC',
#   'ATCO',
#   'ACII',
#   'AUBN',
#   'ADRT',
#   'AURC',
#   'ATAK',
#   'AUS',
#   'ASZ',
#   'AEAC',
#   'AVAC',
#   'AVAN',
#   'AHPA',
#   'EQH',
#   'AXAC',
#   'AXS',
#   'APMI',
#   'AX',
#   'BCSF',
#   'BANF',
#   'BBVA',
#   'BBDO',
#   'BBD',
#   'BCH',
#   'BANC',
#   'BLX',
#   'CIB',
#   'BMA',
#   'BCTF',
#   'BSBR',
#   'BSAC',
#   'BSMX',
#   'SAN',
#   'BCV',
#   'BSVN',
#   'BFIN',
#   'BFC',
#   'BAC',
#   'BOH',
#   'BMRC',
#   'BMO',
#   'BKSC',
#   'BOTJ',
#   'OZK',
#   'BKU',
#   'BWFG',
#   'BNNR',
#   'BANR',
#   'BNIX',
#   'BYN',
#   'BCS',
#   'BHB',
#   'BBDC',
#   'MCI',
#   'MPV',
#   'BFAC',
#   'BCML',
#   'BAFN',
#   'BBAR',
#   'BCBP',
#   'BLSA',
#   'BRD',
#   'BLNG',
#   'BENE',
#   'BACA',
#   'BRK.B',
#   'BRK.A',
#   'BHLB',
#   'BWAC',
#   'BGCP',
#   'BSKY',
#   'TWCB',
#   'BIOT',
#   'BTBT',
#   'BITE',
#   'BITF',
#   'NILE',
#   'BMAC',
#   'BFZ',
#   'BKCC',
#   'BHK',
#   'BTZ',
#   'BGR',
#   'BME',
#   'BLK',
#   'BIGZ',
#   'BKN',
#   'BLW',
#   'BTA',
#   'BIT',
#   'BTT',
#   'BYM',
#   'BFK',
#   'BLE',
#   'BNY',
#   'TCPC',
#   'BUI',
#   'BHV',
#   'BSAQ',
#   'BXSL',
#   'BLEU',
#   'BCSA',
#   'BMAQ',
#   'BCOR',
#   'BLFY',
#   'BOCN',
#   'OWL',
#   'BRBS',
#   'BLUA',
#   'BSGA',
#   'BOAC',
#   'BWC',
#   'BWAQ',
#   'DMF',
#   'LEO',
#   'BOAS',
#   'BSBK',
#   'BOKF',
#   'BFH',
#   'BREZ',
#   'BRDG',
#   'BTWN',
#   'BWB',
#   'BHF',
#   'BLTS',
#   'BSIG',
#   'RILY',
#   'BRPM',
#   'BRIV',
#   'BRLI',
#   'BRAC',
#   'SCLE',
#   'BYFC',
#   'BAM',
#   'BAMR',
#   'BBUC',
#   'BRKL',
#   'BCAC',
#   'BRO',
#   'BRP',
#   'BTCS',
#   'BGSX',
#   'BHSE',
#   'BPAC',
#   'BUR',
#   'BRKH',
#   'BFST',
#   'BY',
#   'BYNO',
#   'BYTS',
#   'CXAC',
#   'CCTS',
#   'CADE',
#   'CALB',
#   'CATC',
#   'CAC',
#   'CM',
#   'CANG',
#   'CNGL',
#   'CBNK',
#   'CCBG',
#   'COF',
#   'CSWC',
#   'CMCA',
#   'CFFN',
#   'CSTR',
#   'CTAQ',
#   'CARE',
#   'GLBL',
#   'CITE',
#   'CARV',
#   'CAS',
#   'CCAI',
#   'CLST',
#   'CPAR',
#   'CHAA',
#   'CATY',
#   'CBFV',
#   'CBMB',
#   'CBOE',
#   'CBTX',
#   'PRPB',
#   'PRPC',
#   'CENQ',
#   'CFBK',
#   'CPF',
#   'CET',
#   'CVCY',
#   'CFIV',
#   'CFVI',
#   'CFFS',
#   'CFFE',
#   'CFFI',
#   'CFSB',
#   'CBRG',
#   'CNTQ',
#   'CLAY',
#   'CHMG',
#   'LFC',
#   'COFS',
#   'CHPM',
#   'CB',
#   'CCV',
#   'CCVI',
#   'CVII',
#   'CHWA',
#   'CIXX',
#   'CIIG',
#   'CNNB',
#   'CINF',
#   'CION',
#   'CIFR',
#   'C',
#   'CZWI',
#   'CFG',
#   'CIZN',
#   'CIA',
#   'CZNC',
#   'CHCO',
#   'CIVB',
#   'CLRM',
#   'CLAS',
#   'CLAQ',
#   'CLIM',
#   'CLOE',
#   'CME',
#   'CNA',
#   'CCNE',
#   'CNF',
#   'CNO',
#   'CCB',
#   'CVLY',
#   'COHN',
#   'CNS',
#   'CRHC',
#   'COLI',
#   'MITA',
#   'CLBR',
#   'CLAA',
#   'CBAN',
#   'COLB',
#   'CLBK',
#   'CMA',
#   'CBSH',
#   'CBU',
#   'CTBI',
#   'CWBC',
#   'CDAQ',
#   'CPUH',
#   'CND',
#   'CNDA',
#   'CNDB',
#   'CNFR',
#   'CNOB',
#   'CSLM',
#   'CSTA',
#   'CPSS',
#   'CONX',
#   'CPAA',
#   'CRZN',
#   'TRON',
#   'COOL',
#   'CORS',
#   'CRVL',
#   'CPAQ',
#   'COVA',
#   'COWN',
#   'PMTS',
#   'CRD.A',
#   'CRD.B',
#   'BAP',
#   'CACC',
#   'CS',
#   'CCAP',
#   'CREC',
#   'CFB',
#   'CPTK',
#   'CRU',
#   'DAOO',
#   'CFR',
#   'CULL',
#   'CURO',
#   'CUBI',
#   'CVBF',
#   'DALS',
#   'DNZ',
#   'DKDCA',
#   'DCRD',
#   'DLCA',
#   'DMAQ',
#   'VCF',
#   'VMM',
#   'VFL',
#   'DWIN',
#   'DMA',
#   'DB',
#   'DHBC',
#   'DHCA',
#   'DHHC',
#   'DHIL',
#   'EQOS',
#   'DHAC',
#   'DTOC',
#   'DWAC',
#   'DILA',
#   'DCOM',
#   'DSAQ',
#   'DFS',
#   'DISA',
#   'DMYS',
#   'DGICA',
#   'DGICB',
#   'DFIN',
#   'DPCS',
#   'XPOA',
#   'DGNU',
#   'DTF',
#   'DTRT',
#   'DSAC',
#   'DUET',
#   'DUNE',
#   'DXF',
#   'KTF',
#   'DYNS',
#   'EGBN',
#   'EBMT',
#   'GRF',
#   'EFBI',
#   'EBC',
#   'ERES',
#   'ESSC',
#   'EWBC',
#   'EVM',
#   'CEV',
#   'EFT',
#   'ETX',
#   'EVN',
#   'EOT',
#   'ENX',
#   'EFR',
#   'EVF',
#   'EAC',
#   'ADOC',
#   'EGGF',
#   'EHTH',
#   'EJFA',
#   'ELVT',
#   'EOCW',
#   'ECF',
#   'ESBK',
#   'EMCF',
#   'ETAC',
#   'HORI',
#   'EIG',
#   'EPWR',
#   'ECPG',
#   'EDNC',
#   'ENCP',
#   'ENVA',
#   'NFYS',
#   'ESGR',
#   'ENTF',
#   'EBTC',
#   'EFSC',
#   'EPHY',
#   'EQHA',
#   'EQBK',
#   'EQD',
#   'EQS',
#   'ERIE',
#   'ESAC',
#   'ESM',
#   'ESQ',
#   'ESSA',
#   'ESNT',
#   'EUCR',
#   'EBAC',
#   'EVBN',
#   'EVE',
#   'EVR',
#   'MNTN',
#   'RE',
#   'EVGR',
#   'EVOJ',
#   'XFIN',
#   'ENPC',
#   'EZPW',
#   'FDS',
#   'FANH',
#   'FMAO',
#   'FMNB',
#   'FPAC',
#   'FST',
#   'FZT',
#   'FATP',
#   'FBK',
#   'AGM',
#   'AGM.A',
#   'FHI',
#   'FNHC',
#   'FFBW',
#   'FGF',
#   'FDBC',
#   'FNF',
#   'FDUS',
#   'FITB',
#   'FWAC',
#   'FACA',
#   'FOA',
#   'FISI',
#   'FXCO',
#   'FNVT',
#   'FSRX',
#   'FTCV',
#   'FTVI',
#   'FEXD',
#   'FTEV',
#   'FINV',
#   'FNWD',
#   'FINW',
#   'FAF',
#   'FBNC',
#   'FBP',
#   'FRBA',
#   'BUSE',
#   'FBIZ',
#   'FCAP',
#   'FCFS',
#   'FCNCA',
#   'FCF',
#   'FCBC',
#   'FCCO',
#   'FCRD',
#   'FFBC',
#   'FFIN',
#   'THFF',
#   'FFNW',
#   'FFWM',
#   'FGBI',
#   'FHB',
#   'FHN',
#   'INBK',
#   'FIBK',
#   'FLAG',
#   'FRME',
#   'FMBH',
#   'FXNC',
#   'FNWB',
#   'FRC',
#   'FRSG',
#   'FSFG',
#   'FSEA',
#   'FUNC',
#   'FUSB',
#   'MYFW',
#   'FSBC',
#   'FBC',
#   'FLME',
#   'FFIC',
#   'FNB',
#   'FNCB',
#   'FOCS',
#   'FIAC',
#   'FRBN',
#   'FRXB',
#   'FSSI',
#   'FCAX',
#   'FVT',
#   'FVIV',
#   'FRLA',
#   'FMIV',
#   'FOUN',
#   'FOXW',
#   'FRAF',
#   'BEN',
#   'FT',
#   'FLAC',
#   'FACT',
#   'FRHC',
#   'FRON',
#   'FICV',
#   'FSBW',
#   'FSK',
#   'FTAA',
#   'EMLD',
#   'HERA',
#   'FTPA',
#   'ZING',
#   'FULT',
#   'FSNB',
#   'FUTU',
#   'FHLT',
#   'FTII',
#   'FVCB',
#   'GGGV',
#   'GLTA',
#   'GBL',
#   'GNT',
#   'GEEX',
#   'GHAC',
#   'GDNR',
#   'GCMG',
#   'GAM',
#   'GAQ',
#   'GBNY',
#   'GGAA',
#   'GENQ',
#   'GNW',
#   'GABC',
#   'GIAC',
#   'GIA',
#   'GIW',
#   'GBCI',
#   'GLEE',
#   'GLAD',
#   'GAIN',
#   'GLHA',
#   'GLBZ',
#   'GGMC',
#   'GACQ',
#   'GBLI',
#   'GLLI',
#   'GPAC',
#   'GSAQ',
#   'GTAC',
#   'GL',
#   'GLAQ',
#   'GOAC',
#   'PUCK',
#   'GOBI',
#   'GOGN',
#   'GOCO',
#   'GAMC',
#   'GBRG',
#   'GFX',
#   'GPCO',
#   'GSBD',
#   'GBDC',
#   'GWII',
#   'GSHD',
#   'GGPI',
#   'GHIX',
#   'GIIX',
#   'GSEV',
#   'GTPB',
#   'GTPA',
#   'GAPA',
#   'GRAB',
#   'GFOR',
#   'GECC',
#   'GSBC',
#   'GRCY',
#   'GDOT',
#   'GCBC',
#   'GHL',
#   'GREE',
#   'GLRE',
#   'GNRS',
#   'GVCI',
#   'GNAC',
#   'GFGD',
#   'AVAL',
#   'GGAL',
#   'SUPV',
#   'GSQB',
#   'GSQD',
#   'GNTY',
#   'GBAB',
#   'GHLD',
#   'GWGH',
#   'GXII',
#   'HGTY',
#   'HALL',
#   'HLAH',
#   'HLNE',
#   'HWC',
#   'HAFC',
#   'HONE',
#   'HWKZ',
#   'HWBK',
#   'HYAC',
#   'HBT',
#   'HCI',
#   'HCMA',
#   'HDB',
#   'HAAC',
#   'HAIA',
#   'HCAR',
#   'HSAQ',
#   'HWEL',
#   'HTLF',
#   'HNNA',
#   'HCIC',
#   'HCVI',
#   'HTGC',
#   'HTBK',
#   'HFWA',
#   'HGBL',
#   'HRTG',
#   'HHGC',
#   'HHLA',
#   'HIGA',
#   'HTPA',
#   'HTH',
#   'HIFS',
#   'HIPO',
#   'HIVE',
#   'HMNF',
#   'HNRA',
#   'HBCP',
#   'HOMB',
#   'HFBL',
#   'HPLT',
#   'HMPT',
#   'HMST',
#   'HTBI',
#   'HOPE',
#   'HMN',
#   'HZON',
#   'HBNC',
#   'HRZN',
#   'HLI',
#   'HPX',
#   'HSBC',
#   'HCII',
#   'HIII',
#   'HUIZ',
#   'HMCO',
#   'HTAQ',
#   'HBAN',
#   'HUT',
#   'HVBC',
#   'HYW',
#   'IBER',
#   'ICCH',
#   'IBN',
#   'ICNC',
#   'IROQ',
#   'IGAC',
#   'IGNY',
#   'IMH',
#   'IGTA',
#   'IOR',
#   'ACQR',
#   'INDB',
#   'IBCP',
#   'IBTX',
#   'AXH',
#   'ITAQ',
#   'NFNT',
#   'IFIN',
#   'IPAX',
#   'ING',
#   'IOAC',
#   'INAQ',
#   'IIII',
#   'INTE',
#   'IRRX',
#   'WEL',
#   'IQMD',
#   'IBKR',
#   'ICE',
#   'IFS',
#   'IBOC',
#   'IGIC',
#   'IMAQ',
#   'IPVA',
#   'IPVF',
#   'IPVI',
#   'VKI',
#   'VCV',
#   'VLT',
#   'IVZ',
#   'OIA',
#   'VMO',
#   'VKQ',
#   'VPV',
#   'IQI',
#   'VGM',
#   'VTN',
#   'IIM',
#   'ISTR',
#   'ICMB',
#   'IVCB',
#   'ITIC',
#   'IACC',
#   'IREN',
#   'ISAA',
#   'ISLE',
#   'ITCB',
#   'ITUB',
#   'ITHX',
#   'ITQ',
#   'IXAQ',
#   'JCIC',
#   'RJAC',
#   'JXN',
#   'JGGC',
#   'JRVR',
#   'JHG',
#   'JATT',
#   'HCNE',
#   'JUGG',
#   'JWSM',
#   'JEF',
#   'JT',
#   'JYAC',
#   'JOFF',
#   'JHS',
#   'JHI',
#   'JPM',
#   'JUN',
#   'JP',
#   'JAQC',
#   'JWAC',
#   'KSI',
#   'KAIR',
#   'KACL',
#   'KYN',
#   'KB',
#   'KRNY',
#   'KMPR',
#   'KCGI',
#   'KFFB',
#   'KRNL',
#   'KYCH',
#   'KEY-K',
#   'KEY',
#   'KVSA',
#   'KVSC',
#   'KINS',
#   'KWAC',
#   'KNSL',
#   'KINZ',
#   'KIII',
#   'KAII',
#   'KAHC',
#   'KKR',
#   'KLAQ',
#   'INKA',
#   'KNSW',
#   'KORE',
#   'LBAI',
#   'LKFN',
#   'LAAA',
#   'LSBK',
#   'LGVC',
#   'LCA',
#   'LARK',
#   'LSPR',
#   'LATG',
#   'LVAC',
#   'LGAC',
#   'LAZ',
#   'LCAA',
#   'LCNB',
#   'LDHA',
#   'LEGA',
#   'LCW',
#   'LFTR',
#   'LGTO',
#   'LMND',
#   'LC',
#   'TREE',
#   'LHC',
#   'LHAA',
#   'LVRA',
#   'LX',
#   'LNFA',
#   'LFAC',
#   'LMACA',
#   'LIBY',
#   'LJAQ',
#   'LMST',
#   'LNC',
#   'LGHL',
#   'LCAP',
#   'LIVB',
#   'LOB',
#   'LOCC',
#   'LOKM',
#   'LYG',
#   'LMAO',
#   'LMFA',
#   'LDI',
#   'L',
#   'LRFC',
#   'LITT',
#   'LGV',
#   'LPLA',
#   'LU',
#   'LBC',
#   'LUXA',
#   'MBAC',
#   'MBSC',
#   'MCBC',
#   'DRAY',
#   'OPA',
#   'MGYR',
#   'MHLD',
#   'MNSB',
#   'MAIN',
#   'MLAC',
#   'MACU',
#   'MLVF',
#   'MAAQ',
#   'MN',
#   'MFC',
#   'MAQC',
#   'MARA',
#   'GATE',
#   'MKL',
#   'MKTX',
#   'FINM',
#   'MMC',
#   'MGLD',
#   'MIT',
#   'MA',
#   'JMAC',
#   'MBI',
#   'MLAI',
#   'MDH',
#   'MFIN',
#   'MSAC',
#   'MTAC',
#   'MEKA',
#   'MBWM',
#   'MPRA',
#   'MBIN',
#   'MFH',
#   'MEAC',
#   'MCY',
#   'MRBK',
#   'CASH',
#   'MTAL',
#   'MET',
#   'MCBS',
#   'MILE',
#   'MCB',
#   'MCR',
#   'CXE',
#   'CMU',
#   'MIN',
#   'CXH',
#   'MFM',
#   'MFV',
#   'MTG',
#   'MBCN',
#   'MSBI',
#   'MPB',
#   'MSVB',
#   'MDWT',
#   'MOFG',
#   'MEOA',
#   'MACC',
#   'MUFG',
#   'MFG',
#   'MPAC',
#   'MC',
#   'MGI',
#   'MRCC',
#   'MTRY',
#   'MON',
#   'MCO',
#   'MS',
#   'MACA',
#   ...],
#  'Healthcare': ['TXG',
#   'YI',
#   'ATNF',
#   'ONEM',
#   'ME',
#   'TSVT',
#   'FDMT',
#   'LBPS',
#   'ETNB',
#   'MASS',
#   'NMTR',
#   'AADI',
#   'ABT',
#   'ABBV',
#   'ABCM',
#   'ABCL',
#   'ABEO',
#   'ABMD',
#   'ABSI',
#   'ABVC',
#   'ACHC',
#   'ACAD',
#   'ACST',
#   'AXDX',
#   'ACCD',
#   'ARAY',
#   'ACRX',
#   'ACER',
#   'ACHV',
#   'ACHL',
#   'ACIU',
#   'ACRS',
#   'ACOR',
#   'ATNM',
#   'ABOS',
#   'ACXP',
#   'AFIB',
#   'ADAG',
#   'ADGI',
#   'ADMP',
#   'AHCO',
#   'ADAP',
#   'ADPT',
#   'ADCT',
#   'ADXN',
#   'ADUS',
#   'ADIL',
#   'ACET',
#   'ADTX',
#   'ADMA',
#   'ADXS',
#   'ADVM',
#   'AGLE',
#   'AERI',
#   'AVTE',
#   'AIH',
#   'AEZS',
#   'AEMD',
#   'AFMD',
#   'AGEN',
#   'AGE',
#   'A',
#   'AGRX',
#   'AGTI',
#   'AGL',
#   'AGIO',
#   'AIKI',
#   'ALRN',
#   'AIM',
#   'AIRS',
#   'AKAN',
#   'AKTX',
#   'AKBA',
#   'KERN',
#   'AKRO',
#   'AKUS',
#   'AKYA',
#   'AKU',
#   'TCRT',
#   'ALBO',
#   'ALC',
#   'ALDX',
#   'ALEC',
#   'ALR',
#   'ALHC',
#   'ALGN',
#   'ALGS',
#   'ALIM',
#   'ALKS',
#   'ALLK',
#   'ALLR',
#   'ALNA',
#   'AHPI',
#   'ALLO',
#   'ALVR',
#   'MDRX',
#   'ALNY',
#   'DRTS',
#   'ATEC',
#   'TKNO',
#   'ALPN',
#   'CYTO',
#   'ATHE',
#   'ALT',
#   'ALXO',
#   'ALZN',
#   'AMRN',
#   'AMAM',
#   'AMED',
#   'AMS',
#   'AMWL',
#   'ABC',
#   'AMGN',
#   'FOLD',
#   'AMRX',
#   'AMN',
#   'AMPH',
#   'AMPE',
#   'AMYT',
#   'AMLX',
#   'ANAB',
#   'AVXL',
#   'ANEB',
#   'ANGO',
#   'ANGN',
#   'ANIK',
#   'ANIP',
#   'ANIX',
#   'ANNX',
#   'ANVS',
#   'ANPC',
#   'ATRS',
#   'ANTM',
#   'APLS',
#   'APEN',
#   'AMEH',
#   'APDN',
#   'AGTC',
#   'AMTI',
#   'APLT',
#   'APRE',
#   'ATR',
#   'APVO',
#   'APTX',
#   'APM',
#   'APTO',
#   'APYX',
#   'AQST',
#   'ARAV',
#   'ABUS',
#   'ABIO',
#   'ACLX',
#   'ARCT',
#   'RCUS',
#   'ARQT',
#   'ARDX',
#   'ARGX',
#   'ARDS',
#   'ARMP',
#   'ARWR',
#   'TARA',
#   'ARTL',
#   'AORT',
#   'ARVN',
#   'ASND',
#   'ASXC',
#   'ASLN',
#   'AWH',
#   'ASMB',
#   'ASRT',
#   'IONM',
#   'AZN',
#   'ATXS',
#   'ATAI',
#   'ATRA',
#   'AVIR',
#   'ATNX',
#   'ATHX',
#   'ATHA',
#   'ATIP',
#   'ATOS',
#   'BCEL',
#   'ATRC',
#   'ATRI',
#   'LIFE',
#   'AUGX',
#   'AURA',
#   'AUPH',
#   'ACB',
#   'AUTL',
#   'AVDL',
#   'AVTX',
#   'AVNS',
#   'AVAH',
#   'ATXI',
#   'AVEO',
#   'CDMO',
#   'RNA',
#   'AVGR',
#   'RCEL',
#   'AVRO',
#   'AXLA',
#   'AXGN',
#   'AXNX',
#   'AXSM',
#   'AYLA',
#   'AYTU',
#   'AZTA',
#   'AZYO',
#   'BBLN',
#   'BXRX',
#   'BHC',
#   'BAX',
#   'BEAM',
#   'BDX',
#   'BGNE',
#   'BLPH',
#   'BLCM',
#   'BLU',
#   'BNTC',
#   'BLI',
#   'BTTX',
#   'XAIR',
#   'BYSI',
#   'BCYC',
#   'BCAB',
#   'BCDA',
#   'BIOC',
#   'BCRX',
#   'BDSX',
#   'BFRA',
#   'BFRI',
#   'BIIB',
#   'BHVN',
#   'BIOL',
#   'BLFS',
#   'BLRX',
#   'BMRN',
#   'BMEA',
#   'BMRA',
#   'PHGE',
#   'BNGO',
#   'BVXV',
#   'BNOX',
#   'BNTX',
#   'BPTH',
#   'BPTS',
#   'BIO.B',
#   'BIO',
#   'BRTX',
#   'BSGM',
#   'TECH',
#   'BEAT',
#   'BTCY',
#   'BVS',
#   'BIVI',
#   'BTAI',
#   'BDTX',
#   'BLUE',
#   'BJDX',
#   'BPMC',
#   'BWV',
#   'BOLT',
#   'BBLG',
#   'BSX',
#   'BCLI',
#   'BWAY',
#   'BCTX',
#   'BBI',
#   'BBIO',
#   'BHG',
#   'DRUG',
#   'BMY',
#   'BKD',
#   'BTX',
#   'BRKR',
#   'BNR',
#   'BFLY',
#   'CCCC',
#   'CABA',
#   'CLBS',
#   'CALA',
#   'CALT',
#   'CANB',
#   'CADL',
#   'CANF',
#   'CANO',
#   'CGC',
#   'CAPR',
#   'CARA',
#   'CRDF',
#   'CAH',
#   'CRDL',
#   'CSII',
#   'CDNA',
#   'CMAX',
#   'CRBU',
#   'CASI',
#   'SAVA',
#   'CSTL',
#   'CTLT',
#   'CBIO',
#   'CPRX',
#   'YCBD',
#   'CELC',
#   'CLDX',
#   'CLRB',
#   'CLLS',
#   'CVM',
#   'CLSN',
#   'CELU',
#   'CYAD',
#   'CNC',
#   'CNTA',
#   'CNTG',
#   'IPSC',
#   'CERE',
#   'CERN',
#   'CERT',
#   'CERS',
#   'CSBR',
#   'CHNG',
#   'CRL',
#   'CHEK',
#   'CMPI',
#   'CKPT',
#   'CEMI',
#   'CHE',
#   'CCXI',
#   'CMMB',
#   'CMRX',
#   'CJJD',
#   'CPHI',
#   'SXTC',
#   'KDNY',
#   'CDXC',
#   'MPLN',
#   'CDTX',
#   'CI',
#   'CINC',
#   'CING',
#   'CTXR',
#   'CRXT',
#   'CLPT',
#   'CLSD',
#   'CLNN',
#   'CLVR',
#   'CLOV',
#   'CLVS',
#   'CNSP',
#   'COCP',
#   'DNAY',
#   'CDXS',
#   'CODX',
#   'CDAK',
#   'COGT',
#   'CGTX',
#   'CWBR',
#   'CHRS',
#   'COLL',
#   'CLGN',
#   'CYH',
#   'CMPS',
#   'CMPX',
#   'CGEN',
#   'CPSI',
#   'CNCE',
#   'CCM',
#   'CFMS',
#   'CNMD',
#   'CNTB',
#   'CNTX',
#   'CFRX',
#   'CNVY',
#   'CRBP',
#   'CORT',
#   'CRMD',
#   'CRTX',
#   'CRVS',
#   'COSM',
#   'CVET',
#   'CELZ',
#   'CRNX',
#   'CRSP',
#   'CRON',
#   'CCRN',
#   'CCEL',
#   'CTIC',
#   'CUE',
#   'HLTH',
#   'CGEM',
#   'CPIX',
#   'CVAC',
#   'CRIS',
#   'CUTR',
#   'CVRX',
#   'CVS',
#   'CYBN',
#   'CYCC',
#   'CYCN',
#   'CYTH',
#   'CBAY',
#   'CYT',
#   'CTKB',
#   'CYTK',
#   'CTMX',
#   'CTSO',
#   'DHR',
#   'DARE',
#   'DRIO',
#   'DVA',
#   'DXR',
#   'DAWN',
#   'DBVT',
#   'DBTX',
#   'DCPH',
#   'DH',
#   'DCTH',
#   'DNLI',
#   'XRAY',
#   'DRMA',
#   'DMTK',
#   'DSGN',
#   'DXCM',
#   'DMAC',
#   'DICE',
#   'DFFN',
#   'DCGO',
#   'DOCS',
#   'RDY',
#   'DRRX',
#   'DYAI',
#   'DYNT',
#   'DVAX',
#   'DYN',
#   'EGRX',
#   'EAR',
#   'EDAP',
#   'EDSA',
#   'EWTX',
#   'EDIT',
#   'EW',
#   'EFTR',
#   'EIGR',
#   'EKSO',
#   'ELAN',
#   'ECOR',
#   'ELMD',
#   'ELDN',
#   'ELEV',
#   'ELYM',
#   'LLY',
#   'ELOX',
#   'EMBC',
#   'EBS',
#   'ENTA',
#   'EHC',
#   'ENDP',
#   'NDRA',
#   'ENLV',
#   'ENOB',
#   'ENSC',
#   'ETTX',
#   'ENTX',
#   'TRDA',
#   'ENVB',
#   'NVST',
#   'NVNO',
#   'ENZ',
#   'EPZM',
#   'EQRX',
#   'EQ',
#   'ERAS',
#   'ERYP',
#   'ESPR',
#   'EPIX',
#   'ESTA',
#   'ETON',
#   'EVAX',
#   'EVLO',
#   'EVFM',
#   'EVGN',
#   'EVOK',
#   'EVH',
#   'EOLS',
#   'EVO',
#   'EXAS',
#   'XGN',
#   'EXEL',
#   'XCUR',
#   'EXAI',
#   'EYEN',
#   'EYPT',
#   'FATE',
#   'FEMY',
#   'FENC',
#   'FGEN',
#   'FTRP',
#   'FNCH',
#   'FWBI',
#   'FLGC',
#   'FLDM',
#   'FHTX',
#   'FONR',
#   'FORA',
#   'FMTX',
#   'FBRX',
#   'FBIO',
#   'FWP',
#   'FRLN',
#   'FREQ',
#   'FMS',
#   'HUGE',
#   'FSTX',
#   'FULC',
#   'FLGT',
#   'FUSN',
#   'GTHX',
#   'GANX',
#   'GLPG',
#   'GALT',
#   'GLTO',
#   'GRTX',
#   'GLMD',
#   'GMDA',
#   'GBS',
#   'GLS',
#   'GMTX',
#   'GNTA',
#   'GBIO',
#   'GENE',
#   'GTH',
#   'GNFT',
#   'GMAB',
#   'GNCA',
#   'GNPX',
#   'GOVX',
#   'GERN',
#   'GHRS',
#   'GILD',
#   'DNA',
#   'GKOS',
#   'GSK',
#   'GBT',
#   'CO',
#   'GMED',
#   'GCTK',
#   'GLYC',
#   'GMVD',
#   'GDRX',
#   'GOSS',
#   'GRCL',
#   'GRPH',
#   'GRAY',
#   'GEG',
#   'GBNH',
#   'GRNA',
#   'GLSI',
#   'GRFS',
#   'GRTS',
#   'GRVI',
#   'GTBP',
#   'GH',
#   'GHSI',
#   'HAE',
#   'HALO',
#   'HNGR',
#   'HRMY',
#   'HARP',
#   'HROW',
#   'HBIO',
#   'HCA',
#   'HCWB',
#   'HCSG',
#   'HCTI',
#   'HCAT',
#   'HQY',
#   'HSTM',
#   'HTBX',
#   'HSDT',
#   'HSIC',
#   'HEPA',
#   'HRTX',
#   'HSKA',
#   'HEXO',
#   'HITI',
#   'HILS',
#   'HSTO',
#   'HOLX',
#   'FIXX',
#   'HOOK',
#   'HZNP',
#   'HOTH',
#   'HTGM',
#   'HUMA',
#   'HUM',
#   'HGEN',
#   'HCM',
#   'HYPR',
#   'IBIO',
#   'ICAD',
#   'ICCM',
#   'ICLR',
#   'ICVX',
#   'ICUI',
#   'IDYA',
#   'IDRA',
#   'IDXX',
#   'IGMS',
#   'IKNA',
#   'ILMN',
#   'IMAB',
#   'IMAC',
#   'IMGO',
#   'IMRA',
#   'IMCC',
#   'IMTX',
#   'IMMX',
#   'ICCC',
#   'IMRX',
#   'IMUX',
#   'IBRX',
#   'IMCR',
#   'IMGN',
#   'IMNM',
#   'IPA',
#   'IMVT',
#   'IMRN',
#   'IMMP',
#   'IMPL',
#   'IMV',
#   'INAB',
#   'NARI',
#   'IXHL',
#   'INCY',
#   'INDP',
#   'INFI',
#   'IFRX',
#   'INFU',
#   'IKT',
#   'INBX',
#   'INM',
#   'INMD',
#   'INMB',
#   'IPHA',
#   'INNV',
#   'INVA',
#   'INGN',
#   'NOTV',
#   'INO',
#   'INZY',
#   'INSM',
#   'IINN',
#   'NSPR',
#   'INSP',
#   'TIL',
#   'PODD',
#   'ITGR',
#   'IART',
#   'IGAP',
#   'NTLA',
#   'ICPT',
#   'INCR',
#   'IDXG',
#   'XENT',
#   'ITCI',
#   'IIN',
#   'ISRG',
#   'IVC',
#   'IVA',
#   'NVTA',
#   'NVIV',
#   'INVO',
#   'IOBT',
#   'IONS',
#   'IOVA',
#   'IQV',
#   'IRMD',
#   'IRTC',
#   'IRIX',
#   'IRWD',
#   'ISO',
#   'ISR',
#   'ISPC',
#   'ITOS',
#   'ITRM',
#   'ISEE',
#   'JAGX',
#   'JANX',
#   'JSPR',
#   'JAZZ',
#   'JNJ',
#   'JNCE',
#   'DERM',
#   'JUPW',
#   'KALA',
#   'KLDO',
#   'KALV',
#   'KMDA',
#   'KRTX',
#   'KPTI',
#   'KZIA',
#   'KMPH',
#   'KROS',
#   'KZR',
#   'KNSA',
#   'KNTE',
#   'KTRA',
#   'KPRX',
#   'KRBP',
#   'KOD',
#   'PHG',
#   'KRON',
#   'KRYS',
#   'KURA',
#   'KYMR',
#   'LH',
#   'LJPC',
#   'LABP',
#   'LCI',
#   'LTRN',
#   'LNTH',
#   'LRMR',
#   'LVTX',
#   'LFLY',
#   'LPTX',
#   'LEGN',
#   'LMAT',
#   'LNSR',
#   'LEXX',
#   'LXRX',
#   'LHCG',
#   'LIAN',
#   'LFMD',
#   'LFST',
#   'LGND',
#   'LMNL',
#   'LCTX',
#   'LPCN',
#   'LQDA',
#   'LIVN',
#   'LIXT',
#   'LOGC',
#   'LBPH',
#   'LGVN',
#   'LUCD',
#   'LHDX',
#   'LMDX',
#   'LUMO',
#   'LYEL',
#   'LYRA',
#   'MGNX',
#   'MDGL',
#   'MGTA',
#   'MYNZ',
#   'MNKD',
#   'MRVI',
#   'MRNS',
#   'MRKR',
#   'MRAI',
#   'MASI',
#   'MTNB',
#   'MXCT',
#   'MCK',
#   'MDXH',
#   'MDVL',
#   'MDNA',
#   'MNOV',
#   'MDGS',
#   'MDWD',
#   'MD',
#   'MEDP',
#   'MDT',
#   'MHUA',
#   'MEIP',
#   'MGTX',
#   'MRK',
#   'MREO',
#   'VIVO',
#   'MMSI',
#   'MACK',
#   'MRSN',
#   'MRUS',
#   'MESO',
#   'MTCR',
#   'MTD',
#   'MBOT',
#   'MICR',
#   'MTP',
#   'MIST',
#   'MLSS',
#   'MDXG',
#   'MNMD',
#   'NERV',
#   'UTRS',
#   'INKT',
#   'MRTX',
#   'MIRO',
#   'MIRM',
#   'MRNA',
#   'MODV',
#   'MODD',
#   'MOLN',
#   'MTEM',
#   'MBRX',
#   'MOH',
#   'MNPR',
#   'GLUE',
#   'MORF',
#   'MOR',
#   'MOTS',
#   'MOVE',
#   'MTBC',
#   'MBIO',
#   'MYMD',
#   'MYO',
#   'MYOV',
#   'MYGN',
#   'NBRV',
#   'NBTX',
#   'NSTG',
#   'NAOV',
#   'NNVC',
#   'NNOX',
#   'NH',
#   'NTRA',
#   'NHC',
#   'NRC',
#   'NTUS',
#   'NAUT',
#   'NAVB',
#   'NKTR',
#   'NMRD',
#   'NEOG',
#   'NEO',
#   'NLTX',
#   'NVCN',
#   'NEPH',
#   'NEPT',
#   'NBSE',
#   'NRBO',
#   'NBIX',
#   'NURO',
#   'STIM',
#   'NMTC',
#   'NPCE',
#   'NRSN',
#   'NVRO',
#   'NXGL',
#   'NEXI',
#   'NXTC',
#   'NXGN',
#   'BIMI',
#   'NGM',
#   'NKTX',
#   'NLSP',
#   'NBY',
#   'NOVN',
#   'NVS',
#   'NVAX',
#   'NVCR',
#   'NVOS',
#   'NVO',
#   'NRXP',
#   'NCNA',
#   'NRIX',
#   'NUTX',
#   'NTRB',
#   'NUVL',
#   'NUVA',
#   'NUVB',
#   'NVCT',
#   'NUWE',
#   'NYMX',
#   'NYXH',
#   'OSH',
#   'OBSV',
#   'OCGN',
#   'OCUL',
#   'OCUP',
#   'OLMA',
#   'OLK',
#   'OMGA',
#   'OMER',
#   'OMCL',
#   'OCX',
#   'TOI',
#   'ONCY',
#   'ONTX',
#   'ONCR',
#   'ONCS',
#   'ONCT',
#   'OTRK',
#   'OPGN',
#   'OPNT',
#   'OPK',
#   'OPT',
#   'OPRX',
#   'OPTN',
#   'OPCH',
#   'OGEN',
#   'ORMP',
#   'OSUR',
#   'ORTX',
#   'OGI',
#   'ORGO',
#   'OGN',
#   'ONVO',
#   'ORGS',
#   'ORIC',
#   'OCDX',
#   'OFIX',
#   'KIDS',
#   'OSCR',
#   'OTIC',
#   'OTLK',
#   'OM',
#   'OVID',
#   'OMI',
#   'OWLT',
#   'OYST',
#   'PIII',
#   'PACB',
#   'PCRX',
#   'PRFX',
#   'PTN',
#   'PALI',
#   'PBLA',
#   'FNA',
#   'PRTK',
#   'PRDS',
#   'KTTA',
#   'PASG',
#   'PDCO',
#   'PAVM',
#   'PDSB',
#   'PEAR',
#   'PEN',
#   'PKI',
#   'PRGO',
#   'PSNL',
#   'PETQ',
#   'PETS',
#   'PTPI',
#   'PETV',
#   'PFE',
#   'PMCB',
#   'PHAR',
#   'PHVS',
#   'PHAS',
#   'PHAT',
#   'PAHC',
#   'PHIO',
#   'PHR',
#   'PIRS',
#   'PLRX',
#   'PSTI',
#   'PSTV',
#   'PLXP',
#   'PMVP',
#   'PNT',
#   'PTE',
#   'PYPD',
#   'PRTG',
#   'PSTX',
#   'PRAX',
#   'PGEN',
#   'PRPO',
#   'DTIL',
#   'POAI',
#   'PRLD',
#   'PINC',
#   'PBH',
#   'PRVA',
#   'PROC',
#   'PRCT',
#   'PCSA',
#   'PDEX',
#   'PROF',
#   'PROG',
#   'PGNY',
#   'RXDX',
#   'PRPH',
#   'PRQR',
#   'PTIX',
#   'PTGX',
#   'PLX',
#   'PRTA',
#   'PRVB',
#   'PMD',
#   'PTCT',
#   'PULM',
#   'LUNG',
#   'PLSE',
#   'PBYI',
#   'PRTC',
#   'PPBT',
#   'PYXS',
#   'QGEN',
#   'QLI',
#   ...],
#  'Industrials': ['MMM',
#   'JOBS',
#   'AZ',
#   'AAON',
#   'AIR',
#   'ABB',
#   'ABM',
#   'ACTG',
#   'ACCO',
#   'EPAC',
#   'AYI',
#   'ADSE',
#   'ADT',
#   'WMS',
#   'ADES',
#   'AEIS',
#   'ACM',
#   'AENZ',
#   'AER',
#   'ACY',
#   'AERC',
#   'AJRD',
#   'AVAV',
#   'ASLE',
#   'AGCO',
#   'UAVS',
#   'AGFY',
#   'AIRI',
#   'AL',
#   'AIRT',
#   'ATSG',
#   'ALG',
#   'ALK',
#   'ALJJ',
#   'ATI',
#   'ALGT',
#   'ALLE',
#   'APT',
#   'ALPP',
#   'ALTG',
#   'AIMC',
#   'UHAL',
#   'AMRC',
#   'AAL',
#   'AMSC',
#   'AME',
#   'POWW',
#   'AP',
#   'AEHL',
#   'AOS',
#   'APG',
#   'APOG',
#   'AIT',
#   'AQMS',
#   'ARMK',
#   'ARCB',
#   'ARC',
#   'ACHR',
#   'ARNC',
#   'ACA',
#   'ASC',
#   'AGX',
#   'ARLO',
#   'AFI',
#   'AWI',
#   'ARTW',
#   'APWC',
#   'ASPN',
#   'ASTE',
#   'ASTR',
#   'ATRO',
#   'ASTC',
#   'ATTO',
#   'ATKR',
#   'AAWW',
#   'ATCX',
#   'ADP',
#   'AWX',
#   'AVY',
#   'CAR',
#   'AXON',
#   'AZEK',
#   'AZUL',
#   'AZZ',
#   'BW',
#   'BMI',
#   'BLDP',
#   'B',
#   'BBSI',
#   'BECN',
#   'BGRY',
#   'BEST',
#   'BGSF',
#   'BKYI',
#   'BRDS',
#   'BLDE',
#   'BLNK',
#   'BE',
#   'BXC',
#   'BAH',
#   'BWMN',
#   'BRC',
#   'BV',
#   'BWEN',
#   'BBU',
#   'BLDR',
#   'BWXT',
#   'BYRN',
#   'CDRE',
#   'CAE',
#   'CSTE',
#   'CNI',
#   'CP',
#   'CPLP',
#   'CGRN',
#   'CSL',
#   'CRS',
#   'CARR',
#   'CWST',
#   'CASS',
#   'CTRM',
#   'CAT',
#   'CBAT',
#   'CBZ',
#   'CEAD',
#   'CECE',
#   'CHRA',
#   'GTLS',
#   'CVR',
#   'CEA',
#   'ZNH',
#   'CYD',
#   'CHRW',
#   'CTAS',
#   'CIR',
#   'CVEO',
#   'CLH',
#   'CLIR',
#   'CNHI',
#   'CODA',
#   'CFX',
#   'CMCO',
#   'FIX',
#   'CODI',
#   'CMPO',
#   'CIX',
#   'BBCP',
#   'ROAD',
#   'VLRS',
#   'CPA',
#   'CNM',
#   'CNR',
#   'CAAP',
#   'CMRE',
#   'CVLG',
#   'CVU',
#   'CRAI',
#   'CR',
#   'CRESY',
#   'CYRX',
#   'CSWI',
#   'CSX',
#   'CMI',
#   'CW',
#   'CTOS',
#   'CVV',
#   'DAC',
#   'DSKE',
#   'DE',
#   'DAL',
#   'DHX',
#   'DSX',
#   'DGLY',
#   'DRTT',
#   'DLHC',
#   'DCI',
#   'DOV',
#   'DPRO',
#   'DCO',
#   'DXPE',
#   'DY',
#   'EGLE',
#   'KODK',
#   'ETN',
#   'EH',
#   'ESLT',
#   'ERJ',
#   'EME',
#   'EMR',
#   'WIRE',
#   'ENR',
#   'ERII',
#   'ESOA',
#   'ENS',
#   'NETI',
#   'ENG',
#   'EBF',
#   'ENOV',
#   'ENVX',
#   'NPO',
#   'EOSE',
#   'EFX',
#   'ESAB',
#   'ESP',
#   'GWH',
#   'EDRY',
#   'ESEA',
#   'CLWT',
#   'EVI',
#   'EVLV',
#   'AQUA',
#   'EXPD',
#   'XPON',
#   'EXPO',
#   'FAST',
#   'FSS',
#   'FDX',
#   'FERG',
#   'FA',
#   'FPAY',
#   'FLS',
#   'FLR',
#   'FLUX',
#   'FORR',
#   'FTAI',
#   'FWRD',
#   'FC',
#   'FELE',
#   'RAIL',
#   'FREY',
#   'ULCC',
#   'FCN',
#   'FCEL',
#   'FTEK',
#   'GTES',
#   'GATX',
#   'JOB',
#   'GENC',
#   'GNK',
#   'GNRC',
#   'GD',
#   'GE',
#   'GFL',
#   'ROCK',
#   'GIC',
#   'SDH',
#   'GPN',
#   'GSL',
#   'GLBS',
#   'GMS',
#   'GOGL',
#   'GOL',
#   'GGG',
#   'EAF',
#   'GHM',
#   'GVA',
#   'GLDD',
#   'GTEC',
#   'GRNQ',
#   'GWAV',
#   'GFF',
#   'GRIN',
#   'OMAB',
#   'PAC',
#   'ASR',
#   'GFAI',
#   'GIFI',
#   'GXO',
#   'HSC',
#   'HA',
#   'HAYN',
#   'HAYW',
#   'HHR',
#   'HTLD',
#   'HEES',
#   'HEI.A',
#   'HEI',
#   'HSII',
#   'HLIO',
#   'HRI',
#   'HCCI',
#   'HTZ',
#   'HXL',
#   'HIHO',
#   'HI',
#   'HIL',
#   'HLMN',
#   'HQI',
#   'HRT',
#   'HNI',
#   'HOLI',
#   'HON',
#   'HWM',
#   'HUBB',
#   'HUBG',
#   'HSON',
#   'HII',
#   'HURC',
#   'HURN',
#   'HBP',
#   'HYFM',
#   'HYRE',
#   'HY',
#   'IAA',
#   'IEP',
#   'ICFI',
#   'IPWR',
#   'IDEX',
#   'IEX',
#   'IESC',
#   'ITW',
#   'IGC',
#   'IEA',
#   'IR',
#   'VATE',
#   'ISSC',
#   'NSP',
#   'IBP',
#   'IIIN',
#   'IVAC',
#   'IRS',
#   'ITT',
#   'IVDA',
#   'J',
#   'JAN',
#   'JBI',
#   'JBHT',
#   'JELD',
#   'JBLU',
#   'JOBY',
#   'JBT',
#   'JCI',
#   'KAI',
#   'KAMN',
#   'BZ',
#   'KBR',
#   'KELYA',
#   'KELYB',
#   'KIQ',
#   'KMT',
#   'KFRC',
#   'KE',
#   'KEX',
#   'KSCP',
#   'KNX',
#   'KNOP',
#   'KFY',
#   'KRNT',
#   'KTOS',
#   'LHX',
#   'LSTR',
#   'SWIM',
#   'LAWS',
#   'FSTR',
#   'LII',
#   'LICY',
#   'LTBR',
#   'ZEV',
#   'LILM',
#   'LMB',
#   'LECO',
#   'LNN',
#   'LEV',
#   'LIQT',
#   'LMT',
#   'LGMK',
#   'LPX',
#   'LXFR',
#   'MIC',
#   'TUSK',
#   'MNTX',
#   'MAN',
#   'MRTN',
#   'MAS',
#   'DOOR',
#   'MHH',
#   'MTZ',
#   'MTRX',
#   'MATX',
#   'MATW',
#   'MMS',
#   'MEC',
#   'MGRC',
#   'MDU',
#   'MTMT',
#   'MRCY',
#   'MESA',
#   'MVST',
#   'YGMZ',
#   'MIR',
#   'MG',
#   'MNTS',
#   'MEG',
#   'MOG.A',
#   'MSA',
#   'MSM',
#   'MLI',
#   'MWA',
#   'MYRG',
#   'NSSC',
#   'NPK',
#   'NM',
#   'NMM',
#   'NTIP',
#   'NLSN',
#   'NKLA',
#   'NL',
#   'NNBR',
#   'NAT',
#   'NDSN',
#   'NSC',
#   'NOC',
#   'NWPX',
#   'NVX',
#   'NVEE',
#   'NVT',
#   'NXTD',
#   'OBCI',
#   'OP',
#   'OPTT',
#   'OMEX',
#   'ODFL',
#   'OFLX',
#   'OESX',
#   'ORN',
#   'OSK',
#   'OTIS',
#   'OC',
#   'PCAR',
#   'PTSI',
#   'PANL',
#   'PKE',
#   'PH',
#   'PKOH',
#   'PSN',
#   'PATI',
#   'PAYX',
#   'PNR',
#   'PSHG',
#   'PFMT',
#   'PESI',
#   'PPIH',
#   'PFIN',
#   'PFSW',
#   'PGTI',
#   'PPSI',
#   'PBI',
#   'PL',
#   'PLUG',
#   'POLA',
#   'POWL',
#   'PLPC',
#   'PRIM',
#   'IPDN',
#   'PRG',
#   'PRLB',
#   'PCT',
#   'PYR',
#   'PXS',
#   'QUAD',
#   'QBAK',
#   'NX',
#   'PWR',
#   'QRHC',
#   'RADA',
#   'RLGT',
#   'RTX',
#   'ROLL',
#   'RCMT',
#   'RCRT',
#   'RDW',
#   'RRX',
#   'RENO',
#   'RCII',
#   'RSG',
#   'REZI',
#   'RGP',
#   'REVG',
#   'RFIL',
#   'RBA',
#   'RRTS',
#   'RHI',
#   'RKLB',
#   'ROK',
#   'ROP',
#   'RYAAY',
#   'R',
#   'RYI',
#   'SB',
#   'SAIA',
#   'SNDR',
#   'SEB',
#   'SMHI',
#   'SHIP',
#   'SNT',
#   'SVT',
#   'SGBX',
#   'SHPW',
#   'SMED',
#   'PIXY',
#   'SFL',
#   'SHYF',
#   'SIDU',
#   'SIF',
#   'SSD',
#   'SGLY',
#   'SITE',
#   'SKYH',
#   'SKYW',
#   'SWBI',
#   'SNA',
#   'SLDP',
#   'LUV',
#   'SGRP',
#   'SPIR',
#   'SPR',
#   'SAVE',
#   'SP',
#   'SPXC',
#   'STAF',
#   'SXI',
#   'SWK',
#   'STN',
#   'SBLK',
#   'SRT',
#   'GASS',
#   'SCS',
#   'SPLP',
#   'SRCL',
#   'STRL',
#   'RGR',
#   'SNCY',
#   'SPCB',
#   'SST',
#   'TH',
#   'TATT',
#   'TAYD',
#   'TDCX',
#   'TISI',
#   'TGEN',
#   'TRC',
#   'TNC',
#   'TEX',
#   'LLAP',
#   'TTEK',
#   'TGH',
#   'TXT',
#   'TFII',
#   'BA',
#   'BCO',
#   'EML',
#   'GRC',
#   'GBX',
#   'SCX',
#   'MTW',
#   'MIDD',
#   'THR',
#   'TKR',
#   'TTC',
#   'TRI',
#   'TWI',
#   'TITN',
#   'TOMZ',
#   'BLD',
#   'TOPS',
#   'TBLT',
#   'TPIC',
#   'TT',
#   'TRNS',
#   'TDG',
#   'TRU',
#   'TG',
#   'TREX',
#   'TRS',
#   'TNET',
#   'TRN',
#   'DCFC',
#   'TRTN',
#   'TGI',
#   'TBI',
#   'TSP',
#   'TPC',
#   'TWIN',
#   'ULBI',
#   'UNF',
#   'UNP',
#   'UAL',
#   'UPS',
#   'URI',
#   'ULH',
#   'UUU',
#   'UPWK',
#   'UGRO',
#   'USAK',
#   'USDP',
#   'ECOL',
#   'USX',
#   'VMI',
#   'VEC',
#   'VRME',
#   'VRSK',
#   'VRTV',
#   'VRRM',
#   'EVTL',
#   'VRT',
#   'VVI',
#   'VIEW',
#   'SPCE',
#   'VORB',
#   'VTSI',
#   'VVNT',
#   'VOLT',
#   'VSEC',
#   'WNC',
#   'WAB',
#   'WCN',
#   'WM',
#   'WSO',
#   'WSO.B',
#   'WTS',
#   'WBT',
#   'WERN',
#   'WCC',
#   'UP',
#   'WHLM',
#   'WLDN',
#   'WLMS',
#   'WLFC',
#   'WSC',
#   'WWD',
#   'WOR',
#   'GWW',
#   'XMTR',
#   'XOS',
#   'XPO',
#   'XYL',
#   'YAYO',
#   'YELL',
#   'ZIM',
#   'ZIP',
#   'ZTO',
#   'ZWS'],
#  'Technology': ['VNET',
#   'DDD',
#   'EGHT',
#   'JFU',
#   'ATEN',
#   'ABST',
#   'ACN',
#   'ACIW',
#   'ACMR',
#   'ACVA',
#   'AEY',
#   'ADBE',
#   'ADTN',
#   'AHI',
#   'AMD',
#   'AEHR',
#   'AFRM',
#   'AGIL',
#   'AGYS',
#   'AGMH',
#   'API',
#   'AIRG',
#   'AKAM',
#   'AKTS',
#   'ALRM',
#   'ALF',
#   'ALIT',
#   'ALYA',
#   'ALKT',
#   'ALGM',
#   'AMOT',
#   'ALLT',
#   'AOSL',
#   'ALTR',
#   'AYX',
#   'AMBA',
#   'DOX',
#   'AMSWA',
#   'AVCT',
#   'AMST',
#   'AMKR',
#   'APH',
#   'AMPG',
#   'AMPL',
#   'ASYS',
#   'ADI',
#   'PLAN',
#   'ANSS',
#   'APPF',
#   'APPN',
#   'AAPL',
#   'AMAT',
#   'AAOI',
#   'APP',
#   'APCX',
#   'ARBE',
#   'ANET',
#   'ARQQ',
#   'ARRY',
#   'ARW',
#   'AIP',
#   'ASAN',
#   'ASX',
#   'ASGN',
#   'ASML',
#   'AZPN',
#   'ALOT',
#   'ASUR',
#   'TEAM',
#   'ATOM',
#   'ATC',
#   'AUUD',
#   'AUDC',
#   'AEYE',
#   'AUR',
#   'JG',
#   'ADSK',
#   'AATC',
#   'AVLR',
#   'AVYA',
#   'AVPT',
#   'AVNW',
#   'AVDX',
#   'AVT',
#   'AWRE',
#   'ACLS',
#   'AXTI',
#   'BLZE',
#   'BKKT',
#   'BAND',
#   'GLG',
#   'BEEM',
#   'BDC',
#   'BELFB',
#   'BELFA',
#   'BHE',
#   'BNFT',
#   'BSY',
#   'BBAI',
#   'BIGC',
#   'BILL',
#   'BTCM',
#   'BKTI',
#   'BLKB',
#   'BB',
#   'BLBX',
#   'BKI',
#   'BL',
#   'BKSY',
#   'BLND',
#   'BDR',
#   'BMTX',
#   'BNSO',
#   'BRQS',
#   'BOSC',
#   'EPAY',
#   'BOX',
#   'BOXL',
#   'BRZE',
#   'BLIN',
#   'BCOV',
#   'AVGO',
#   'BR',
#   'BSQR',
#   'BTRS',
#   'BMBL',
#   'AI',
#   'CCMP',
#   'CACI',
#   'CDNS',
#   'CAMP',
#   'CALX',
#   'CMBM',
#   'CAMT',
#   'CAN',
#   'CSIQ',
#   'CAJ',
#   'CTLP',
#   'CASA',
#   'CZOO',
#   'CCCS',
#   'CDK',
#   'CDW',
#   'CLS',
#   'CLBT',
#   'CETX',
#   'CPTN',
#   'CRNT',
#   'CISO',
#   'CRNC',
#   'CDAY',
#   'CEVA',
#   'GIB',
#   'ECOM',
#   'CHKP',
#   'CIH',
#   'CD',
#   'IMOS',
#   'CIEN',
#   'CRUS',
#   'CSCO',
#   'CINT',
#   'CTXS',
#   'CLVT',
#   'CLSK',
#   'CLFD',
#   'CLRO',
#   'YOU',
#   'CWAN',
#   'RAAS',
#   'NET',
#   'CLPS',
#   'CGNX',
#   'CTSH',
#   'CGNT',
#   'COHR',
#   'COHU',
#   'COIN',
#   'COMM',
#   'CVLT',
#   'COMP',
#   'CTG',
#   'CMTL',
#   'CNXC',
#   'CNDT',
#   'CFLT',
#   'CCSI',
#   'CTK',
#   'CCRD',
#   'CORZ',
#   'GLW',
#   'CRSR',
#   'BASE',
#   'COUP',
#   'CPSH',
#   'CREX',
#   'CRDO',
#   'CRCT',
#   'CRWD',
#   'LAW',
#   'CSGS',
#   'CSPI',
#   'CTS',
#   'CUEN',
#   'CVT',
#   'CYBR',
#   'CYBE',
#   'CTEK',
#   'CYN',
#   'CYRN',
#   'CYXT',
#   'DJCO',
#   'DAKT',
#   'DQ',
#   'DZSI',
#   'DDOG',
#   'DAIO',
#   'DTSS',
#   'DTST',
#   'DATS',
#   'MSP',
#   'DAVE',
#   'DELL',
#   'DM',
#   'DSWL',
#   'DIDI',
#   'DBD',
#   'DGHI',
#   'DGII',
#   'DMRC',
#   'DOCN',
#   'APPS',
#   'DIOD',
#   'DLO',
#   'DCBO',
#   'DOCU',
#   'DLB',
#   'DOMO',
#   'DV',
#   'DBX',
#   'DCT',
#   'DNB',
#   'DUOL',
#   'DUOT',
#   'DXC',
#   'DT',
#   'ETWO',
#   'EBON',
#   'EBIX',
#   'SATS',
#   'EGAN',
#   'ESTC',
#   'ELSE',
#   'ELTK',
#   'EMAN',
#   'EMBK',
#   'EMKR',
#   'MSN',
#   'DAVA',
#   'WATT',
#   'ENFN',
#   'ESMT',
#   'ENPH',
#   'ENTG',
#   'ENV',
#   'EPAM',
#   'PLUS',
#   'ESE',
#   'EEFT',
#   'EB',
#   'EVBG',
#   'EVCM',
#   'MRAM',
#   'EVTC',
#   'EVOL',
#   'EVOP',
#   'XELA',
#   'EXLS',
#   'EXFY',
#   'EXTR',
#   'EZFL',
#   'FFIV',
#   'FN',
#   'FICO',
#   'FARO',
#   'FSLY',
#   'FSRD',
#   'FATH',
#   'FIS',
#   'FSLR',
#   'FISV',
#   'FIVN',
#   'FLT',
#   'FLEX',
#   'FLYW',
#   'FCUV',
#   'FRGE',
#   'FORG',
#   'FORM',
#   'FORTY',
#   'FTNT',
#   'FTV',
#   'FKWL',
#   'FEIM',
#   'FRSH',
#   'FTCI',
#   'YMM',
#   'FTFT',
#   'GRMN',
#   'IT',
#   'GDS',
#   'G',
#   'GILT',
#   'GTLB',
#   'VRAR',
#   'GB',
#   'GFS',
#   'GLOB',
#   'GDDY',
#   'GPRO',
#   'GBOX',
#   'GDYN',
#   'GVP',
#   'GSIT',
#   'GTYH',
#   'GWRE',
#   'HLIT',
#   'HCP',
#   'HTCR',
#   'HPE',
#   'HIMX',
#   'HPQ',
#   'HUBS',
#   'HUSN',
#   'IIIV',
#   'IBEX',
#   'ICHR',
#   'INVE',
#   'IDBA',
#   'IIVI',
#   'IMMR',
#   'PI',
#   'INDI',
#   'INFN',
#   'IFBD',
#   'INFA',
#   'III',
#   'INFY',
#   'INOD',
#   'INPX',
#   'INSG',
#   'NSIT',
#   'INST',
#   'INTA',
#   'IMTE',
#   'INTC',
#   'IDN',
#   'LINK',
#   'IBM',
#   'IMXI',
#   'INTT',
#   'INTZ',
#   'INTU',
#   'IONQ',
#   'IPGP',
#   'AUID',
#   'IRNT',
#   'IS',
#   'ISDR',
#   'ISUN',
#   'ITI',
#   'ITRI',
#   'ITRN',
#   'JBL',
#   'JKHY',
#   'FROG',
#   'JKS',
#   'JNPR',
#   'KLR',
#   'KLTR',
#   'KARO',
#   'KSPN',
#   'KPLT',
#   'KEYS',
#   'KTCC',
#   'KC',
#   'KLAC',
#   'KNBE',
#   'KN',
#   'KOPN',
#   'KOSS',
#   'KBNT',
#   'KLIC',
#   'KULR',
#   'KVHI',
#   'KD',
#   'LAIX',
#   'LRCX',
#   'LTRX',
#   'LTCH',
#   'LSCC',
#   'LDOS',
#   'LPL',
#   'LPTH',
#   'LSPD',
#   'LLNW',
#   'LFUS',
#   'LPSN',
#   'RAMP',
#   'LVOX',
#   'LOGI',
#   'LYLT',
#   'GNSS',
#   'LYTS',
#   'LITE',
#   'LUNA',
#   'LYFT',
#   'MTSI',
#   'MGIC',
#   'MX',
#   'MNDT',
#   'MANH',
#   'MANT',
#   'MRIN',
#   'MTEK',
#   'MKTW',
#   'MKFG',
#   'MQ',
#   'MRVL',
#   'MTLS',
#   'MTTR',
#   'MIGI',
#   'MAXR',
#   'MAXN',
#   'MXL',
#   'MCLD',
#   'MLNK',
#   'MLAB',
#   'MMAT',
#   'MEI',
#   'MCHP',
#   'MFGP',
#   'MU',
#   'MSFT',
#   'MSTR',
#   'MVIS',
#   'MICT',
#   'MIME',
#   'MNDO',
#   'MINM',
#   'MIND',
#   'MITK',
#   'MIXT',
#   'MKSI',
#   'MTC',
#   'MODN',
#   'MOGO',
#   'MNTV',
#   'MNDY',
#   'ML',
#   'MDB',
#   'MPWR',
#   'MSI',
#   'MITQ',
#   'MYNA',
#   'MYSZ',
#   'NABL',
#   'NNDM',
#   'NATI',
#   'NVTS',
#   'NCNO',
#   'NCR',
#   'NEON',
#   'NPTN',
#   'NRDY',
#   'UEPS',
#   'NTAP',
#   'NTGR',
#   'NTCT',
#   'NTWK',
#   'NEWR',
#   'NXPL',
#   'NXTP',
#   'NICE',
#   'LASR',
#   'NOK',
#   'NSYS',
#   'NLOK',
#   'NVMI',
#   'NOVT',
#   'NTNX',
#   'NVEI',
#   'NVEC',
#   'NVDA',
#   'NXPI',
#   'OIIM',
#   'OBLG',
#   'OKTA',
#   'OLB',
#   'OLO',
#   'OMQS',
#   'ONTF',
#   'ONDS',
#   'OCFT',
#   'OSPN',
#   'OSS',
#   'OG',
#   'ON',
#   'ONTO',
#   'OTEX',
#   'OPFI',
#   'OCC',
#   'ORCL',
#   'OSIS',
#   'OTMO',
#   'OUST',
#   'PD',
#   'PAGS',
#   'PLTR',
#   'PANW',
#   'PALT',
#   'TEUM',
#   'PCYG',
#   'PAR',
#   'PAYA',
#   'PAYC',
#   'PYCR',
#   'PCTY',
#   'PAY',
#   'PAYO',
#   'PSFE',
#   'PAYS',
#   'CNXN',
#   'PCTI',
#   'PDFS',
#   'PEGA',
#   'PRSO',
#   'PRFT',
#   'PLAB',
#   'PHUN',
#   'PEGY',
#   'PING',
#   'PXLW',
#   'POLY',
#   'PLXS',
#   'POET',
#   'PRCH',
#   'PBTS',
#   'POWI',
#   'PWSC',
#   'PRTH',
#   'PCOR',
#   'PRGS',
#   'PRO',
#   'PTC',
#   'PUBM',
#   'PSTG',
#   'QTWO',
#   'QIWI',
#   'QRVO',
#   'QCOM',
#   'XM',
#   'QLYS',
#   'QNGY',
#   'QUBT',
#   'QMCO',
#   'QH',
#   'QUIK',
#   'QUMU',
#   'RXT',
#   'RDWR',
#   'RMBS',
#   'RPD',
#   'RCAT',
#   'RDVT',
#   'REKR',
#   'MARK',
#   'RELY',
#   'SOL',
#   'RPAY',
#   'REFR',
#   'RSSS',
#   'RELL',
#   'RGTI',
#   'RMNI',
#   'RNG',
#   'RIOT',
#   'RSKD',
#   'HOOD',
#   'RKLY',
#   'ROG',
#   'RBCN',
#   'SFET',
#   'SAIL',
#   'CRM',
#   'IOT',
#   'SANG',
#   'SANM',
#   'SPNS',
#   'SAP',
#   'STRC',
#   'SATL',
#   'SCSC',
#   'SMIT',
#   'SAIC',
#   'SEAC',
#   'STX',
#   'SCWX',
#   'LEDS',
#   'SEMR',
#   'SMTC',
#   'ST',
#   'S',
#   'SQNS',
#   'NOW',
#   'SREV',
#   'FOUR',
#   'SHLS',
#   'SHOP',
#   'SSTI',
#   'SWIR',
#   'SGLB',
#   'SGMA',
#   'SILC',
#   'SLAB',
#   'SIMO',
#   'SSNT',
#   'SITM',
#   'SYTA',
#   'SKYT',
#   'SWKS',
#   'SGH',
#   'SMAR',
#   'SMSI',
#   'SNPO',
#   'SNOW',
#   'SOPA',
#   'SCKT',
#   'SEDG',
#   'SWI',
#   'SLNH',
#   'SOFO',
#   'SONM',
#   'SONO',
#   'SOTK',
#   'SONY',
#   'SOS',
#   'ANY',
#   'SPI',
#   'SPLK',
#   'SRAD',
#   'CXM',
#   'SPT',
#   'SPSC',
#   'SKYX',
#   'SQ',
#   'SQSP',
#   'SSNC',
#   'SMRT',
#   'STEM',
#   'STER',
#   'STM',
#   'STNE',
#   'SSYS',
#   'WISA',
#   'SUMO',
#   'NOVA',
#   'SPWR',
#   'RUN',
#   'SUNW',
#   'SMCI',
#   'SURG',
#   'SWCH',
#   'SWVL',
#   'SYNA',
#   'SNCR',
#   'SNX',
#   'SNPS',
#   'TAIT',
#   'TSM',
#   'TAOP',
#   'TASK',
#   'TCCO',
#   'TEL',
#   'TDY',
#   'ERIC',
#   'TSAT',
#   'TLS',
#   'TIXT',
#   'TENB',
#   'TDC',
#   'TER',
#   'TESS',
#   'TXN',
#   'DSGX',
#   'HCKT',
#   'LGL',
#   'TTD',
#   'TWKS',
#   'TOST',
#   'TSEM',
#   'TACT',
#   'TGAN',
#   'TRMB',
#   'TRT',
#   'TROO',
#   'TSRI',
#   'IDAI',
#   'TTEC',
#   'TTMI',
#   'TCX',
#   'TUFN',
#   'HEAR',
#   'TUYA',
#   'TYL',
#   'UBER',
#   'UI',
#   'PATH',
#   'UCTT',
#   'UIS',
#   'UMC',
#   'U',
#   'OLED',
#   'UEIC',
#   'UPLD',
#   'USER',
#   'USIO',
#   'UTME',
#   'UTSI',
#   'VCSA',
#   'VLN',
#   'VRNS',
#   'VECO',
#   'VLD',
#   'VLDR',
#   'VERB',
#   'VRNT',
#   'VRSN',
#   'VERI',
#   'VERX',
#   'DSP',
#   'VIAO',
#   'VSAT',
#   'VIAV',
#   'VICR',
#   'VMEO',
#   'VQS',
#   'VHC',
#   'VSH',
#   'VPG',
#   'VISL',
#   'VVPR',
#   'VZIO',
#   'VMW',
#   'VNT',
#   'VJET',
#   'VOXX',
#   'VTEX',
#   'VUZI',
#   'WTRH',
#   'WKME',
#   'WBX',
#   'WAVD',
#   'WSTG',
#   'WEAV',
#   'WEJO',
#   'WDC',
#   'WEX',
#   'WFCF',
#   'WYY',
#   'WIT',
#   'WTT',
#   'WKEY',
#   'WIX',
#   'MAPS',
#   'WNS',
#   'WOLF',
#   'WDAY',
#   'WK',
#   'WRAP',
#   'XRX',
#   'XPER',
#   'YALA',
#   'YEXT',
#   'DAO',
#   'ZBRA',
#   'ZEN',
#   'ZENV',
#   'ZEPP',
#   'ZETA',
#   'ZI',
#   'ZM',
#   'ZS',
#   'ZUO',
#   'PWFL'],
#  'Utilities': ['ADN',
#   'AQN',
#   'ALE',
#   'LNT',
#   'AMPS',
#   'AEE',
#   'AEP',
#   'AWR',
#   'AWK',
#   'LFG',
#   'ARIS',
#   'ARTNA',
#   'AY',
#   'ATO',
#   'AGR',
#   'AVA',
#   'AZRE',
#   'BKH',
#   'BIPC',
#   'BIP',
#   'BEPC',
#   'BEP',
#   'CDZI',
#   'CWT',
#   'CNP',
#   'EBR.B',
#   'EBR',
#   'CEPU',
#   'CPK',
#   'CREG',
#   'CWEN',
#   'CWEN.A',
#   'CMS',
#   'SBS',
#   'CIG.C',
#   'CIG',
#   'ELP',
#   'ED',
#   'CWCO',
#   'CEG',
#   'D',
#   'DTE',
#   'DUK',
#   'WAVE',
#   'EIX',
#   'ELLO',
#   'EE',
#   'EDN',
#   'ENIA',
#   'ENIC',
#   'NRGV',
#   'ETR',
#   'WTRG',
#   'EVRG',
#   'ES',
#   'EXC',
#   'FE',
#   'FLNC',
#   'FTS',
#   'HTOO',
#   'GNE',
#   'GWRS',
#   'HE',
#   'HLGN',
#   'HNP',
#   'IDA',
#   'KEN',
#   'KEP',
#   'MGEE',
#   'MSEX',
#   'MNTK',
#   'NGG',
#   'NFE',
#   'NJR',
#   'NEE',
#   'NEP',
#   'NI',
#   'NWE',
#   'NWN',
#   'NRG',
#   'OGE',
#   'OGS',
#   'OEG',
#   'ORA',
#   'OTTR',
#   'PAM',
#   'PCG',
#   'PNW',
#   'PNM',
#   'POR',
#   'PPL',
#   'PEG',
#   'PCYO',
#   'RNW',
#   'RGCO',
#   'SRE',
#   'SJW',
#   'SJI',
#   'SWX',
#   'SR',
#   'SPH',
#   'AES',
#   'SO',
#   'YORW',
#   'TAC',
#   'UGI',
#   'UTL',
#   'VIA',
#   'VWTR',
#   'VST',
#   'WEC',
#   'XEL']}

# %%
transactions = pd.read_csv('../data/all_transactions.csv')

# %%
transactions = transactions[(transactions['asset_type'] == 'Stock')|(transactions['asset_type'] == 'Stock Option')]
transactions
# Out:
#      transaction_date   owner ticker  \
# 0          03/09/2022    Self   TACO
# 15         03/30/2022   Joint    WST
# 16         03/30/2022   Joint   VEEV
# 17         03/30/2022   Joint    VMW
# 18         03/30/2022   Joint    SNA
# ...               ...     ...    ...
# 8406       12/11/2014  Spouse  DVFAX
# 8412       12/12/2014  Spouse    XOM
# 8413       12/19/2014  Spouse     BA
# 8414       12/12/2014  Spouse    BAC
# 8415       12/11/2014  Spouse    MIK
#
#                                     asset_description asset_type  \
# 0           Del Taco Restaurants, Inc. - Common Stock      Stock
# 15    West Pharmaceutical Services, Inc. Common Stock      Stock
# 16            Veeva Systems Inc. Class A Common Stock      Stock
# 17                 Vmware, Inc. Common stock, Class A      Stock
# 18                  Snap-On Incorporated Common Stock      Stock
# ...                                               ...        ...
# 8406     Cohen &amp; Steers Dividend Value A (NASDAQ)      Stock
# 8412                   Exxon Mobil Corporation (NYSE)      Stock
# 8413                        The Boeing Company (NYSE)      Stock
# 8414               Bank of America Corporation (NYSE)      Stock
# 8415            The Michaels Companies, Inc. (NASDAQ)      Stock
#
#                 type             amount  \
# 0     Sale (Partial)  $15,001 - $50,000
# 15       Sale (Full)   $1,001 - $15,000
# 16       Sale (Full)   $1,001 - $15,000
# 17       Sale (Full)   $1,001 - $15,000
# 18       Sale (Full)   $1,001 - $15,000
# ...              ...                ...
# 8406        Purchase   $1,001 - $15,000
# 8412     Sale (Full)   $1,001 - $15,000
# 8413        Purchase   $1,001 - $15,000
# 8414     Sale (Full)   $1,001 - $15,000
# 8415        Purchase   $1,001 - $15,000
#
#                                     comment                senator  \
# 0     Asset held by Roundstone Ventures LLC  William F Hagerty, Iv
# 15                                       --    Thomas H Tuberville
# 16                                       --    Thomas H Tuberville
# 17                                       --    Thomas H Tuberville
# 18                                       --    Thomas H Tuberville
# ...                                     ...                    ...
# 8406                                     --        Susan M Collins
# 8412                                    Sep            Pat Roberts
# 8413                                      R            Pat Roberts
# 8414                                      R            Pat Roberts
# 8415                                      R            Pat Roberts
#
#                                                ptr_link disclosure_date
# 0     https://efdsearch.senate.gov/search/view/ptr/3...      04/13/2022
# 15    https://efdsearch.senate.gov/search/view/ptr/0...      04/08/2022
# 16    https://efdsearch.senate.gov/search/view/ptr/0...      04/08/2022
# 17    https://efdsearch.senate.gov/search/view/ptr/0...      04/08/2022
# 18    https://efdsearch.senate.gov/search/view/ptr/0...      04/08/2022
# ...                                                 ...             ...
# 8406  https://efdsearch.senate.gov/search/view/ptr/d...      01/09/2015
# 8412  https://efdsearch.senate.gov/search/view/ptr/f...      01/05/2015
# 8413  https://efdsearch.senate.gov/search/view/ptr/f...      01/05/2015
# 8414  https://efdsearch.senate.gov/search/view/ptr/f...      01/05/2015
# 8415  https://efdsearch.senate.gov/search/view/ptr/f...      01/05/2015
#
# [6985 rows x 11 columns]

# %%
for index,value in tqdm(transactions['senator'].iteritems()):
    if value == 'William F Hagerty, Iv':
        transactions.loc[index, 'senator_rev'] = 'Hagerty, Bill'
    if value == 'Thomas H Tuberville':
        transactions.loc[index, 'senator_rev'] = 'Tuberville, Tommy'
    if value == 'Thomas R Carper':
        transactions.loc[index, 'senator_rev'] = 'Carper, Thomas'
    if value == 'Ron L Wyden':
        transactions.loc[index, 'senator_rev'] = 'Wyden, Ron'
    if value == 'A. Mitchell Mcconnell, Jr.':
        transactions.loc[index, 'senator_rev'] = 'McConnell, Mitch'
    if value == 'Shelley M Capito':
        transactions.loc[index, 'senator_rev'] = 'Capito, Shelley'
    if value == 'Patrick J Toomey':
        transactions.loc[index, 'senator_rev'] = 'Toomey, Pat'
    if value == 'Mark R Warner':
        transactions.loc[index, 'senator_rev'] = 'Warner, Mark'
    if value == 'Susan M Collins':
        transactions.loc[index, 'senator_rev'] = 'Collins, Susan'
    if value == 'Jerry Moran,':
        transactions.loc[index, 'senator_rev'] = 'Moran, Jerry'
    if value == 'John R Thune':
        transactions.loc[index, 'senator_rev'] = 'Thune, John'
    if value == 'John W Hickenlooper':
        transactions.loc[index, 'senator_rev'] = 'Hickenlooper, John'
    if value == 'Jacklyn S Rosen':
        transactions.loc[index, 'senator_rev'] = 'Rosen, Jacky'
    if value == 'Gary C Peters':
        transactions.loc[index, 'senator_rev'] = 'Peters, Gary'
    if value == 'Roy Blunt':
        transactions.loc[index, 'senator_rev'] = 'Blunt, Roy'
    if value == 'Cynthia M Lummis':
        transactions.loc[index, 'senator_rev'] = 'Lummis, Cynthia'
    if value == 'Sheldon Whitehouse':
        transactions.loc[index, 'senator_rev'] = 'Whitehouse, Sheldon'
    if value == 'Rand Paul':
        transactions.loc[index, 'senator_rev'] = 'Paul, Rand'
    if value == 'Angus S King, Jr.':
        transactions.loc[index, 'senator_rev'] = 'King, Angus'
    if value == 'John Boozman':
        transactions.loc[index, 'senator_rev'] = 'Boozman, John'
    if value == 'Ladda Tammy Duckworth':
        transactions.loc[index, 'senator_rev'] = 'Duckworth, Tammy'
    if value == 'Daniel S Sullivan':
        transactions.loc[index, 'senator_rev'] = 'Sullivan, Dan'
    if value == 'James M Inhofe':
        transactions.loc[index, 'senator_rev'] = 'Inhofe, Jim'
    if value == 'Pat Roberts':
        transactions.loc[index, 'senator_rev'] = 'Roberts, Pat'
    if value == 'William Cassidy':
        transactions.loc[index, 'senator_rev'] = 'Cassidy, Bill'
    if value == 'Kelly Loeffler':
        transactions.loc[index, 'senator_rev'] = 'Loeffler, Kelly'
    if value == 'Timothy M Kaine':
        transactions.loc[index, 'senator_rev'] = 'Kaine, Tim'
    if value == 'David A Perdue , Jr':
        transactions.loc[index, 'senator_rev'] = 'Perdue, David'
    if value == 'Tina Smith':
        transactions.loc[index, 'senator_rev'] = 'Smith, Tina'
    if value == 'John Hoeven':
        transactions.loc[index, 'senator_rev'] = 'Hoeven, John'
    if value == 'John N Kennedy':
        transactions.loc[index, 'senator_rev'] = 'Kennedy, John'
    if value == 'Rafael E Cruz':
        transactions.loc[index, 'senator_rev'] = 'Cruz, Ted'
    if value == 'Christopher A Coons':
        transactions.loc[index, 'senator_rev'] = 'Coons, Christopher'
    if value == 'Thomas Udall':
        transactions.loc[index, 'senator_rev'] = 'Udall, Tom'
    if value == 'John F Reed':
        transactions.loc[index, 'senator_rev'] = 'Reed, John'
    if value == 'Thomas R Tillis':
        transactions.loc[index, 'senator_rev'] = 'Tillis, Thom'
    if value == 'Robert P Casey, Jr.':
        transactions.loc[index, 'senator_rev'] = 'Casey, Bob'
    if value == 'Tammy Duckworth':
        transactions.loc[index, 'senator_rev'] = 'Duckworth, Tammy'
    if value == 'Michael F Bennet':
        transactions.loc[index, 'senator_rev'] = 'Bennet, Michael'
    if value == 'Patty Murray':
        transactions.loc[index, 'senator_rev'] = 'Murray, Patty'
    if value == 'Steve Daines':
        transactions.loc[index, 'senator_rev'] = 'Daines, Steve'
    if value == 'Joseph Manchin, Iii':
        transactions.loc[index, 'senator_rev'] = 'Manchin, Joe'
    if value == 'Chris Van Hollen':
        transactions.loc[index, 'senator_rev'] = 'Van Hollen, Chris'
    if value == 'John Cornyn':
        transactions.loc[index, 'senator_rev'] = 'Cornyn, John'
    if value == 'Maria Cantwell':
        transactions.loc[index, 'senator_rev'] = 'Cantwell, Maria'
    if value == 'Michael  B Enzi':
        transactions.loc[index, 'senator_rev'] = 'Enzi, Michael'
    if value == 'Mike Rounds':
        transactions.loc[index, 'senator_rev'] = 'Rounds, Mike'
# Out:
# 0it [00:00, ?it/s]

# %%
sen_list = ['Hagerty, Bill',
 'Tuberville, Tommy',
 'Carper, Thomas',
 'Wyden, Ron',
 'McConnell, Mitch',
 'Capito, Shelley',
 'Toomey, Pat',
 'Warner, Mark',
 'Collins, Susan',
 'Moran, Jerry',
 'Thune, John',
 'Hickenlooper, John',
 'Rosen, Jacky',
 'Peters, Gary',
 'Blunt, Roy',
 'Lummis, Cynthia',
 'Whitehouse, Sheldon',
 'Paul, Rand',
 'King, Angus',
 'Boozman, John',
 'Duckworth, Tammy',
 'Sullivan, Dan',
 'Inhofe, Jim',
 'Roberts, Pat',
 'Cassidy, Bill',
 'Loeffler, Kelly',
 'Kaine, Tim',
 'Perdue, David',
 'Smith, Tina',
 'Hoeven, John',
 'Kennedy, John',
 'Cruz, Ted',
 'Coons, Christopher',
 'Udall, Tom',
 'Reed, John',
 'Tillis, Thom',
 'Casey, Bob',
 'Bennet, Michael',
 'Murray, Patty',
 'Daines, Steve',
 'Manchin, Joe',
 'Van Hollen, Chris',
 'Cornyn, John',
 'Cantwell, Maria',
 'Enzi, Michael',
 'Rounds, Mike']

# %%
sen_stock_dict = {}
for sen in sen_list:
    if sen in sen_stock_dict:
        sen_stock_dict[sen].extend(list(transactions[transactions.senator_rev == sen]['ticker']))
    else:
        sen_stock_dict[sen] = list(transactions[transactions.senator_rev == sen]['ticker'])

# %%
sen_stock_dict
# Out:
# {'Hagerty, Bill': ['TACO',
#   'DDOG',
#   'RHP',
#   'RNR',
#   'RHP',
#   'RNR',
#   'PNFP',
#   'ENVA',
#   'CCEP',
#   'BKEP',
#   'NS',
#   'CLDT',
#   'VRM',
#   'DDOG',
#   'BA',
#   'FL4.SG',
#   'NTRA',
#   'QRTEP',
#   'CTAA',
#   '--',
#   'LMND',
#   '--',
#   'VRM'],
#  'Tuberville, Tommy': ['WST',
#   'VEEV',
#   'VMW',
#   'SNA',
#   'SIVB',
#   'SPGI',
#   'ROK',
#   'REGN',
#   'NFLX',
#   'LMST',
#   'KEY',
#   'INTU',
#   'GNRC',
#   'FGBI',
#   'FITB',
#   'EXP',
#   'DEO',
#   'CFG',
#   'CE',
#   'CP',
#   'CABO',
#   'BKE',
#   'BIO',
#   'BMO',
#   'TMO',
#   'RMD',
#   'RF',
#   'NOC',
#   'NDAQ',
#   'MRK',
#   'MASI',
#   'MMC',
#   'MKSI',
#   'HUMA',
#   'HON',
#   'GFI',
#   'IT',
#   'DHI',
#   'CDNS',
#   'AME',
#   'GOOG',
#   'ABBV',
#   'GOLD',
#   'GOLD',
#   'MSFT',
#   'SCCO',
#   'NU',
#   'ECOM',
#   'NU',
#   'ECOM',
#   '--',
#   'OXY',
#   'ARKK',
#   'ARKK',
#   'X',
#   'X',
#   'X',
#   'X',
#   'PYPL',
#   'PYPL',
#   'PYPL',
#   'PYPL',
#   'ECOM',
#   'ECOM',
#   'ECOM',
#   'ECOM',
#   'PYPL',
#   'F',
#   'X',
#   'MSFT',
#   'MRO',
#   'MRO',
#   'CLF',
#   'INTC',
#   'GOLD',
#   'BABA',
#   'QCOM',
#   'BABA',
#   'BABA',
#   'QCOM',
#   'CLF',
#   'CLF',
#   'X',
#   'INTC',
#   'WBA',
#   'VZ',
#   'MMM',
#   'PFE',
#   'IBM',
#   'INTC',
#   'KO',
#   'CSCO',
#   'CVX',
#   'DOW',
#   'AMGN',
#   'INTC',
#   'CLF',
#   'SSYS',
#   'SSYS',
#   'SSYS',
#   'SSYS',
#   'DUK',
#   'MDT',
#   'ABBV',
#   'ABC',
#   'CTAS',
#   'LMT',
#   'PEP',
#   'PM',
#   'PONCX',
#   'PG',
#   'TSN',
#   'XEL',
#   'ABQCX',
#   'FUN',
#   'CRWD',
#   'FGSCX',
#   'GILD',
#   'CLOU',
#   'NWL',
#   'PEGA',
#   'VTRS',
#   'ACN',
#   'ADBE',
#   'AWK',
#   'AAPL',
#   'CTAS',
#   'LLY',
#   'MA',
#   'MSFT',
#   'NEE',
#   'RTX',
#   'WMT',
#   'AAPL',
#   'PYPL',
#   'QQQ',
#   'ECOM',
#   'CLF',
#   'ECOM',
#   'ECOM',
#   'BABA',
#   'BABA',
#   'BABA',
#   'BABA',
#   'SSYS',
#   'MSFT',
#   'OXY',
#   'ECOM',
#   'AAPL',
#   'OXY',
#   'PYPL',
#   'PYPL',
#   'PYPL',
#   'ADBE',
#   'CLF',
#   'CLF',
#   'CLF',
#   'CLF',
#   'F',
#   'F',
#   'SSYS',
#   'SCCO',
#   'SCCO',
#   'SCCO',
#   'SCCO',
#   'QCOM',
#   'RMD',
#   'APAM',
#   'AON',
#   'X',
#   'CALX',
#   'CALX',
#   'CALX',
#   'INTC',
#   'INTC',
#   'AA',
#   'X',
#   'X',
#   'INTC',
#   'AA',
#   'GE',
#   'UAA',
#   'UA',
#   'BDX',
#   'D',
#   'DOW',
#   'GD',
#   'PG',
#   'NFLX',
#   'MPWR',
#   'KEYS',
#   'KLAC',
#   'JNJ',
#   'INTU',
#   'GNRC',
#   'EL',
#   'EXP',
#   'DEO',
#   'CTAS',
#   'CABO',
#   'BKE',
#   'ALLE',
#   'APD',
#   'WAL',
#   'MMM',
#   '--',
#   'DECK',
#   'CLX',
#   'CHE',
#   'BHP',
#   'ATHM',
#   'AME',
#   'SSYS',
#   'X',
#   'BABA',
#   'BABA',
#   'BABA',
#   'BABA',
#   'ECOM',
#   'CALX',
#   'ECOM',
#   'ECOM',
#   'CALX',
#   'SSYS',
#   'SSBK',
#   'INTC',
#   'OXY',
#   'OXY',
#   'F',
#   'AA',
#   'NVDA',
#   'CLF',
#   'CLF',
#   'CLF',
#   'CLF',
#   'CLF',
#   'CLF',
#   'CLF',
#   'CLF',
#   'AA',
#   'BABA',
#   'BABA',
#   'QQQ',
#   'INTC',
#   'CRWD',
#   'NWL',
#   'PEGA',
#   'PEP',
#   'XLY',
#   '--',
#   'MTUM',
#   'SQ',
#   'DTD',
#   'ALGN',
#   'INTC',
#   'BABA',
#   'CLF',
#   'CLF',
#   'SDOG',
#   'QQQ',
#   'TDY',
#   'AA',
#   'AA',
#   'AA',
#   'AA',
#   'AA',
#   'FB',
#   'INTC',
#   'INTC',
#   'INTC',
#   'INTC',
#   'WY',
#   'ONEQ',
#   'DG',
#   'ADBE',
#   'OXY',
#   'OXY',
#   'OXY',
#   'OXY',
#   'OXY',
#   'OXY',
#   'ECOM',
#   'ECOM',
#   'ECOM',
#   'ECOM',
#   'ECOM',
#   'ECOM',
#   'ECOM',
#   'ECOM',
#   'ECOM',
#   'VEEV',
#   'F',
#   'SSYS',
#   'SSYS',
#   'MSFT',
#   'BRK-B',
#   'CSX',
#   'WST',
#   'WAL',
#   'WAT',
#   'VMW',
#   'MMM',
#   'TER',
#   'SNA',
#   'SIVB',
#   'SWKS',
#   'SEIC',
#   'ROK',
#   'REGN',
#   'DGX',
#   'QCOM',
#   'PYPL',
#   'ODFL',
#   'NDSN',
#   'NTES',
#   'MRK',
#   'JNJ',
#   'INTU',
#   'IDXX',
#   'IEX',
#   'IEX',
#   'HON',
#   'HSY',
#   'GGG',
#   'GNTX',
#   'FTNT',
#   'EA',
#   'EBAY',
#   'EW',
#   'DECK',
#   'CNR',
#   'CL',
#   'CLX',
#   'CHE',
#   'CE',
#   'BIO',
#   'BHP',
#   'ATHM',
#   'AME',
#   'GOOGL',
#   'AA',
#   'AA',
#   'AA',
#   'AA',
#   'CLF',
#   'CLF',
#   'CLF',
#   'ADP',
#   'CALX',
#   'CALX',
#   'CALX',
#   'QQQ',
#   'CSX',
#   'ECOM',
#   'MSFT',
#   'FB',
#   'ECOM',
#   'CLF',
#   'CLF',
#   'CLF',
#   'AA',
#   'ECOM',
#   'ECOM',
#   'ADBE',
#   'FCX',
#   'SSYS',
#   'CALX',
#   'CALX',
#   'OXY',
#   'OXY',
#   'OXY',
#   'OXY',
#   'INTC',
#   'EA',
#   'PYPL',
#   'PYPL',
#   'FCX',
#   'FDSWX',
#   'FCX',
#   'X',
#   'X',
#   'X',
#   'X',
#   'X',
#   'X',
#   'ADP',
#   'OXY',
#   'MSFT',
#   'AAPL',
#   '--',
#   'QCOM'],
#  'Carper, Thomas': ['MAXR',
#   'WIW',
#   'NVDA',
#   'SI',
#   'C',
#   'TTE',
#   'QCOM',
#   'ARCC',
#   'LMT',
#   'CVS',
#   'NVDA',
#   'MET',
#   'AXS',
#   'GLAD',
#   'HASI',
#   'ETN',
#   'ABBV',
#   'RTX',
#   'IRM',
#   'APO',
#   'LHX',
#   'AAPL',
#   'CSCO',
#   'GLW',
#   'INTC',
#   'V',
#   'WIW',
#   'VZ',
#   'DLR',
#   'RIO',
#   'AMT',
#   'MOS',
#   'LDP',
#   'AQN',
#   'AY',
#   'JCI',
#   'GMRE',
#   'BMY',
#   'DIS',
#   'JNJ',
#   'CEM',
#   'SNOW',
#   'GOOG',
#   'AAPL',
#   'LMRK',
#   'WW',
#   'ARE',
#   'COR',
#   'JCI',
#   'FAST',
#   'NUAN',
#   'GAN',
#   'TRIT',
#   'CWEN',
#   'DD',
#   'INTC',
#   'DD',
#   'PBA',
#   'AQN',
#   'VIAV',
#   'EVOP',
#   'FEYE',
#   'DDOG',
#   'CAG',
#   'AJRD',
#   'TSLA',
#   'PBA',
#   'DD',
#   'DOW',
#   'VTRS',
#   'NTAP',
#   'BMY',
#   'V',
#   'QCOM',
#   'SNPS',
#   'GOLD',
#   'OHI',
#   'WIW',
#   'ERIC',
#   'ARE',
#   'LGI',
#   'MRVL',
#   'BRKR',
#   'MANT',
#   'ACIW',
#   'SWKS',
#   'NUAN',
#   'AJRD',
#   'CONE',
#   'CEF',
#   'WW',
#   'GMAB',
#   'BAH',
#   'LDP',
#   'ABBV',
#   'HBI',
#   'ATVI',
#   'FTNT',
#   'NTLA',
#   'MAXR',
#   'ARNA',
#   'KEYS',
#   'PAGS',
#   'CTVA',
#   'VIAV',
#   'SI',
#   'CRWD',
#   'DD',
#   'DOW',
#   'DDOG',
#   'EVOP',
#   'AAPL',
#   'GLW',
#   'HAL',
#   'PAAS',
#   'TMO',
#   'RIO',
#   'LDP',
#   'LDP',
#   'WIW',
#   'LDP',
#   'TCEHY',
#   'ARE',
#   'CONE',
#   'LDP',
#   'LGI',
#   'WW',
#   'C',
#   'QCOM',
#   'RMD',
#   'OHI',
#   'ARCC',
#   'LMT',
#   'WIW',
#   'NVDA',
#   'AXS',
#   'MPW',
#   'GLAD',
#   'MANT',
#   'SWKS',
#   'HASI',
#   'ABBV',
#   'LMRK',
#   'AY',
#   'IRM',
#   'LHX',
#   'APO',
#   'AAPL',
#   'PFE',
#   'TSN',
#   'TCEHY',
#   'WIW',
#   'PYPL',
#   'CVS',
#   'SWKS',
#   'CEF',
#   'DIS',
#   'CEF',
#   'FPL',
#   'DRI',
#   'QCOM',
#   'RMD',
#   'SBUX',
#   'ARCC',
#   'CVS',
#   'DGX',
#   'ARE',
#   'LGI',
#   'PKG',
#   'MET',
#   'RTN',
#   'GLAD',
#   'SWKS',
#   'CEF',
#   'CFG',
#   'TCEHY',
#   'MPC',
#   'KNX',
#   'CB',
#   'IRM',
#   'HPQ',
#   'LHX',
#   'APO',
#   'CAG',
#   'GLW',
#   'FITB',
#   'MSFT',
#   'NVO',
#   'PEP',
#   'TSN',
#   'VZ',
#   'CEF',
#   'DIS',
#   'SWKS',
#   'CVS',
#   'PYPL',
#   'VOD',
#   'MPC',
#   'WFC',
#   'CSCO',
#   'ABBV',
#   'JPM',
#   'HQL',
#   'HQL',
#   'BSTZ',
#   'BSTZ',
#   'UAA',
#   'UAA',
#   'BP',
#   'MCD',
#   'RTN',
#   'MO',
#   'TSM',
#   'DRI',
#   'CEF',
#   'ABB',
#   'SMG',
#   'CAG',
#   'BSTZ',
#   'BSTZ',
#   'VGR',
#   'QCOM',
#   'SWKS',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   'QCOM',
#   'RMD',
#   '--',
#   'ARCC',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   'NWL',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   'PBA',
#   '--',
#   '--',
#   'GLAD',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   'GLW',
#   'DHR',
#   '--',
#   '--',
#   '--',
#   'HRS',
#   'HRL',
#   '--',
#   '--',
#   '--',
#   'NPK',
#   '--',
#   '--',
#   'RHI',
#   'TMO',
#   'QCOM',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   'TSN',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   'RAI',
#   '--',
#   '--',
#   'SCCO',
#   'ASIX',
#   '--',
#   '--',
#   'MDT',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   'AEE',
#   '--',
#   '--',
#   'WTR',
#   '--',
#   '--',
#   'SE',
#   '--',
#   'ADT.F',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   'GAS',
#   'AEE',
#   '--',
#   'NWN',
#   '--',
#   '--',
#   '--',
#   'CVG',
#   'ATML',
#   'DD',
#   '--',
#   '--',
#   'AAPL',
#   'DD',
#   'DD',
#   'DD',
#   'DD',
#   'DD',
#   'DD',
#   'DD',
#   'DD',
#   'DD',
#   'DD',
#   'DD',
#   '--',
#   'AAPL',
#   'VLO',
#   '--',
#   '--',
#   '--',
#   'ABBV',
#   'ABT',
#   'AAPL',
#   '--',
#   'ITW',
#   '--',
#   '--',
#   'UA',
#   'HBI',
#   'PNQI',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   'TGT',
#   'HBI',
#   '--',
#   'PNQI',
#   '--'],
#  'Wyden, Ron': ['AAPL',
#   'AAPL',
#   'AMAT',
#   'KLAC',
#   'MTCH',
#   'AMAT',
#   'KLAC',
#   'STZ',
#   'AVGO',
#   'INTC',
#   'KLAC',
#   'KLAC',
#   'KLAC',
#   'STX',
#   'AMAT',
#   'KLAC',
#   'AAPL',
#   'AAPL',
#   'AAPL',
#   'AAPL',
#   'DIS',
#   'KLAC',
#   'AAPL',
#   'DIS',
#   'KLAC',
#   'AAPL',
#   'DIS',
#   'KLAC',
#   'BYND',
#   'NVDA',
#   'WDAY',
#   'NVDA',
#   'WDAY',
#   'NVDA',
#   'WDAY',
#   'NFLX',
#   'NFLX',
#   'NFLX',
#   'W',
#   'AAPL',
#   'AMZN',
#   'AAPL',
#   'AMWD',
#   'IRBT',
#   'UPS',
#   'FDX',
#   'W',
#   'SQ',
#   'KR',
#   'CLX',
#   'AMWD',
#   'NFLX',
#   'NFLX',
#   'NFLX',
#   'NVDA',
#   'UPS',
#   'FDX',
#   'SQ',
#   'T',
#   'XOM',
#   'UPS',
#   'NVDA',
#   'KR',
#   'FDX',
#   'LOW',
#   'DHI',
#   'UPS',
#   'UPS',
#   'PSA',
#   'FDX',
#   'F',
#   'DHI',
#   'AAPL',
#   'WDAY',
#   'PSA',
#   'KR',
#   'DHI',
#   'COUP',
#   'CLX',
#   'BYND',
#   'PSA',
#   'MTCH',
#   'KR',
#   'KLAC',
#   'DIS',
#   'MAR',
#   'VAC',
#   'INTC',
#   'MSFT',
#   'OSK',
#   'NVDA',
#   'BYND',
#   'STX',
#   'AMZN',
#   'STX',
#   'AMZN',
#   'AAPL',
#   'KLAC',
#   'MSFT',
#   'NVDA',
#   'TRIP',
#   'AAPL',
#   'CAT',
#   'COST',
#   'F',
#   'OSK',
#   'AAPL',
#   'AAPL',
#   'OSK',
#   'MSFT',
#   'GOOG',
#   'FB',
#   'IRBT',
#   'NVDA',
#   'DHI',
#   'AMZN',
#   'AAPL',
#   'AMZN',
#   'MSFT',
#   'NFLX',
#   'NVDA',
#   'AAPL',
#   'COST',
#   'COUP',
#   'DIS',
#   'FB',
#   'GOOG',
#   'IRBT',
#   'MSFT',
#   'NVDA',
#   'PYPL',
#   'AAPL',
#   'AMAT',
#   'AVGO',
#   'COUP',
#   'MMM',
#   'MSFT',
#   'AMAT',
#   'COUP',
#   'INTC',
#   'KLAC',
#   'MSFT',
#   'NFLX',
#   'VMC',
#   'STZ',
#   'RDS-B',
#   'PYPL',
#   'MAR',
#   'KLAC',
#   'FB',
#   'AVGO',
#   'VMC',
#   'TRIP',
#   'MAR',
#   'GOOG',
#   'FB',
#   'CAT',
#   'AMZN',
#   'AMAT',
#   'NVDA',
#   'DIS',
#   'DIS',
#   'DIS',
#   'DIS',
#   'AMZN',
#   'BERY',
#   'TRIP',
#   'MAR',
#   'VAC',
#   'NVDA',
#   'VAC',
#   'GOOG',
#   'PYPL',
#   'FB',
#   'UBER',
#   'UBER',
#   'AMZN',
#   'QSR',
#   'MCD',
#   'DPZ',
#   'BYND',
#   'STZ',
#   'MTCH',
#   'BLL',
#   'BRY',
#   'GE',
#   'AMAT',
#   'DIS',
#   'DNKN',
#   'F',
#   'GOOG',
#   'KLAC',
#   'SBUX',
#   'T',
#   'VMC',
#   'AMZN',
#   'TEL',
#   'JCI',
#   'C',
#   'CRWD',
#   'PYPL',
#   'CRWD',
#   'NVDA',
#   'AMZN',
#   'UPS',
#   'GOOG',
#   'QSR',
#   'GRUB',
#   'GOOG',
#   'IRBT',
#   'DNKN',
#   'SBUX',
#   'RDS-B',
#   'T',
#   'CSCO',
#   'AMAT',
#   'KLAC',
#   'AVGO',
#   'XOM',
#   'V',
#   'CAT',
#   'AMZN',
#   'DIS'],
#  'McConnell, Mitch': ['WFC',
#   'WFC',
#   '--',
#   'WFC',
#   'WFC',
#   'WFC',
#   'WFC',
#   'WFC',
#   'WFC',
#   'WFC',
#   'WFC',
#   'VMC',
#   'IR',
#   'WFC',
#   'WFC',
#   'WFC',
#   'WFC',
#   'WFC',
#   'WFC',
#   'WFC',
#   '--',
#   '--',
#   '--'],
#  'Capito, Shelley': ['NEE',
#   'MSFT',
#   'LHX',
#   'LOW',
#   'AAPL',
#   'NVS',
#   'VZ',
#   'AAPL',
#   'MSFT',
#   'AAPL',
#   'RDSA',
#   'MSFT',
#   'IBM',
#   'INTC',
#   'C',
#   'USB',
#   'JPM',
#   'AAPL',
#   '--',
#   'WFC',
#   'T',
#   'WFC',
#   'UBSI',
#   'USB',
#   'JPM',
#   'BLK',
#   'WFC',
#   'C',
#   'UNH',
#   'PSX',
#   'AMT',
#   'SYY',
#   'PII',
#   'OTIS',
#   'XOM',
#   'CLX',
#   'CARR',
#   'WFC',
#   'WFC',
#   'RTN',
#   'JPM',
#   'MSFT',
#   'JNJ',
#   'ABT',
#   'TFC',
#   'CMCSA',
#   'C',
#   'MSFT',
#   'RDSA.AS',
#   'MSFT',
#   'INTC',
#   'HBAN',
#   'XOM',
#   'C',
#   'NSC',
#   'C',
#   'WFC',
#   'WFC',
#   'V',
#   'TSM',
#   'SFTBY',
#   'SRE',
#   'RDS-B',
#   'SLB',
#   'RBGLY',
#   'PM',
#   'PDRDY',
#   'AVGO',
#   'LRLCY',
#   'NVO',
#   'MRAAY',
#   'NSRGY',
#   'NPSNY',
#   'JPM',
#   'MCO',
#   'MDLZ',
#   'MSFT',
#   'LVS',
#   'KYCCF',
#   'ICE',
#   'INTC',
#   'SAFRY',
#   'HLT',
#   'GDDY',
#   'GILD',
#   'ESLOY',
#   'ENB',
#   'DEO',
#   'DE',
#   'DHR',
#   'CCI',
#   'CVX',
#   'CABGY',
#   'CSX',
#   'CME',
#   'BK',
#   'ASML',
#   'AZN',
#   'AHKSY',
#   'AAPL',
#   'AMT',
#   'AMZN',
#   'GOOG',
#   'EADSY',
#   'ATVI',
#   'AAGIY',
#   'KO',
#   'ANCX',
#   'GIS',
#   'PG',
#   'PEP',
#   '--',
#   'LIN',
#   '--',
#   'QCOM',
#   'IBM',
#   'INCY',
#   'SHECY',
#   'PX',
#   'JNJ',
#   'JPM',
#   'GILD',
#   'QCOM',
#   'WAB',
#   'ENB',
#   'BA',
#   'RCL',
#   'BNPQY',
#   '--',
#   'DWDP',
#   'ENB',
#   'PTEN',
#   'WEC',
#   'WMT',
#   'VFC',
#   'UTX',
#   'USB',
#   'MMM',
#   'TGT',
#   'SYY',
#   'QCOM',
#   'PG',
#   'PX',
#   'PII',
#   'PSX',
#   'PEP',
#   'PAYX',
#   'NVS',
#   'NSC',
#   'NKE',
#   'NEE',
#   'JPM',
#   'MSFT',
#   'MDT',
#   'MCD',
#   'LOW',
#   'JNJ',
#   'IBM.MX',
#   'ITW',
#   'HRS',
#   'GIS',
#   'GD',
#   'FDS',
#   'XOM',
#   'ES',
#   'EMR',
#   'EV',
#   'CL',
#   'CLX',
#   'CSCO',
#   'CB',
#   'CVX',
#   'BLK',
#   'BDX',
#   'ADP',
#   'ADI',
#   'AMGN',
#   'APD',
#   'ACN',
#   'ABT',
#   'T',
#   'AFL',
#   'VGK',
#   'UBSI',
#   'NSRGY',
#   'MS',
#   'LULU',
#   'IYE',
#   'KHC',
#   'RHHBY',
#   'CLB',
#   'CHK',
#   'CME',
#   'BRK-B',
#   'AL',
#   'WEC',
#   'WMT',
#   'VFC',
#   'UTX',
#   'USB',
#   'MMM',
#   'SYY',
#   'PX',
#   'PII',
#   'PSX',
#   'PEP',
#   'PAYX',
#   'NSC',
#   'NEE',
#   'JPM',
#   'MSFT',
#   'MDT',
#   'MCD',
#   'LOW',
#   'JNJ',
#   'ITW',
#   'HRS',
#   'GD',
#   'ES',
#   'EMR',
#   'CL',
#   'CLX',
#   'CSCO',
#   'CB',
#   'CVX',
#   'BLK',
#   'BDX',
#   'ADP',
#   'ADI',
#   'AMGN',
#   'APD',
#   'ACN',
#   'ABT',
#   'T',
#   'AFL',
#   'UBSI',
#   'MDLZ',
#   'FANUY',
#   'WFC',
#   'RHHBY',
#   'STT',
#   'MDLZ',
#   'ICE',
#   'OXY',
#   'CERN',
#   'BUD',
#   'GWW',
#   'GE',
#   'RDS-A',
#   'PG',
#   'NSC',
#   'MSFT',
#   'MRK',
#   'IBM',
#   'INTC',
#   'XOM',
#   'KO',
#   'C',
#   'CSCO',
#   'BMY',
#   'SLB',
#   'RYAAY',
#   'INTC',
#   'HXL',
#   'FANUY',
#   'DWDP',
#   'GDDY',
#   'CSX',
#   'ENB',
#   'SGAPY',
#   'SSDOY',
#   'MRK',
#   'BMY',
#   'C',
#   'GILD',
#   '--',
#   'JPM',
#   'ACN',
#   'SJM',
#   'TD',
#   'SIEGY',
#   'PM',
#   'PFE',
#   'NVS',
#   'NEE',
#   'NSRGY',
#   'MSFT',
#   'MRK',
#   'LMT',
#   'LVMUY',
#   'INTC',
#   'RHHBY',
#   'XOM',
#   'CMPGY',
#   'CSCO',
#   'BASFY',
#   'AXAHY',
#   'T',
#   'K',
#   'HLT',
#   'WEC',
#   'V',
#   'VTKLY',
#   'TSM',
#   'SFTBY',
#   'SGAPY',
#   'SSDOY',
#   'RDS-B',
#   'SMECF',
#   'RCL',
#   'RBGLY',
#   'PDRDY',
#   'AVGO',
#   'LRLCY',
#   'OXY',
#   'NVO',
#   'MRAAY',
#   'NSRGY',
#   'NPSND',
#   'JPM',
#   'MCO',
#   'LVS',
#   'KYCCF',
#   'INCY',
#   '--',
#   'RHHBY',
#   'HXL',
#   'JKHY',
#   'FANUY',
#   'ENB',
#   'ETN',
#   'CCI',
#   'CVX',
#   'CERN',
#   'CABGY',
#   'CME',
#   'BNPQY',
#   'ASML',
#   'AZN',
#   '--',
#   'AHKSY',
#   '--',
#   'AMT',
#   '--',
#   '--',
#   '--',
#   'ANCX',
#   '--',
#   'CSCO',
#   'SCG',
#   'SO',
#   '--',
#   'AEX.MU',
#   '--',
#   'WFC',
#   'C',
#   'WFC',
#   'USB',
#   'JWN',
#   'BRK-B',
#   'F',
#   'VFC',
#   'UTX',
#   'MMM',
#   'PAYX',
#   'NEE',
#   'MSFT',
#   'MDT',
#   'LOW',
#   'JNJ',
#   'SJM',
#   'ITW',
#   'GD',
#   'CLX',
#   'CB',
#   'BDX',
#   'ABT',
#   'AAPL',
#   'COP',
#   'NKE',
#   'CB',
#   '--',
#   '--',
#   '--',
#   'ABT'],
#  'Toomey, Pat': ['--',
#   '--',
#   'SPG',
#   'PENN',
#   'GME',
#   'SHOP',
#   'GME',
#   'TSLA',
#   'AIV',
#   'NTRP',
#   'NTRP',
#   'AIV',
#   'TSLA',
#   'AAPL',
#   '--',
#   'NKLA',
#   'NKLA',
#   'TSLA',
#   'TSLA',
#   '--',
#   'PPL',
#   'GE',
#   'ET',
#   'NDAQ',
#   'NDAQ',
#   'ET',
#   'ETP',
#   'MPLX',
#   'REVB',
#   'TBT',
#   'TBT',
#   'GE',
#   'CAPL',
#   'CAPL',
#   'PG',
#   'REVB',
#   'GLD',
#   'REVB',
#   'REVB',
#   '--',
#   'BOX',
#   'BOX',
#   'REVB',
#   'BOX',
#   'REVB',
#   'NTRP',
#   'REVB',
#   'PFS',
#   'REVB',
#   'PFS',
#   'REVB',
#   'REVB',
#   'BAC',
#   'PFS',
#   'REVB',
#   'PFS',
#   'REVB',
#   'GE',
#   'MPLX',
#   '^MWE',
#   'ETP',
#   '^RGP',
#   'GE',
#   'REVB',
#   'REVB',
#   'REVB',
#   'PHLD',
#   'PEY',
#   'T',
#   'GE',
#   'SPY',
#   'GE',
#   'VZ',
#   'XEL',
#   'TRV',
#   'DD',
#   'VZ',
#   'NEE-PC',
#   'T',
#   'BAC',
#   '--',
#   'PFS',
#   'PEY',
#   'BUNT',
#   'CVX',
#   'PG',
#   '--',
#   'MTUM',
#   'SHY',
#   'PG',
#   '--',
#   'SPY',
#   'SPY160219P00180000',
#   'SPY160219P00180000',
#   'SPY160219P00180000',
#   '--',
#   'EEM',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   'PFS',
#   'CVX',
#   'PFS',
#   'PFS',
#   'PFS',
#   'PFS',
#   'BUNT-RP',
#   'VZ',
#   'CVX',
#   'PFS',
#   'PFS',
#   'PFS',
#   'IBKC',
#   'IBKC',
#   'PG',
#   'PFS',
#   'PFS',
#   'CVX',
#   'CVX',
#   'LINE',
#   'PFS',
#   'T',
#   'ESV',
#   'EEM',
#   'XLU',
#   'XLV',
#   'XLU',
#   'QQQ',
#   'SPY',
#   'SHY',
#   'PCY'],
#  'Warner, Mark': ['ROAD',
#   'ROAD',
#   'ZAYO',
#   'ZAYO',
#   'CHTR',
#   'HALO',
#   'XON',
#   'ZIOP'],
#  'Collins, Susan': ['UL',
#   'WEX',
#   'VFC',
#   'OTIS',
#   'HSIC',
#   'CARR',
#   'MMM',
#   'HSY',
#   'NVDA',
#   'LIN',
#   'AMZN',
#   'DNKN',
#   'CVET',
#   'AKAM',
#   'RHT',
#   'WEX',
#   'LIN',
#   'FB',
#   'XOM',
#   'ENB',
#   'CFR',
#   'STZ',
#   'NEE',
#   'AON',
#   'SBUX',
#   'PX',
#   'HON',
#   'TJX',
#   'AMZN',
#   'NSRGY',
#   'UNH',
#   'SLB',
#   'PFE',
#   'PEP',
#   'NSRGY',
#   'CMCSA',
#   'UNH',
#   'TMO',
#   'MRK',
#   'STZ',
#   'JPM',
#   'USB',
#   'HOLX',
#   'ENB',
#   'TSCO',
#   'RHT',
#   'AYI',
#   'SNA',
#   'CFR',
#   'CVS',
#   'FB',
#   'AME',
#   'RHHBY',
#   'GILD',
#   'DHR',
#   'BRKB',
#   'PRGO',
#   'ESRX',
#   'VZ',
#   'SRCL',
#   'GOOG',
#   'COP',
#   'TSCO',
#   'TMK',
#   'MTD',
#   'HOLX',
#   'AWK',
#   'WFC',
#   'USB',
#   'TMK',
#   'RHT',
#   'FTV',
#   'HSY',
#   'BIN',
#   'WCN',
#   'DD',
#   'PX',
#   'SRCL',
#   'RHT',
#   '--',
#   '--',
#   '--',
#   '--',
#   'EMC',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   'KMB',
#   'KMB',
#   'HAL',
#   'HAL',
#   'HAL',
#   'HAL',
#   'AXP',
#   'AXP',
#   'AXP',
#   'AXP',
#   'AXP',
#   'HSY',
#   'AYI',
#   'MMM',
#   'WCN',
#   'UL',
#   'MTD',
#   'CVS',
#   'ADP',
#   'AAPL',
#   'AXP',
#   'TOLLX',
#   'TOLLX',
#   'WASCX',
#   'MDDVX',
#   'MDDVX',
#   'DVFAX',
#   'DVFAX'],
#  'Moran, Jerry': ['USB',
#   'MSFT',
#   'GILD',
#   'XOM',
#   'CVS',
#   'BRK.B',
#   'BAC',
#   'AAPL',
#   'PII',
#   'PFE',
#   'KMB',
#   'CMCSA',
#   'CSCO',
#   'CI',
#   'BK',
#   'USB',
#   'MSFT',
#   'KR',
#   'GILD',
#   'FB',
#   'XOM',
#   'DVA',
#   'CVS',
#   'BRK.B',
#   'BAC',
#   'AAPL',
#   'GOOG',
#   'VZ',
#   'PII',
#   'PFE',
#   'KMB',
#   'CMCSA',
#   'CSCO',
#   'CI',
#   'BK',
#   'VZ',
#   'COST',
#   'COST',
#   'WFC',
#   'DIS',
#   'V',
#   'TXN',
#   'JPM',
#   'KO',
#   'AAPL',
#   'ALL',
#   'ABBV',
#   'KR',
#   'CVX',
#   'BRK-B',
#   'WFC',
#   'DIS',
#   'V',
#   'TXN',
#   'RDS-B',
#   'OXY',
#   'MPC',
#   'JPM',
#   'COST',
#   'KO',
#   'BRK-B',
#   'AAPL',
#   'ALL',
#   'ABBV',
#   'KR',
#   'USB',
#   'JNJ',
#   'INTC',
#   'GILD',
#   'CVS',
#   'CVX',
#   'BAC',
#   'VWO',
#   'HAL',
#   'XOM',
#   'BRK-B',
#   'WFC',
#   'DIS',
#   '3V64.TI',
#   'VZ',
#   'TXN',
#   'JNK',
#   'OXY',
#   'MPC',
#   'JNJ',
#   'INTC',
#   'GILD',
#   'GIS',
#   '0QZI.IL',
#   'XOM',
#   'COST',
#   'KO',
#   'AAPL',
#   'WFC',
#   'DIS',
#   '3V64.TI',
#   'VZ',
#   'USB',
#   'TXN',
#   'JNK',
#   'OXY',
#   'MSFT',
#   'MPC',
#   'JNJ',
#   'INTC',
#   'GILD',
#   'GIS',
#   '0QZI.IL',
#   'XOM',
#   'CVS',
#   'COST',
#   'KO',
#   'BRK-B',
#   'BAC',
#   'AAPL',
#   'AMZN',
#   'WY',
#   'LM09.SG',
#   'GS',
#   'GOOG',
#   'GIS',
#   'CVS',
#   'COST',
#   'BAC',
#   'AAPL',
#   'ALL',
#   'WY',
#   'WFC',
#   'VZ',
#   'USB',
#   'RDS-B',
#   'MSFT',
#   'LM09.SG',
#   'JPM',
#   'GS',
#   'XOM',
#   'DIS',
#   'DVA',
#   'COST',
#   'AAPL',
#   'BRK-B',
#   'GOOG',
#   'ABBV',
#   'WY',
#   'WFC',
#   'RDS-B',
#   'LM09.SG',
#   'JPM',
#   'GS',
#   'XOM',
#   'GIS',
#   'CVS',
#   'COST',
#   'BAC',
#   'AAPL',
#   '--',
#   'PFE',
#   'WY',
#   'WFC',
#   '--',
#   'USB',
#   'RDS-B',
#   'MSFT',
#   'LM09.SG',
#   'JPM',
#   'GS',
#   'XOM',
#   'DIS',
#   'DVA',
#   'COST',
#   'BRKB',
#   'AAPL',
#   'GOOG',
#   'ABBV'],
#  'Thune, John': ['IRT'],
#  'Hickenlooper, John': ['PYPL',
#   'NVDA',
#   'MSFT',
#   'FB',
#   'AAPL',
#   'AMZN',
#   'GOOGL',
#   'TTD',
#   'CVX',
#   'PINS',
#   'SNAP',
#   'OGN',
#   'MRK',
#   'NOK',
#   'CMG',
#   'QRTEA',
#   'TTD',
#   'PTON',
#   'CARG',
#   'DGNR',
#   'LMACU'],
#  'Rosen, Jacky': ['DELL', 'PFE', 'IR', 'VFC', 'APC', 'NVS'],
#  'Peters, Gary': ['CAG',
#   'OFC',
#   '--',
#   'O',
#   'VPU',
#   '--',
#   'STAG',
#   'AEP',
#   'AEP',
#   '--',
#   'TFC',
#   'TOT',
#   'SHW',
#   'GIS',
#   'GE',
#   'T',
#   'SHW',
#   'DWDP',
#   'DWDP',
#   'CVS',
#   'OFC',
#   'MAT',
#   'ARCC',
#   'BHF',
#   'VSM',
#   'MCC',
#   'ARCC',
#   'SPG',
#   'MPW',
#   'SPG',
#   'CVS',
#   'CVS',
#   'CPGX',
#   'IVZ',
#   'WPC',
#   'NUE',
#   '--',
#   '--',
#   '--',
#   '--',
#   'IVZ',
#   'ABBV',
#   'T',
#   'PFE',
#   'MMC',
#   'UNP',
#   'GM',
#   'STAG',
#   'UTX',
#   'KRFT',
#   'DTE',
#   'QCOM',
#   'EMR',
#   '--',
#   'MDT'],
#  'Blunt, Roy': ['--', 'NRDY', 'KHC', 'MDLZ', '--', '--'],
#  'Lummis, Cynthia': ['J'],
#  'Whitehouse, Sheldon': ['BABA',
#   'MCHP',
#   'T',
#   'FTV',
#   'CB',
#   'TT',
#   'TT',
#   'IBM',
#   'IBM',
#   '--',
#   '--',
#   'ILMN',
#   'CGNX',
#   'SIEGY',
#   'WM',
#   'DLR',
#   'IBM',
#   'TSLA',
#   'CVS',
#   'T',
#   'TSLA',
#   'NSRGY',
#   'KO',
#   'NVDA',
#   'CVS',
#   'INTC',
#   'PGR',
#   'TEL',
#   'MCD',
#   'VZ',
#   'SIEGY',
#   'T',
#   'SQ',
#   'CGNX',
#   'INTC',
#   'BA',
#   'BIIB',
#   'BA',
#   'NFLX',
#   'T',
#   'FB',
#   'NSRGY',
#   'PEP',
#   'PG',
#   'HAS',
#   'T',
#   'FB',
#   'GS',
#   'ETN',
#   'BUD',
#   'REZI',
#   'AMZN',
#   'F',
#   'NVDA',
#   'T',
#   'TSLA',
#   'BMY',
#   'C',
#   'BUD',
#   'REZI',
#   'AAPL',
#   'UNP',
#   'COF',
#   'ILMN',
#   'F',
#   'TSLA',
#   'SQ',
#   'F',
#   'KHC',
#   'IBM',
#   'IBM',
#   'AET',
#   'LRCX',
#   'NVDA',
#   'F',
#   'ON',
#   'GS',
#   'T',
#   'BABA',
#   'LRCX',
#   'WMT',
#   'WMT',
#   'T',
#   'BRK-B',
#   'GILD',
#   'MCHP',
#   'MCHP',
#   'WMT',
#   'PYPL',
#   'LRCX',
#   'GS',
#   'DAL',
#   'C',
#   'BA',
#   'BABA',
#   'KHC',
#   'BTO',
#   'T',
#   'ON',
#   'C',
#   'AMZN',
#   'CB',
#   'HD',
#   'MCD',
#   'F',
#   'ETN',
#   'BUD',
#   'ADI',
#   'IBM',
#   'TSLA',
#   'MGA',
#   'V',
#   'CVS',
#   'CMCSA',
#   'JPM',
#   'WPC',
#   'AAPL',
#   'FB',
#   'FB',
#   'FB',
#   'NVDA',
#   'C',
#   'C',
#   'WMT',
#   'BIIB',
#   'V',
#   'COST',
#   'GE',
#   'V',
#   'USB',
#   'NWL',
#   'NWL',
#   'DISH',
#   'JCI',
#   'REGN',
#   'JPM',
#   'GE',
#   'IBM',
#   'TMUS',
#   'TMUS',
#   'TSLA',
#   'MRK',
#   'WMT',
#   'QCOM',
#   'GILD',
#   'MCK',
#   'DISH',
#   'GILD',
#   'TJX',
#   'UNP',
#   'BHF',
#   'TSLA',
#   'AAPL',
#   'BHF',
#   'NWL',
#   'TSLA',
#   'DISH',
#   'SYK',
#   'WMT',
#   '--',
#   'C',
#   'HPQ',
#   'BTO',
#   'BMY',
#   'GS',
#   'COF',
#   'SBUX',
#   'TSLA',
#   'JCI',
#   'CSCO',
#   'LW',
#   'FTV',
#   'BIVV',
#   'BIVV',
#   'ADI',
#   'LB',
#   'C',
#   'CVS',
#   'F',
#   'MGA',
#   'DISH',
#   'MMC',
#   'WBA',
#   'TWTR',
#   'VEVIX',
#   'MA',
#   'ADI',
#   'BAC',
#   'LRCX',
#   'C',
#   'GS',
#   'WM',
#   'REGN',
#   'AKAM',
#   'TWTR',
#   'AMGN',
#   'IBM',
#   'F',
#   'MMM',
#   'MGA',
#   'NKE',
#   'QCOM',
#   'DISH',
#   'QCOM',
#   'LB',
#   'WPC',
#   'USB',
#   'LB',
#   'AMGN',
#   'IBM',
#   'LLTC',
#   'ADI',
#   'MCHP',
#   'CAG',
#   'GE',
#   'CVS',
#   'JCI',
#   'BMY',
#   'JPM',
#   'BUD',
#   'BRK-B',
#   'DISH',
#   'EL',
#   'MCK',
#   'ABT',
#   'BMY',
#   'DISH',
#   'ADI',
#   'PFE',
#   'MDT',
#   'NVDA',
#   'PANW',
#   'UNH',
#   'PANW',
#   'AAPL',
#   'NSRGY',
#   'TMUS',
#   'IR',
#   'BA',
#   'MO',
#   'LW',
#   'AAPL',
#   'IR',
#   'MO',
#   'USB',
#   'BRK-B',
#   'GS',
#   'GS',
#   'GILD',
#   'PSA',
#   'BIIB',
#   'BIIB',
#   'AMGN',
#   'GILD',
#   'ORCL',
#   'DIS',
#   'GILD',
#   'FB',
#   'AMGN',
#   'GILD',
#   'MCK',
#   'GOOGL',
#   'ABT',
#   'BA',
#   'DIS',
#   'SBUX',
#   'UL',
#   'JCI',
#   'GILD',
#   'ORCL',
#   'DEO',
#   'ASIX',
#   'ASIX',
#   'ASIX',
#   'HSBC',
#   'HAS',
#   'DIS',
#   'BRK-B',
#   'JPM',
#   'IBM',
#   'BRK-B',
#   'MCK',
#   'MA',
#   'CB',
#   'DEO',
#   'WFC',
#   'HAS',
#   'IBM',
#   'GILD',
#   'MAR',
#   'FB',
#   'NFLX',
#   'NSRGY',
#   '--',
#   'WEC',
#   'DIS',
#   'SO',
#   'EL',
#   'MCK',
#   'VOD',
#   'BA',
#   'AXP',
#   'WM',
#   'GILD',
#   'REGN',
#   'NFLX',
#   'NSRGY',
#   'PSA',
#   'MET',
#   'GE',
#   'TJX',
#   'SBUX',
#   'GILD',
#   'BMY',
#   'REGN',
#   'GILD',
#   'RYAAY',
#   'UA',
#   'FB',
#   'C',
#   'DHR',
#   'FB',
#   'WM',
#   'WM',
#   'ESRX',
#   'HAS',
#   'GILD',
#   'WM',
#   'FB',
#   'ESRX',
#   'HAS',
#   'GILD',
#   'AAPL',
#   'VFC',
#   'GILD',
#   'NFLX',
#   'CMCSA',
#   'FB',
#   'AMGN',
#   'PSA',
#   'ACN',
#   'IBM',
#   'NVDA',
#   'SBUX',
#   'VFC',
#   'NWL',
#   'DEO',
#   'CERN',
#   'REGN',
#   'CMCSA',
#   'FB',
#   'TWTR',
#   'IBM',
#   'NWL',
#   'AMZN',
#   'GOOGL',
#   'AMGN',
#   'TJX',
#   'GE',
#   'AMZN',
#   'NVDA',
#   'VMW',
#   'WBA',
#   'DIS',
#   'AAPL',
#   'STT',
#   'UA',
#   'NVDA',
#   'AAPL',
#   'LRCX',
#   'NWL',
#   'FB',
#   'MET',
#   'V',
#   'CVS',
#   'HOT',
#   'NWL',
#   'NWL',
#   'HD',
#   'CSCO',
#   'LRCX',
#   'FB',
#   'CP',
#   'CAT',
#   'BAC',
#   'NWL',
#   'FB',
#   'TWTR',
#   'TWTR',
#   'JPM',
#   'CP',
#   'IONS',
#   'LRCX',
#   'M',
#   'LMT',
#   'MSFT',
#   'GILD',
#   'GME',
#   'NVDA',
#   'NVDA',
#   'LRCX',
#   'CSCO',
#   'WMT',
#   'VZ',
#   'UA',
#   'NFLX',
#   'MRK',
#   'LLTC',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   'UTX',
#   'M',
#   'RTN',
#   'QCOM',
#   'BAC',
#   'PG',
#   'CSX',
#   'BIIB',
#   'QLIK',
#   'FB',
#   'VFC',
#   'GE',
#   'BIIB',
#   'KO',
#   'BIIB',
#   'BIIB',
#   'BIIB',
#   'WFC',
#   'VZ',
#   'NFLX',
#   'KLXI',
#   'KLXI',
#   'T',
#   'BIIB',
#   'LLTC',
#   'T',
#   'BIIB',
#   'MRK',
#   'GPRO',
#   'M',
#   'CY',
#   'TRIP',
#   'CHL',
#   'KORS',
#   'AMGN',
#   'BAC',
#   'CY',
#   'RTN',
#   'PCAR',
#   'PRU',
#   'FEYE',
#   'MRK',
#   'TU',
#   'NFLX',
#   'BIIB',
#   'GILD',
#   '--',
#   'BIIB',
#   'NFLX',
#   'SSYS',
#   'GILD',
#   'ACN',
#   'BABA',
#   'HD',
#   'UA',
#   'LLTC',
#   'KORS',
#   'BMY',
#   'HYH',
#   'KORS',
#   'PEP',
#   'CMRE',
#   'ABBV',
#   'AMGN',
#   'STT',
#   'KORS',
#   'A',
#   'DISH',
#   'ETN',
#   'DD',
#   'ETN',
#   'DHR',
#   'ACE',
#   'GILD',
#   'AIG',
#   'KLXI'],
#  'Paul, Rand': ['--'],
#  'King, Angus': ['TMO',
#   'ADBE',
#   'VZ',
#   'SLB',
#   'XOM',
#   'COP',
#   'WAT',
#   'CMCSA',
#   'AMZN',
#   'UTX',
#   'MKC',
#   'AXP',
#   'SLB',
#   'NKE',
#   'CB',
#   'GILD',
#   'SLB',
#   'COP',
#   'PG',
#   'NVS',
#   'CSCO',
#   'IBM',
#   'DIS',
#   'TGT',
#   'TEVA',
#   'GE',
#   'EMC',
#   'CB',
#   '--',
#   'KMI',
#   '--',
#   '--'],
#  'Boozman, John': ['IWM', '--'],
#  'Duckworth, Tammy': ['VZ',
#   'ITW',
#   'DIS',
#   'WBA',
#   'MDLZ',
#   'GE',
#   'DWDP',
#   'BBL',
#   'GS',
#   'SOUHY',
#   'DWDP',
#   'ABT',
#   'JNJ',
#   'CC',
#   'INTC',
#   'DVMT',
#   'MCD',
#   'NEE',
#   'CAT',
#   'GME',
#   'CAT',
#   'POT'],
#  'Sullivan, Dan': ['RPM',
#   'RPM',
#   'RPM',
#   'RPM',
#   'RPM',
#   'RPM',
#   'RPM',
#   'RPM',
#   'RPM',
#   'RPM'],
#  'Inhofe, Jim': ['CRSP',
#   'CRSP',
#   'BLK',
#   'AAPL',
#   'AMZN',
#   'BAM',
#   'V',
#   'MSFT',
#   'BAM',
#   'C',
#   'BAM',
#   'PYPL',
#   'INTU',
#   'DHR',
#   'BAM',
#   'AAPL',
#   'PG',
#   'BFAM',
#   'UNH',
#   'XBI',
#   'AIG',
#   'PYPL',
#   'ISRG',
#   '--',
#   '--',
#   'TEL',
#   'LH',
#   'CLR',
#   'DHR',
#   'EDIT',
#   'MSFT',
#   'DAL',
#   'KMX',
#   'BABA',
#   'ALB',
#   'V',
#   'AMZN',
#   'MRK',
#   'XBI',
#   'CELG',
#   'TEL',
#   'APTV',
#   'XPO',
#   'RTN',
#   'CELG',
#   'APTV',
#   'AIG',
#   'GE',
#   'XPO',
#   'ISRG',
#   'NTLA',
#   'ALB',
#   'CRM',
#   'GE',
#   'GOOGL',
#   'LEA',
#   'APTV',
#   'XPO',
#   'INTU',
#   'BKNG',
#   'DHR',
#   'BAM',
#   'BFAM',
#   '--',
#   'CELG',
#   'RSPP',
#   'ST',
#   'LEA',
#   'APTV',
#   'CRSP',
#   'BMY',
#   'CLR',
#   'V',
#   'UNH',
#   'CRM',
#   'PEP',
#   'MSFT',
#   'LH',
#   'XOM',
#   'DFS',
#   'DAL',
#   'CLR',
#   'COHR',
#   'C',
#   'KMX',
#   'BAM',
#   'BLK',
#   'GOOGL',
#   'AAPL',
#   'CHKP',
#   'BLK',
#   'XPO',
#   'GILD',
#   'CELG',
#   'AGN',
#   'MSFT',
#   'KMX',
#   'KMX',
#   'BUD',
#   'DAL',
#   'UNH',
#   'PCLN',
#   'XOM',
#   'XON',
#   'PYPL',
#   'HBI',
#   'GE',
#   'BABA',
#   'NTLA',
#   'EDIT',
#   'CRSP',
#   'BLK',
#   'DIS',
#   'COHR',
#   'CVS',
#   'CVS',
#   'GM',
#   'COHR',
#   'XON',
#   'FLR',
#   'GE',
#   'MSFT',
#   'C',
#   'RSPP',
#   'NFX',
#   'UL',
#   'ST',
#   'UNH',
#   'JNJ',
#   'BFAM',
#   'AMGN',
#   'UL',
#   'FLR',
#   'CRM',
#   'HBI',
#   'GE',
#   'GM',
#   'SYF',
#   'BMY',
#   'XON',
#   'AGN',
#   'CERN',
#   'SYF',
#   'BMY',
#   'CHKP',
#   'WFC',
#   'UL',
#   'ARW',
#   'BUD',
#   'GILD',
#   '--',
#   'CERN',
#   'CTSH',
#   'DIS',
#   'A',
#   'AGN',
#   'CSX',
#   'AGN',
#   'PRGO',
#   'BBU',
#   'ESRX',
#   'C',
#   'BMY',
#   'BLK',
#   'BIIB',
#   'AGN',
#   'NFX',
#   'CLR',
#   'PRGO',
#   'BABA',
#   'PG',
#   'CLR',
#   'SYF',
#   'C',
#   'RRC',
#   'NFX',
#   'CTSH',
#   'SWN',
#   'SYF',
#   'GILD',
#   'CLR',
#   'ITC',
#   'CHK',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   'COF',
#   'RSPP',
#   'CHK',
#   'CLR',
#   'AAPL',
#   'A',
#   'EMR',
#   'ARW',
#   'MRK',
#   'DISCK',
#   'QCOM',
#   'CLR',
#   'FANG',
#   'MSACX',
#   'VADDX',
#   'NGIPX',
#   'WSTMX',
#   'VMIIX',
#   'VSMIX',
#   'ACSDX',
#   'MGEMX',
#   'BIIB',
#   'CLR',
#   'GE',
#   'PCLN',
#   'MRK',
#   'ITC',
#   'ABT',
#   'NGIPX',
#   'GILD',
#   'CLR',
#   'ALTR',
#   'PG',
#   'AMZN',
#   'EMR',
#   'WFC',
#   'ETN',
#   'MCD'],
#  'Roberts, Pat': ['BA',
#   'PLUG',
#   'SQ',
#   'BA',
#   'NVDA',
#   'EXPI',
#   'ETY',
#   'W',
#   'TSLA',
#   'TSLA',
#   'BA',
#   'TSLA',
#   'BA',
#   'COST',
#   'AAPL',
#   'AAPL',
#   'ZM',
#   'BA',
#   'V',
#   'COST',
#   'COST',
#   'BA',
#   '--',
#   'NVDA',
#   'W',
#   'DAL',
#   '--',
#   'DIS',
#   '--',
#   '--',
#   '--',
#   'BBY',
#   'NVAX',
#   'BA',
#   'WMT',
#   'AAPL',
#   'NVDA',
#   'AAPL',
#   'AAPL',
#   'NVDA',
#   'NFLX',
#   'NVDA',
#   'NFLX',
#   'BYND',
#   'NVDA',
#   'AAPL',
#   'AAPL',
#   'TSLA',
#   'NVDA',
#   'W',
#   'AAPL',
#   'ZM',
#   'MSFT',
#   'MSFT',
#   'AAPL',
#   'AAPL',
#   'BA',
#   'WMT',
#   'GOLD',
#   'BBY',
#   'GLD',
#   'NVAX',
#   'AAPL',
#   'TSLA',
#   'AAPL',
#   'AAPL',
#   'TGT',
#   'AAL',
#   'NOC',
#   'AAL',
#   'BA',
#   'MA',
#   'BA',
#   'NFLX',
#   'NFLX',
#   'AAL',
#   'BABA',
#   'WMT',
#   'SPOT',
#   'BYND',
#   'AMZN',
#   'AAL',
#   'AAL',
#   'BA',
#   'AAL',
#   'BA',
#   'NFLX',
#   'AAPL',
#   'DIS',
#   'TJX',
#   'NFLX',
#   'TJX',
#   '--',
#   'MSFT',
#   'MA',
#   'BYND',
#   '--',
#   'MSFT',
#   'AAPL',
#   'NVDA',
#   'NFLX',
#   'AAPL',
#   'AMZN',
#   'AMZN',
#   'NFLX',
#   'NFLX',
#   'NFLX',
#   'MSFT',
#   'MSFT',
#   'DIS',
#   'XOM',
#   'CVX',
#   'BA',
#   'WMT',
#   'AAPL',
#   '--',
#   'V',
#   'WMT',
#   'NFLX',
#   'NVDA',
#   'NFLX',
#   'AAPL',
#   'NFLX',
#   'NVDA',
#   'AAPL',
#   'AAPL',
#   'NFLX',
#   'WMT',
#   'NVDA',
#   'MSFT',
#   'MA',
#   'KSS',
#   'NFLX',
#   'AMZN',
#   'NFLX',
#   'MA',
#   'NVDA',
#   'AMZN',
#   'ETY',
#   'BABA',
#   'NFLX',
#   'MA',
#   'NOC',
#   'NOC',
#   'DIS',
#   'MSFT',
#   'KTB',
#   'KTB',
#   'AMZN',
#   'MA',
#   'AAPL',
#   'NVDA',
#   'NFLX',
#   'NFLX',
#   'AAPL',
#   'CELG',
#   'NFLX',
#   'AMZN',
#   'WMT',
#   'FB',
#   'NOC',
#   'TGT',
#   'NOC',
#   'WMT',
#   'FB',
#   'KSS',
#   '--',
#   'NOC',
#   'NOC',
#   'AAPL',
#   'NVDA',
#   'NOC',
#   'NFLX',
#   'AAPL',
#   'AMZN',
#   'FB',
#   '--',
#   'XOM',
#   'DVN',
#   'NFLX',
#   'NOC',
#   'NVDA',
#   'AAPL',
#   'AMZN',
#   'JPM',
#   'BA',
#   'FB',
#   'NOC',
#   'BAC',
#   'TGT',
#   'BAC',
#   'TGT',
#   'BAC',
#   'AMZN',
#   'NFLX',
#   'CVX',
#   'NFLX',
#   'AMZN',
#   '--',
#   'BAC',
#   'NVDA',
#   'CVX',
#   'NFLX',
#   'NFLX',
#   'NFLX',
#   'WMT',
#   'FB',
#   'WMT',
#   'FB',
#   'AMZN',
#   'FB',
#   'ETY',
#   'NFLX',
#   'BA',
#   'BAC',
#   'BAC',
#   'RTN',
#   'NFLX',
#   'BA',
#   'ETY',
#   'AAPL',
#   'AMZN',
#   'NVDA',
#   'NOC',
#   'LMT',
#   'AAPL',
#   'NVDA',
#   'NOC',
#   'COST',
#   'AMZN',
#   'DVN',
#   '--',
#   'AMZN',
#   'CELG',
#   'BAC',
#   'LMT',
#   'JPM',
#   'ETY',
#   'BAC',
#   'SBUX',
#   'ETY',
#   'ETY',
#   'ETY',
#   'ETY',
#   'NVDA',
#   'NVDA',
#   'DVN',
#   'NVDA',
#   'TJX',
#   'XOM',
#   '--',
#   'CVX',
#   'AMZN',
#   'AAPL',
#   'TJX',
#   'NFLX',
#   'NFLX',
#   'BA',
#   'RTN',
#   'NVDA',
#   'NOC',
#   'AAPL',
#   '--',
#   'SBUX',
#   'GE',
#   'COF',
#   'WF',
#   'T',
#   'BAC',
#   'BAC',
#   'CELG',
#   'TCS',
#   'BIDU',
#   'FB',
#   'NVDA',
#   'NFLX',
#   '--',
#   'COF',
#   'FB',
#   'BA',
#   'RTN',
#   '--',
#   'SBUX',
#   'GE',
#   'COF',
#   'WF',
#   'T',
#   'BAC',
#   'BAC',
#   'CELG',
#   'TCS',
#   '--',
#   'NOC',
#   'TCS',
#   'BIDU',
#   'DVN',
#   '--',
#   'BAC',
#   'SBUX',
#   '--',
#   'WF',
#   'COF',
#   'CELG',
#   'SBUX',
#   'BIDU',
#   'NFLX',
#   'BAC',
#   'NFLX',
#   'BIDU',
#   'BAC',
#   'TJX',
#   '--',
#   'FB',
#   '--',
#   'T',
#   'ZNGA.SW',
#   'AMZN',
#   'AAPL',
#   'NFLX',
#   'AAPL',
#   'AAPL',
#   '--',
#   '--',
#   'T',
#   'SBUX',
#   'NFLX',
#   '--',
#   'FB',
#   'TJX',
#   'NOC',
#   '--',
#   'BA',
#   'FB',
#   'BAC',
#   'CVX',
#   'NFLX',
#   'ZNGA',
#   'AAPL',
#   'TJX',
#   'NOC',
#   'COST',
#   'HDS',
#   'COST',
#   'COST',
#   'HD',
#   'FB',
#   'FB',
#   'HDS',
#   'NFLX',
#   'FB',
#   'ZNGA',
#   'GM',
#   'GE',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   'BIDU',
#   'AAPL',
#   'AAPL',
#   'SBUX.SW',
#   'CELG',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   'AAPL',
#   'CVX',
#   'NFLX',
#   'NFLX',
#   'BA',
#   'COST',
#   'AAPL',
#   'DVN',
#   'CVX',
#   'NFLX',
#   'BABA',
#   'BIDU',
#   'AAPL',
#   'BA',
#   'BA',
#   'ETY',
#   'ETY',
#   'ETY',
#   'BABA',
#   'AAPL',
#   'BA',
#   'AMZN',
#   'SBUX',
#   'COST',
#   'ETY',
#   'DVN',
#   'MIK',
#   'GM',
#   'CELG',
#   'ZNGA',
#   'BIDU',
#   'AAPL',
#   'NFLX',
#   'TCS',
#   'NFLX',
#   'TCS',
#   'TWTR',
#   'XOM',
#   'BA',
#   'BAC',
#   'MIK'],
#  'Cassidy, Bill': ['WMT',
#   'UPS',
#   'SBUX',
#   'PLD',
#   'PG',
#   'JPM',
#   'MSFT',
#   'MDT',
#   'LOW',
#   'IBM',
#   'DOW',
#   'DIS',
#   'CMCSA',
#   'CSCO',
#   'CVS',
#   'BLK',
#   'AAPL',
#   'AMGN',
#   'AAPL',
#   'SBUX',
#   'MSFT',
#   'LOW',
#   'IBM',
#   'DIS',
#   'CMCSA',
#   'CSCO',
#   'AAPL',
#   'TROW',
#   'PLD',
#   'WMT',
#   'TROW',
#   'PG',
#   'MSFT',
#   'MDT',
#   'EMR',
#   'BLK',
#   'AAPL',
#   'AMGN',
#   'T',
#   'VFC',
#   'PSX',
#   'MMM',
#   'JNJ',
#   'DOW',
#   'DD',
#   'WMT',
#   'SBUX',
#   'PG',
#   'NVS',
#   'JPM',
#   'MSFT',
#   'MDT',
#   'FRT',
#   'XOM',
#   'DIS',
#   'CMCSA',
#   'CSCO',
#   'CVS',
#   'AAPL',
#   'AMGN',
#   'NVS',
#   'PPG',
#   'NVS',
#   'MDT',
#   'XOM',
#   'DWDP',
#   'DIS',
#   'CMCSA',
#   'CSCO',
#   'CVS',
#   'AAPL',
#   'TROW',
#   'VFC',
#   'UPS',
#   'SBUX',
#   'PG',
#   'MSFT',
#   'MDT',
#   'LOW',
#   'IBM',
#   'GWW',
#   'XOM',
#   'EMR',
#   'CMCSA',
#   'CSCO',
#   'CVS',
#   'BLK',
#   'AFL',
#   'AAPL',
#   'IHE',
#   'AAPL',
#   'SLB',
#   'QCOM',
#   'XOM',
#   'IBM',
#   'DIS',
#   'CVS',
#   'T',
#   'ABT',
#   'MDT',
#   'TGT',
#   'AAPL',
#   'FRT',
#   'TGT',
#   'SO',
#   'LOW',
#   'AMT',
#   '--',
#   'CVX',
#   'QCOM',
#   'PX',
#   'NSC',
#   'JNJ',
#   'EV',
#   'VFC',
#   'PPG',
#   'LOW',
#   'GWW',
#   'CVS',
#   'AMGN',
#   'WMT',
#   'SO',
#   'PG',
#   'T',
#   'TM',
#   'RDS-B',
#   'SLB',
#   'OXY',
#   'F',
#   'XOM',
#   'CMI',
#   'CVX',
#   'CTL',
#   'CAT',
#   'AMT',
#   'T',
#   'YACKX',
#   'WMT',
#   'VFC',
#   'UTX',
#   'SO',
#   'QCOM',
#   'PG',
#   'PX',
#   'NVS',
#   'NSC',
#   'LOW',
#   'MSFT',
#   'JNJ',
#   'EMR',
#   'EV',
#   'DIS',
#   'CSCO',
#   'BLK',
#   'ABT',
#   'AFL',
#   'COP',
#   'SLB',
#   'INTC',
#   'CMI',
#   'AAPL',
#   'IHE',
#   'CAT',
#   'OXY',
#   'NBL'],
#  'Loeffler, Kelly': ['ICE',
#   'ICE',
#   'ICE',
#   'ICE',
#   'PRU',
#   'TEX',
#   'TGT',
#   'STT',
#   'SLB',
#   'KHC',
#   'HIG',
#   'DFS',
#   'CL',
#   'CAT',
#   'BMY',
#   'BP',
#   'AMAT',
#   'AA',
#   'UTX',
#   'STT',
#   'PRU',
#   'K',
#   'HIG',
#   'GS',
#   'XOM',
#   'DD',
#   'DOW',
#   'DFS',
#   'DAL',
#   'CVS',
#   'CTVA',
#   'CL',
#   'CTSH',
#   'CSCO',
#   'BMY',
#   'BP',
#   'AIG',
#   'MO',
#   'AGN',
#   'ABBV',
#   'AGCO',
#   'MPC',
#   'EBAY',
#   'VZ',
#   'CTXS',
#   'PFE',
#   'AAPL',
#   'C',
#   'PRU',
#   'CSCO',
#   'WMT',
#   'PYPL',
#   'KMI',
#   'T',
#   'MDLZ',
#   'FDX',
#   'LOW',
#   'TFC',
#   'SAP',
#   'DOCU',
#   'LMT',
#   'DIS',
#   'AMGN',
#   'BAC',
#   'STZ',
#   'JD',
#   'KEY',
#   'ORCL',
#   'DG',
#   'DG',
#   'CME',
#   'FIS',
#   'WDC',
#   'VMC',
#   'UL',
#   'TRV',
#   'TRV',
#   'TRV',
#   'TJX',
#   'RTX',
#   'PRU',
#   'PRU',
#   'PGR',
#   'PG',
#   'PANW',
#   'NNVC',
#   'MRK',
#   'LLY',
#   'KO',
#   'K',
#   'K',
#   'HIG',
#   'HIG',
#   'GS',
#   'GLNCY',
#   'ETN',
#   'EMR',
#   'EMR',
#   'EMR',
#   'DIS',
#   'DFS',
#   'DFS',
#   'DD',
#   'DD',
#   'DD',
#   'DAL',
#   'DAL',
#   'DAL',
#   'CVX',
#   'CVX',
#   'CVX',
#   'CVS',
#   'CTSH',
#   'CTSH',
#   'CSCO',
#   'CSCO',
#   'CR',
#   'CR',
#   'CR',
#   'CMCSA',
#   'CMCSA',
#   'CL',
#   'CAT',
#   'CAT',
#   'CAH',
#   'CAH',
#   'BP',
#   'BP',
#   'BABA',
#   'AMGN',
#   'AIZ',
#   'AIZ',
#   'AIZ',
#   'AIG',
#   'AIG',
#   'AIG',
#   'AFL',
#   'AFL',
#   'ADM',
#   'ADM',
#   'ADM',
#   'ABT',
#   'ABBV',
#   'ABBV',
#   'RTN',
#   'HELE',
#   'GOOGL',
#   'ARNA',
#   'ADP',
#   'CME',
#   'COST',
#   'DG',
#   'FIS',
#   'IPHI',
#   'MSFT',
#   'RTX',
#   'VTR',
#   'AIG',
#   'WDC',
#   'K',
#   'EMR',
#   'CR',
#   'CSCO',
#   'ADM',
#   'PRU',
#   'CVX',
#   'DAL',
#   'AIZ',
#   'HIG',
#   'CAH',
#   'AIZ',
#   'ADM',
#   'PRU',
#   'DAL',
#   'AIG',
#   'CVX',
#   'CSCO',
#   'ADP',
#   'FIS',
#   'CME',
#   'DG',
#   'TDG',
#   'CME',
#   'MSFT',
#   'TDG',
#   'DD',
#   'K',
#   'BABA',
#   'AIZ',
#   'ABBV',
#   'DOCU',
#   'PRU',
#   'CVX',
#   'DD',
#   'AIZ',
#   'EMR',
#   'CR',
#   'HIG',
#   'AMGN',
#   'AIG',
#   'PANW',
#   'CVX',
#   'BP',
#   'DD',
#   'DD',
#   'DD',
#   'BKNG',
#   'BKNG',
#   'HELE',
#   'BKNG',
#   'TJX',
#   'ROST',
#   'LULU',
#   'FB',
#   'ROST',
#   'CME',
#   'NVDA',
#   'AZO',
#   'ADP',
#   'ARNA',
#   'AMZN',
#   'CME',
#   'AMZN',
#   'NVDA',
#   'IPHI',
#   'FB',
#   'ARNA',
#   'ICE',
#   'ICE',
#   'ICE',
#   'ICE',
#   'ICE',
#   'ORCL',
#   'XOM',
#   'CTXS',
#   'FNKO',
#   'EEFT',
#   'ORLY',
#   'FNKO',
#   'FNKO',
#   'AZO',
#   'ARNA',
#   'TCEHY',
#   'ROKU',
#   'FNKO',
#   'ARNA',
#   'TCEHY',
#   'KL',
#   'CMCSA',
#   'AZO',
#   'HON',
#   'MRK',
#   'DFS',
#   'DAL',
#   'EMR',
#   'CAT',
#   'AFL',
#   'CMCSA',
#   'CSCO',
#   'GS',
#   'CVX',
#   'UL',
#   'PRU',
#   'TJX',
#   'ROST',
#   'AZO',
#   'AZO',
#   'ROST',
#   'KEYS',
#   'CMCSA',
#   'REZI',
#   'REZI',
#   'DFS',
#   'REZI'],
#  'Kaine, Tim': ['GE', '--', 'KMI'],
#  'Perdue, David': ['DOW',
#   'DD',
#   'BRK-B',
#   'BAC',
#   'AAPL',
#   'PFE',
#   'LYV',
#   'LYV',
#   'MU',
#   'MU',
#   'DIS',
#   'MU',
#   'MRK',
#   'MRK',
#   'MRK',
#   'LGF-B',
#   'GPK',
#   'FDX',
#   'DVN',
#   'DAL',
#   'ALB',
#   'HBI',
#   'URBN',
#   'AXTA',
#   'FEYE',
#   'SBUX',
#   'SBUX',
#   'VIAC',
#   'RF',
#   'WPX',
#   'PFE',
#   'LYV',
#   'GM',
#   'GLW',
#   'CAIFX',
#   'FRIAX',
#   'PBA',
#   'ENB',
#   'TRP',
#   'ORCL',
#   'CEQP',
#   'ORCL',
#   'EQM',
#   'PEP',
#   'NWSA',
#   'ORCL',
#   'CVX',
#   'NKE',
#   'WFC',
#   'JPM',
#   'BMY',
#   'ORCL',
#   'BX',
#   'BRK-B',
#   'COST',
#   'AMT',
#   'MRK',
#   'MA',
#   'ANTM',
#   'BK',
#   'PYPL',
#   'ABBV',
#   'AMZN',
#   'CSCO',
#   'EXR',
#   'BAX',
#   'XOM',
#   'SYK',
#   'COP',
#   'FOX',
#   'CTSH',
#   'ACA',
#   'AAPL',
#   'JNJ',
#   'DIS',
#   'CSCO',
#   'MDLZ',
#   'BOIVF',
#   'VZ',
#   'USB',
#   'RL',
#   'WFC',
#   'MSFT',
#   'STT',
#   'UHAL',
#   'KO',
#   'EQM',
#   'BMY',
#   'BAC',
#   'ORCL',
#   'VZ',
#   'PYPL',
#   'GOOGL',
#   'NKE',
#   'MDLZ',
#   'MO',
#   'JPM',
#   'KMI',
#   'NFLX',
#   'HCA',
#   'V',
#   'PRU',
#   'EMR',
#   'HON',
#   'EXR',
#   'CSCO',
#   'COST',
#   'DOW',
#   'AAPL',
#   'AMZN',
#   'DIS',
#   'BAH',
#   'MU',
#   'M',
#   'SU',
#   'CVX',
#   'GOOG',
#   'FHB',
#   'BKNG',
#   'DIS',
#   'FOXA',
#   'HUN',
#   'NWS',
#   'UN',
#   'MSM',
#   'SYY',
#   'PG',
#   'EAF',
#   'PAGP',
#   'PSXP',
#   'SUN',
#   'TCP',
#   'KMI',
#   'EPD',
#   'LNG',
#   'TRP',
#   'MMP',
#   'OKE',
#   'PAA',
#   'ENB',
#   'PBA',
#   'SHLX',
#   'WMB',
#   'TRGP',
#   'MPLX',
#   'ET',
#   'DIS',
#   'COP',
#   'KO',
#   'DD',
#   'C',
#   '--',
#   'HD',
#   'GIS',
#   'BMY',
#   'CAT',
#   'BP',
#   'AAPL',
#   'T',
#   'AFL',
#   'BX',
#   'BA',
#   'JNJ',
#   'TFC',
#   'SYY',
#   'SOJA',
#   'URI',
#   'WFC',
#   'VZ',
#   'SO',
#   'MRK',
#   'PG',
#   'JPM',
#   'INTC',
#   'LLY',
#   'MSFT',
#   'PYPL',
#   'PM',
#   'NKE',
#   'NSC',
#   'MU',
#   'MRK',
#   'NWS',
#   'WPX',
#   'KR',
#   'DD',
#   'CZR',
#   'CZR',
#   'BAC',
#   'KR',
#   'KR',
#   'BAC',
#   'KR',
#   'URBN',
#   'URBN',
#   'URBN',
#   'GM',
#   'KR',
#   'URBN',
#   'KR',
#   'BRK-B',
#   'BRK-B',
#   'URBN',
#   'BRK-B',
#   'BAC',
#   'BRK-B',
#   'BRK-B',
#   'MSM',
#   'M',
#   'NWSA',
#   'FOXA',
#   'EAF',
#   'GEL',
#   'ENB',
#   'KR',
#   'KR',
#   'TRP',
#   'ENB',
#   'KR',
#   'TRP',
#   'KR',
#   'AXTA',
#   'KR',
#   'KR',
#   'KR',
#   'RF',
#   'FOX',
#   'LYV',
#   'HUN',
#   'UHAL',
#   'LYV',
#   'AXTA',
#   'PG',
#   'PEP',
#   'NWSA',
#   'FHB',
#   'CTSH',
#   'SYY',
#   'MSM',
#   'KR',
#   'WFC',
#   'HUN',
#   'GM',
#   'LYV',
#   'KR',
#   'KR',
#   'BAC',
#   'KR',
#   'UHAL',
#   'CDLX',
#   'CDLX',
#   'LYV',
#   'SBUX',
#   'KR',
#   'GOOG',
#   'KR',
#   'CLX',
#   'BOIVF',
#   'SYY',
#   'PAGP',
#   'MSM',
#   'NWSA',
#   'PAGP',
#   'KR',
#   'M',
#   'BAC',
#   'BOIVF',
#   'SBUX',
#   'BAC',
#   'SBUX',
#   'RL',
#   'SBUX',
#   'BOIVF',
#   'BOIVF',
#   'DOW',
#   'NFLX',
#   'TRP',
#   'BOIVF',
#   'WMB',
#   'LNG',
#   'ORCL',
#   'BOIVF',
#   'VIAC',
#   'MU',
#   'GPK',
#   'SBUX',
#   'MU',
#   'GPK',
#   'MU',
#   'MU',
#   'GM',
#   'PFE',
#   'DD',
#   'DD',
#   'DVN',
#   'PFE',
#   'PFE',
#   'CZR',
#   'CZR',
#   'DD',
#   'PFE',
#   'DD',
#   'DAL',
#   'PFE',
#   'DD',
#   'CZR',
#   'CZR',
#   'CZR',
#   'PFE',
#   'PFE',
#   'CZR',
#   'GPK',
#   'CZR',
#   'DD',
#   'PFE',
#   'DD',
#   'T',
#   'VIAC',
#   'T',
#   '--',
#   'DIS',
#   'CZR',
#   'FEYE',
#   'GPK',
#   'DAL',
#   'T',
#   'VIAC',
#   'DVN',
#   'T',
#   'T',
#   'CZR',
#   'T',
#   'VIAC',
#   'T',
#   'CZR',
#   'VIAC',
#   'TRP',
#   'T',
#   'CZR',
#   'DAL',
#   'T',
#   'TRP',
#   'HBI',
#   'HBI',
#   'WMB',
#   'TRGP',
#   'TRGP',
#   'HBI',
#   'ET',
#   'ET',
#   'AAPL',
#   'ET',
#   'ET',
#   'WMB',
#   'WMB',
#   'TRGP',
#   'MPLX',
#   'ENB',
#   'DCP',
#   'DCP',
#   'LNG',
#   'ALB',
#   'WES',
#   'WES',
#   'SHLX',
#   'OKE',
#   'T',
#   'PSXP',
#   'PSXP',
#   'PSXP',
#   'VIAC',
#   'T',
#   '--',
#   'ENTG',
#   'URBN',
#   'BAC',
#   'BAC',
#   'GLW',
#   'AXTA',
#   'AAPL',
#   'WPX',
#   'GPK',
#   'BAC',
#   'WPX',
#   'DD',
#   'DD',
#   'CDLX',
#   'GPK',
#   'URBN',
#   'GPK',
#   'ENTG',
#   'URBN',
#   'AAPL',
#   'ENTG',
#   'URBN',
#   'FEYE',
#   'ALB',
#   'VIAC',
#   '--',
#   'RF',
#   'ENTG',
#   'ENTG',
#   'ALB',
#   'BAH',
#   'DOW',
#   'KMI',
#   'URBN',
#   'URBN',
#   'ACA',
#   'URBN',
#   'URBN',
#   'FDX',
#   'PAA',
#   'URBN',
#   'ENTG',
#   'LNG',
#   'SUN',
#   'URBN',
#   'IP',
#   'URBN',
#   'PAA',
#   'URBN',
#   'TRGP',
#   'TRGP',
#   'URBN',
#   'ALB',
#   'URBN',
#   'URBN',
#   'URBN',
#   'URBN',
#   'URBN',
#   'AM',
#   'FEYE',
#   'ALB',
#   'ENTG',
#   'FEYE',
#   'SPY',
#   'CTSH',
#   'GPK',
#   'XOM',
#   'TCP',
#   'CBS',
#   'LGF-B',
#   'BOIVF',
#   'FDX',
#   'CBS',
#   'SPY',
#   'DVN',
#   'CBS',
#   'RF',
#   'LGF-B',
#   'CBS',
#   'SPY',
#   'FDX',
#   'DVN',
#   'LGF-B',
#   'LGF-B',
#   'ALB',
#   'ALB',
#   'BOIVF',
#   'FEYE',
#   'BOIVF',
#   'ACA',
#   'BOIVF',
#   'BOIVF',
#   'ALB',
#   'NFLX',
#   'PEP',
#   'AAPL',
#   'AAPL',
#   'ALB',
#   'DIS',
#   'TCP',
#   'ALB',
#   'EAF',
#   'MSFT',
#   'COP',
#   'STT',
#   'PG',
#   'DIS',
#   'USB',
#   'KO',
#   'MSM',
#   'PEP',
#   'XOM',
#   'NWSA',
#   'SYK',
#   'BOIVF',
#   'ORCL',
#   'FOX',
#   'BK',
#   'BKNG',
#   'ANTM',
#   'SYY',
#   'UHAL',
#   'CBS',
#   'ENTG',
#   'CBS',
#   'IP',
#   'PBA',
#   'SPY',
#   'CTSH',
#   'XOM',
#   'RF',
#   'MOS',
#   'DVN',
#   'CBS',
#   'SPY',
#   'LGF-B',
#   'FDX',
#   'NWSA',
#   'NWSA',
#   'TRGP',
#   'ENTG',
#   'DOW',
#   'RF',
#   'PAA',
#   'ALB',
#   'FDX',
#   'CZR',
#   'CZR',
#   'ENTG',
#   'ENTG',
#   'BPL',
#   'BPL',
#   'BPL',
#   'BPL',
#   'ET',
#   'WES',
#   'WES',
#   'BPL',
#   'BPL',
#   'OKE',
#   'AAPL',
#   'DCP',
#   'GPK',
#   'SU',
#   'T',
#   'T',
#   'T',
#   'ENTG',
#   'ENTG',
#   'CZR',
#   'CZR',
#   'GPK',
#   'ENTG',
#   'M',
#   'BMY',
#   'GPK',
#   'GPK',
#   'EXR',
#   'EXR',
#   'GPK',
#   'DIS',
#   'FEYE',
#   'GPK',
#   'DIS',
#   'GPK',
#   'KR',
#   'KR',
#   'M',
#   'KR',
#   'CZR',
#   'STT',
#   'CZR',
#   'KR',
#   'KR',
#   'CZR',
#   'ANDX',
#   'T',
#   'KO',
#   'GE',
#   'PYPL',
#   'JCI',
#   'SUN',
#   'KR',
#   'GPK',
#   'CZR',
#   'GPK',
#   'GPK',
#   'CZR',
#   'ENTG',
#   'HBI',
#   'GPK',
#   'GPK',
#   'CZR',
#   'CZR',
#   'LGF-B',
#   'CZR',
#   'CZR',
#   'CZR',
#   'MYL',
#   'ABBV',
#   'BMY',
#   'DOW',
#   'DOW',
#   'DD',
#   'DD',
#   'ENTG',
#   'MSM',
#   'CZR',
#   'BWXT',
#   'CZR',
#   'BWXT',
#   'CZR',
#   'CZR',
#   'FEYE',
#   'CZR',
#   'CZR',
#   'BWXT',
#   'WPX',
#   'FDX',
#   'PBA',
#   'CZR',
#   'OKE',
#   'LNG',
#   'LGF-B',
#   'TRGP',
#   'TRGP',
#   'CTVA',
#   'CTVA',
#   'NWSA',
#   'GLW',
#   'GLW',
#   'BWXT',
#   'GLW',
#   'GLW',
#   'GLW',
#   'M',
#   'PBA',
#   'PG',
#   'PEP',
#   'EAF',
#   'CTSH',
#   'INFY',
#   'EAF',
#   'CEQP',
#   'EAF',
#   'PEP',
#   'PG',
#   'EAF',
#   'FDX',
#   'AVP',
#   'CTSH',
#   'INFY',
#   'GLW',
#   'DIS',
#   'FDX',
#   'GLW',
#   'AMT',
#   'BWXT',
#   'BWXT',
#   'ACA',
#   'OKE',
#   'BWXT',
#   'BWXT',
#   'FDX',
#   'FDX',
#   'FDX',
#   'BWXT',
#   'ENTG',
#   'GLW',
#   'BWXT',
#   'FDX',
#   'FDX',
#   'FDX',
#   'FDX',
#   'LYV',
#   'BWXT',
#   'ENTG',
#   'TRP',
#   'TRP',
#   'TRP',
#   'TRP',
#   'WMB',
#   'LYV',
#   'ENTG',
#   'FDC',
#   'TRP',
#   'FDC',
#   'BWXT',
#   'FDC',
#   'BWXT',
#   'MRK',
#   'DIS',
#   'FDC',
#   'EMR',
#   'FDC',
#   'FDX',
#   'AAPL',
#   'FDX',
#   'AAPL',
#   'BWXT',
#   'FDC',
#   'LYV',
#   'DIS',
#   'DIS',
#   'FDX',
#   '--',
#   'BWXT',
#   'LYV',
#   'MOS',
#   'FDX',
#   'FDX',
#   'LYV',
#   'FDC',
#   'AM',
#   'FDX',
#   'FDX',
#   'MOS',
#   'FDX',
#   'FDX',
#   'MOS',
#   'KMI',
#   'FDX',
#   'BKNG',
#   'MSFT',
#   'CSCO',
#   'ORCL',
#   'GOOG',
#   'IBM',
#   'BWXT',
#   'ET',
#   'BWXT',
#   'MPLX',
#   'TRGP',
#   'WES',
#   'FDC',
#   'FDC',
#   'TRP',
#   'FDC',
#   'TRP',
#   'TRP',
#   'BWXT',
#   'WGP',
#   'BOIVF',
#   'BWXT',
#   'BWXT',
#   'TRGP',
#   'LNG',
#   'BWXT',
#   'UHAL',
#   'PEP',
#   'AVP',
#   'STT',
#   'PG',
#   'FOX',
#   'KO',
#   'UN',
#   'CSCO',
#   'SYY',
#   'FOXA',
#   'ORCL',
#   'MSFT',
#   'COP',
#   'ANTM',
#   'ACA',
#   'INFY',
#   'MU',
#   'CLX',
#   'BRK-B',
#   'WFC',
#   'TRGP',
#   'GLW',
#   'MRK',
#   'MOS',
#   'HBI',
#   'ENTG',
#   'GM',
#   'PG',
#   'WPX',
#   'BOIVF',
#   'FDC',
#   'LGF-B',
#   'OKE',
#   'PAGP',
#   'FDC',
#   'FEYE',
#   'FEYE',
#   'BOIVF',
#   'PAGP',
#   'AM',
#   'WPX',
#   'T',
#   'T',
#   'FDC',
#   'T',
#   'WPX',
#   'WPX',
#   'MPLX',
#   'FDC',
#   'WPX',
#   'BOIVF',
#   'T',
#   'ET',
#   'MPLX',
#   'T',
#   'T',
#   'MMP',
#   'BOIVF',
#   'T',
#   'T',
#   'T',
#   'WPX',
#   'FDC',
#   'FDC',
#   'WPX',
#   'WPX',
#   'WPX',
#   'FDC',
#   'FDC',
#   'BWXT',
#   'AM',
#   'DVN',
#   'DVN',
#   'AM',
#   'KN',
#   'BWXT',
#   'GPK',
#   'KN',
#   'BWXT',
#   'BWXT',
#   'CZR',
#   'BWXT',
#   'DVN',
#   'KN',
#   'AAPL',
#   'BWXT',
#   'WPX',
#   'SPY',
#   'SPY',
#   'CZR',
#   'AXTA',
#   'SPY',
#   'HBI',
#   'DVN',
#   'FDC',
#   'BWXT',
#   'ACA',
#   'BWXT',
#   'LGF-B',
#   'ACA',
#   'RF',
#   'BWXT',
#   'LGF-B',
#   'PAGP',
#   'PG',
#   'GPK',
#   'LGF-B',
#   'VLP',
#   'SLB',
#   'STT',
#   'ACA',
#   'BWXT',
#   'ET',
#   'LGF-B',
#   'BWXT',
#   'MU',
#   'KN',
#   'VLP',
#   'LGF-B',
#   'BWXT',
#   'LGF-B',
#   'SU',
#   'SLB',
#   'UPS',
#   'BWXT',
#   'UPS',
#   'WPX',
#   'KN',
#   'MOS',
#   'LGF-B',
#   'GLW',
#   'UPS',
#   'RF',
#   'UPS',
#   'GLW',
#   'BWXT',
#   'GLW',
#   'LGF-B',
#   'LGF-B',
#   'BWXT',
#   'LGF-B',
#   'BWXT',
#   'BWXT',
#   'BWXT',
#   'LGF-B',
#   'LGF-B',
#   'LGF-B',
#   'LGF-B',
#   'LGF-B',
#   'KMI',
#   'WMB',
#   'GPK',
#   'LGF-B',
#   'AAPL',
#   'AAPL',
#   'AAPL',
#   'AAPL',
#   'DISCA',
#   'DISCA',
#   'LGF-B',
#   'AAPL',
#   'LGF-B',
#   'DISCA',
#   'LGF-B',
#   'DVN',
#   'SPY',
#   'HBI',
#   'FDC',
#   'AXTA',
#   'DISCA',
#   'PFE',
#   'VLP',
#   'DISCA',
#   'FDC',
#   'DISCA',
#   'LGF-B',
#   'GPK',
#   'MOS',
#   'PFE',
#   'LGF-B',
#   'PFE',
#   'FDC',
#   'FDC',
#   'LGF-B',
#   'FDC',
#   'FDC',
#   'FDC',
#   'VLP',
#   'DISCA',
#   'LGF-B',
#   'MOS',
#   'KN',
#   'DISCA',
#   'LGF-B',
#   'MOS',
#   'MOS',
#   'LGF-B',
#   'PFE',
#   'KN',
#   'LGF-B',
#   'FDC',
#   'FDC',
#   'LGF-B',
#   'PFE',
#   'PFE',
#   'DISCA',
#   'DISCA',
#   'FEYE',
#   'DISCA',
#   'FEYE',
#   'FEYE',
#   'FEYE',
#   'FDC',
#   'DISCA',
#   'PFE',
#   'GPK',
#   'FDC',
#   'MOS',
#   'MOS',
#   'DISCA',
#   'DISCA',
#   'GPK',
#   'PFE',
#   'DISCA',
#   'ETP',
#   'GPK',
#   'CBS',
#   'HBI',
#   'AAPL',
#   'PFE',
#   'AAPL',
#   'PFE',
#   'GPK',
#   'GPK',
#   'FDC',
#   'DISCA',
#   'PFE',
#   'GPK',
#   'FDC',
#   'PFE',
#   'PFE',
#   'DISCA',
#   'MRK',
#   'FDC',
#   'FDC',
#   'MU',
#   'ENTG',
#   'DVN',
#   'MOS',
#   'DISCA',
#   'PG',
#   'JNJ',
#   'CAT',
#   'IP',
#   'WMB',
#   'RF',
#   'VLP',
#   'BAC',
#   ...],
#  'Smith, Tina': ['DXCM',
#   'PODD',
#   'ABT',
#   'MSTY.PA',
#   'MSTY.PA',
#   'PODD',
#   'CUTR',
#   'CUTR',
#   'PODD',
#   'IIN',
#   'TCMD',
#   'TCMD',
#   'PODD',
#   'CGNT',
#   'CGNT',
#   'CGNT',
#   'CGNT',
#   'PODD',
#   'CUTR',
#   'ENTL'],
#  'Hoeven, John': ['BMEZ',
#   'BIV',
#   'VFIJX',
#   'SLB',
#   'MPC',
#   'TGBAX',
#   'REZI',
#   'KHC',
#   'GTX',
#   'PRU',
#   'BSTZ',
#   'IVZ',
#   'XOM',
#   'TWO',
#   'XOM',
#   'EXC',
#   'CVX',
#   'IBM',
#   'NFLX',
#   'KTB',
#   'DOW',
#   'CVS',
#   'UPS',
#   'BSTZ',
#   'CE',
#   'DOW',
#   'WTW',
#   'WTW',
#   'WTW',
#   'WTW',
#   'KDP',
#   'XSLV',
#   'PRNHX',
#   'FLMVX',
#   'FCNTX',
#   'TGT',
#   'MET',
#   'IVZ',
#   'KDP',
#   'CCI',
#   'LYB',
#   'AAPL',
#   'WTW',
#   'DWDP',
#   'TAP',
#   'IVZ',
#   'BUD',
#   'T',
#   'FDX',
#   'FDX',
#   'CAT',
#   'WTW',
#   'T',
#   'MET',
#   'CVS',
#   'AMZN',
#   'T',
#   'GIS',
#   'IBM',
#   'DWDP',
#   'UPS',
#   'DWDP',
#   'WMT',
#   'CAT',
#   'WTW',
#   'WMT',
#   'WTW',
#   'JETS',
#   'AMZN',
#   'AVGO',
#   'NGG',
#   'QCOM',
#   'IBM',
#   'DPS',
#   'FB',
#   'LYB',
#   'WTW',
#   'F',
#   'IBM',
#   'MDLZ',
#   'GIS',
#   'SBUX',
#   'SPG',
#   'KSS',
#   'NGG',
#   'UPS',
#   'QCOM',
#   'KSS',
#   'CCI',
#   'MRK',
#   'WTW',
#   'VFC',
#   'JNJ',
#   'ABBV',
#   'PFE',
#   'BMY',
#   'AMGN',
#   'VZ',
#   'PG',
#   'PEP',
#   'INTC',
#   'KO',
#   'CSCO',
#   'T',
#   'SPG',
#   'NKE',
#   'CSX',
#   'F',
#   'USB',
#   'UNP',
#   'VSAT',
#   'IBM',
#   'WFC',
#   'VLO',
#   'CAT',
#   'UA',
#   'UAA',
#   'CTL',
#   'BX',
#   'DEO',
#   'MDU',
#   'PFE',
#   'AMGN',
#   'TJX',
#   'RL',
#   'JCI',
#   'HAS',
#   'BMY',
#   'MCD',
#   'PRU',
#   'MCD',
#   'IVZ',
#   'UA-C',
#   'IRET',
#   'IRET',
#   'VLO',
#   'MCD',
#   '--',
#   'IVZ',
#   'PRU',
#   'FB',
#   'GOOG',
#   'ADP',
#   'MRK',
#   'AAPL',
#   'MCD',
#   'UA',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   'JCI',
#   'RL',
#   'TAP',
#   'KHC',
#   'KRFT',
#   'PRPFX',
#   'MDU',
#   'CAT',
#   'ABBV',
#   'NOG',
#   'NOG',
#   'FCX',
#   'COH'],
#  'Kennedy, John': ['MTUM', '--'],
#  'Cruz, Ted': ['PAGP', 'GS', 'OKE', 'GS', 'OKE', '--', '--', 'PAGP'],
#  'Coons, Christopher': ['NFLX',
#   'NFLX',
#   'NFLX',
#   'NFLX',
#   'AAPL',
#   'AAPL',
#   'MSFT'],
#  'Udall, Tom': ['CBS', 'GE'],
#  'Reed, John': ['XLNX',
#   'TMO',
#   'SYK',
#   'SLB',
#   'QCOM',
#   'PEP',
#   'MSFT',
#   'ISRG',
#   'INTC',
#   'IQV',
#   'HOLX',
#   'FDX',
#   'DHR',
#   'COST',
#   'CELG',
#   'CVS',
#   'AAPL',
#   'ADI',
#   'XLNX',
#   'TMO',
#   'SYK',
#   'IQV',
#   'FDX',
#   'AAPL',
#   'ADI',
#   'XLNX',
#   'VRTX',
#   'SYK',
#   'QCOM',
#   'ISRG',
#   'INTC',
#   'ITW',
#   'IQV',
#   'HON',
#   'FDX',
#   'DHR',
#   'COST',
#   'CSCO',
#   'CVS',
#   'AAPL',
#   'AMGN',
#   'HOLX',
#   'AGN',
#   'UNFI',
#   'DHR',
#   'XLNX',
#   'VRTX',
#   'VWO',
#   'TMO',
#   'SYK',
#   'XBI',
#   'XSD',
#   'RYT',
#   'QCOM',
#   'ISRG',
#   'INTC',
#   'ITW',
#   'IYT',
#   'IQV',
#   'HON',
#   'FDX',
#   'DHR',
#   'COST',
#   'CSCO',
#   'CVS',
#   'AAPL',
#   'ADI',
#   'AMGN',
#   'LSCC',
#   'LSCC',
#   'HACK',
#   'PEP',
#   'CELG',
#   'UNFI',
#   'XSD',
#   'LSCC',
#   'AGN',
#   'Q',
#   'Q',
#   'WFM',
#   'Q',
#   'Q',
#   'HACK',
#   'IYT',
#   'ADI',
#   'XBI',
#   'WFM',
#   'DVMT',
#   'NXPI',
#   'NXPI',
#   '--',
#   'WETF',
#   'AGU',
#   'ESRX',
#   'CELG',
#   'CELG',
#   'TMO',
#   'XBI',
#   'FDX',
#   'ADI',
#   'AGN',
#   '--',
#   'XBI',
#   'HACK',
#   'IYT',
#   'FDX',
#   'ADI',
#   'AGN',
#   'ESRX',
#   'EMR',
#   'HON',
#   'PEP',
#   'PEP',
#   'QCOM',
#   'NXPI',
#   'QCOM',
#   'NXPI',
#   'ZBH',
#   'ZBH',
#   'WETF',
#   'DVMT',
#   'AMG',
#   'XSD',
#   'INTC',
#   'DHR',
#   'IAI',
#   'AMG',
#   'XSD',
#   'DHR',
#   'EEM',
#   'TMO',
#   'XSD',
#   'ISRG',
#   'WETF',
#   'VWO',
#   'FEYE',
#   'XSD',
#   'HACK',
#   'ISRG',
#   'WETF',
#   'TMO',
#   'IYT',
#   'TMO',
#   'DHR',
#   'TMO',
#   'DHR',
#   'TMO',
#   'IYT',
#   'DHR',
#   'TMO',
#   'DHR',
#   'IYT',
#   'CELG',
#   'AMG',
#   'ZBH',
#   'PEP',
#   'MSFT',
#   'CELG',
#   'AMG',
#   'ZBH',
#   'PEP',
#   'NCR',
#   'FDX',
#   'FDX',
#   'CELG',
#   'CELG',
#   'TBF',
#   'TBF',
#   'VWO',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   '--',
#   'FEYE',
#   'ALTR',
#   'AMG',
#   'ALTR',
#   'AMG',
#   'LSCC',
#   'LSCC',
#   'XRT',
#   'VRTX',
#   'TBF',
#   'TBF',
#   'MSFT',
#   'FEYE',
#   'ESRX',
#   'SLB',
#   'EMC',
#   'MYL',
#   'ACT',
#   'AMAT',
#   'ACT',
#   'MYL',
#   'CELG',
#   'AMGN',
#   'IYT'],
#  'Tillis, Thom': ['CVS',
#   'AQFH',
#   'AQFH',
#   '--',
#   'JCOM',
#   'WST',
#   'WAL',
#   'WAGE',
#   'VSI',
#   'TYPE',
#   'TXRH',
#   'TUMI',
#   'TTC',
#   'TNGO',
#   'THS',
#   'THRM',
#   'TECH',
#   'TCBI',
#   'SXT',
#   'SWI',
#   'SSB',
#   'SQI',
#   'SPSC',
#   'SMTC',
#   'SIGI',
#   'SHOO',
#   'SGY',
#   'RRTS',
#   'ROLL',
#   'RBA',
#   'RAVN',
#   'QLIK',
#   'PRLB',
#   'PRIM',
#   'PRAA',
#   'PRA',
#   'POWI',
#   'PLT',
#   'PLKI',
#   'PEB',
#   'PBH',
#   'OMCL',
#   'OFC',
#   'NSR',
#   'NICE',
#   'MNRO',
#   'MG',
#   'MFRM',
#   'MDCA',
#   'MASI',
#   'LSTR',
#   'LOCK',
#   'LL',
#   'KWR',
#   'JJSF',
#   'IPCM',
#   'ICUI',
#   'ICON',
#   'HUBG',
#   'IART',
#   'HLX',
#   'HF',
#   'HEI',
#   'HCSG',
#   'GMED',
#   'FNGN',
#   'FMBI',
#   'FET',
#   'EVR',
#   'EPAY',
#   'EGBN',
#   'DRQ',
#   'DIOD',
#   'DFRG',
#   'CYBX',
#   'CVLT',
#   'CTRL',
#   'CTCT',
#   'CRZO',
#   'CMN',
#   'CLC',
#   'CHEF',
#   'CGNX',
#   'CASY',
#   'BMR',
#   'BIO',
#   'BERY',
#   'BECN',
#   'BCPC',
#   'ATRO',
#   'AMSG',
#   'ALE',
#   'AKRX',
#   'AFSI',
#   'ABCO',
#   'AAT',
#   'AAON',
#   'NICE'],
#  'Casey, Bob': ['FE'],
#  'Bennet, Michael': ['RGC', 'LVLT', 'RGC'],
#  'Murray, Patty': ['WMB',
#   'WRK',
#   'WFC',
#   'WBA',
#   'WMT',
#   'VZ',
#   'VTR',
#   'UTX',
#   'UPS',
#   'UN',
#   'USB',
#   'TUP',
#   'TWX',
#   'TEVA',
#   'TGT',
#   'TSM',
#   'STI',
#   'SU',
#   'STT',
#   'SO',
#   'SLB',
#   'SNY',
#   'SABR',
#   'RAI',
#   'RTN',
#   'QCOM',
#   'PSA',
#   'PRU',
#   'PG',
#   'PDM',
#   'PFE',
#   'PAYX',
#   'PPL',
#   'MS',
#   'TAP',
#   'MSFT',
#   'MET',
#   'MRK',
#   'MXIM',
#   'MDC',
#   'MTB',
#   'KMI',
#   'KMB',
#   'KEY',
#   'KAR',
#   'JNJ',
#   'JPM',
#   'HSY',
#   'GSK',
#   'GILD',
#   'GM',
#   'GE',
#   'GD',
#   'XOM',
#   'EXC',
#   'ETR',
#   'DNKN',
#   'DUK',
#   'DOW',
#   'DIS',
#   'CCI',
#   'COP',
#   'CMA',
#   'CMCSA',
#   'KO',
#   'CSCO',
#   'CVX',
#   'CVS',
#   'BMY',
#   'BA',
#   'BAC',
#   'BGS',
#   'AAPL',
#   'APA',
#   'AMGN',
#   'AMT',
#   'T',
#   'LYB',
#   'TEL',
#   'CB',
#   'MDT',
#   'ETN',
#   'DLPH',
#   'WMB',
#   'WRK',
#   'WFC',
#   'WBA',
#   'WMT',
#   'VZ',
#   'UTX',
#   'UPS',
#   'UN',
#   'USB',
#   'TUP',
#   'TWX',
#   'TGT',
#   'STI',
#   'SU',
#   'STT',
#   'SO',
#   'SLB',
#   'SNY',
#   'SABR',
#   'RTN',
#   'QCOM',
#   'PSA',
#   'PRU',
#   'PG',
#   'PFE',
#   'PAYX',
#   'PPL',
#   'MS',
#   'TAP',
#   'MSFT',
#   'MET',
#   'MRK',
#   'MXIM',
#   'MMC',
#   'MTB',
#   'KMI',
#   'KMB',
#   'KEY',
#   'KAR',
#   'JNJ',
#   'JPM',
#   'HSY',
#   'GSK',
#   'GILD',
#   'GM',
#   'GE',
#   'GD',
#   'FL',
#   'XOM',
#   'EXC',
#   'ETR',
#   'DNKN',
#   'DUK',
#   'DOW',
#   'DIS',
#   'CCI',
#   'COP',
#   'CMA',
#   'CMCSA',
#   'KO',
#   'CSCO',
#   'CVX',
#   'CVS',
#   'BMY',
#   'BA',
#   'BAC',
#   'BGS',
#   'AAPL',
#   'APA',
#   'AMGN',
#   'T',
#   'LYB',
#   'TEL',
#   'CB',
#   'MDT',
#   'ETN',
#   'DLPH'],
#  'Daines, Steve': ['--'],
#  'Manchin, Joe': ['HBAN'],
#  'Van Hollen, Chris': ['YUMC', 'YUM', 'VZ', 'PEP', 'JNJ', 'GE', 'T'],
#  'Cornyn, John': ['AAPL', 'AAPL'],
#  'Cantwell, Maria': ['RNWK'],
#  'Enzi, Michael': ['KEY'],
#  'Rounds, Mike': ['--']}

# %%
amount_series = transactions.amount
for index,value in amount_series.iteritems():
    transactions.loc[index, 'amount'] = value.replace('$','')

# %%
transactions = transactions.drop(columns=['comment','ptr_link','senator'])

# %%
transactions = transactions.rename(columns={'asset_description':'Asset Description','transaction_date':'Transaction Date','owner':'Owner','ticker':'Ticker','asset_type':'Asset Type','type':'Type','amount':'Amount','disclosure_date':'Disclosure Date','senator_rev':'Senator'})

# %%
transactions = transactions.reset_index().drop(columns='index')

# %%
transactions
# Out:
#      Transaction Date   Owner Ticker  \
# 0          03/09/2022    Self   TACO
# 1          03/30/2022   Joint    WST
# 2          03/30/2022   Joint   VEEV
# 3          03/30/2022   Joint    VMW
# 4          03/30/2022   Joint    SNA
# ...               ...     ...    ...
# 6980       12/11/2014  Spouse  DVFAX
# 6981       12/12/2014  Spouse    XOM
# 6982       12/19/2014  Spouse     BA
# 6983       12/12/2014  Spouse    BAC
# 6984       12/11/2014  Spouse    MIK
#
#                                     Asset Description Asset Type  \
# 0           Del Taco Restaurants, Inc. - Common Stock      Stock
# 1     West Pharmaceutical Services, Inc. Common Stock      Stock
# 2             Veeva Systems Inc. Class A Common Stock      Stock
# 3                  Vmware, Inc. Common stock, Class A      Stock
# 4                   Snap-On Incorporated Common Stock      Stock
# ...                                               ...        ...
# 6980     Cohen &amp; Steers Dividend Value A (NASDAQ)      Stock
# 6981                   Exxon Mobil Corporation (NYSE)      Stock
# 6982                        The Boeing Company (NYSE)      Stock
# 6983               Bank of America Corporation (NYSE)      Stock
# 6984            The Michaels Companies, Inc. (NASDAQ)      Stock
#
#                 Type           Amount Disclosure Date            Senator
# 0     Sale (Partial)  15,001 - 50,000      04/13/2022      Hagerty, Bill
# 1        Sale (Full)   1,001 - 15,000      04/08/2022  Tuberville, Tommy
# 2        Sale (Full)   1,001 - 15,000      04/08/2022  Tuberville, Tommy
# 3        Sale (Full)   1,001 - 15,000      04/08/2022  Tuberville, Tommy
# 4        Sale (Full)   1,001 - 15,000      04/08/2022  Tuberville, Tommy
# ...              ...              ...             ...                ...
# 6980        Purchase   1,001 - 15,000      01/09/2015     Collins, Susan
# 6981     Sale (Full)   1,001 - 15,000      01/05/2015       Roberts, Pat
# 6982        Purchase   1,001 - 15,000      01/05/2015       Roberts, Pat
# 6983     Sale (Full)   1,001 - 15,000      01/05/2015       Roberts, Pat
# 6984        Purchase   1,001 - 15,000      01/05/2015       Roberts, Pat
#
# [6985 rows x 9 columns]

# %% [markdown]
# # Bill Categorization

# %% [markdown]
# URL iteration list

# %%
normal_policy_list = ['Health', 'Public Lands and Natural Resources', 'Agriculture and Food', 'Economics and Public Finance', 'Housing and Community Development', 'Water Resources Development']

# %%
url_policy_list = list(map(lambda x: x.replace(' ', '+').replace(',', '%2C'), normal_policy_list))

# %%
var_policy_list = list(map(lambda x: x.replace(' ', '_').replace(',', ''), normal_policy_list))

# %% [markdown]
# Retreiving all items on one page

# %% [markdown]
# response = requests.get('https://www.congress.gov/search?pageSort=title&pageSize=250&q=%7B%22congress%22%3A%5B%22117%22%2C%22112%22%2C%22113%22%2C%22114%22%2C%22115%22%2C%22116%22%5D%2C%22source%22%3A%22legislation%22%2C%22subject%22%3A%22Health%22%7D')

# %% [markdown]
# soup = BS(response.text)

# %% [markdown]
# soup.find_all('span', attrs={'class':'result-heading'})

# %% [markdown]
# bill_tags = str(soup.find_all('span', attrs={'class':'result-heading'}))

# %% [markdown]
# #Bills
# URL='https://www.congress.gov/search?pageSort=title&q=%7B%22congress%22%3A%5B%22117%22%2C%22112%22%2C%22113%22%2C%22114%22%2C%22115%22%2C%22116%22%5D%2C%22source%22%3A%22legislation%22%2C%22subject%22%3A%22Health%22%7D&pageSize=250&page=1'
# response = requests.get(URL)
# soup = BS(response.text)
# pages = int(re.search('class="results-number"> of (\d+)</span>', str(soup.find_all('span', attrs={'class':'results-number'}))).group(1))
# for x in tqdm(range(1,pages+1)):
#     response = requests.get(f'https://www.congress.gov/search?pageSort=title&q=%7B%22congress%22%3A%5B%22117%22%2C%22112%22%2C%22113%22%2C%22114%22%2C%22115%22%2C%22116%22%5D%2C%22source%22%3A%22legislation%22%2C%22subject%22%3A%22Health%22%7D&pageSize=250&page={x}')
#     soup = BS(response.text)
#     bill_tags = str(soup.find_all('span', attrs={'class':'result-heading'}))
#     print(x,len(re.findall('r=\d+">(S.\d+|H.R.\d+|S.Res.\d+|H.Res.\d+|S.Con.Res.\d+|H.Con.Res.\d+|S.J.Res.\d+|H.J.Res.\d+)</a>', bill_tags)[1::2]))

# %% [markdown]
# #Congress
# URL='https://www.congress.gov/search?pageSort=title&q=%7B%22congress%22%3A%5B%22117%22%2C%22112%22%2C%22113%22%2C%22114%22%2C%22115%22%2C%22116%22%5D%2C%22source%22%3A%22legislation%22%2C%22subject%22%3A%22Health%22%7D&pageSize=250&page=1'
# response = requests.get(URL)
# soup = BS(response.text)
# pages = int(re.search('class="results-number"> of (\d+)</span>', str(soup.find_all('span', attrs={'class':'results-number'}))).group(1))
# for x in tqdm(range(1,pages+1)):
#     response = requests.get(f'https://www.congress.gov/search?pageSort=title&q=%7B%22congress%22%3A%5B%22117%22%2C%22112%22%2C%22113%22%2C%22114%22%2C%22115%22%2C%22116%22%5D%2C%22source%22%3A%22legislation%22%2C%22subject%22%3A%22Health%22%7D&pageSize=250&page={x}')
#     soup = BS(response.text)
#     bill_tags = str(soup.find_all('span', attrs={'class':'result-heading'}))
#     print(x,len(re.findall('</a> — (\d+th Congress \\(\d{4}-\d{4}\\))</span>', bill_tags)[1::2]))

# %% [markdown]
# len(re.findall('</a> — (\d+th Congress \\(\d{4}-\d{4}\\))</span>', bill_tags)[1::2])

# %% [markdown]
# bill_tags

# %% [markdown]
# Method for testing any given policy

# %% [markdown]
# #Bills
# #must replace both URLs with pertinent policy url
# URL='https://www.congress.gov/search?pageSort=title&q=%7B%22congress%22%3A%5B%22117%22%2C%22112%22%2C%22113%22%2C%22114%22%2C%22115%22%2C%22116%22%5D%2C%22source%22%3A%22legislation%22%2C%22subject%22%3A%22Health%22%7D&pageSize=250&page=1'
# response = requests.get(URL)
# soup = BS(response.text)
# pages = int(re.search('class="results-number"> of (\d+)</span>', str(soup.find_all('span', attrs={'class':'results-number'}))).group(1))
# bills = []
#
# for x in tqdm(range(1,pages+1)):
#             response = requests.get(f'https://www.congress.gov/search?pageSort=title&q=%7B%22congress%22%3A%5B%22117%22%2C%22112%22%2C%22113%22%2C%22114%22%2C%22115%22%2C%22116%22%5D%2C%22source%22%3A%22legislation%22%2C%22subject%22%3A%22Health%22%7D&pageSize=250&page={x}')
#             soup = BS(response.text)
#             bill_tags = str(soup.find_all('span', attrs={'class':'result-heading'}))
#             bills.extend(list(re.findall('r=\d+">(S.\d+|H.R.\d+|S.Res.\d+|H.Res.\d+|S.Con.Res.\d+|H.Con.Res.\d+|S.J.Res.\d+|H.J.Res.\d+)</a>', bill_tags)[1::2]))

# %% [markdown]
# #Congress
# #must replace both URLs with pertinent policy url
# URL='https://www.congress.gov/search?pageSort=title&q=%7B%22congress%22%3A%5B%22117%22%2C%22112%22%2C%22113%22%2C%22114%22%2C%22115%22%2C%22116%22%5D%2C%22source%22%3A%22legislation%22%2C%22subject%22%3A%22Health%22%7D&pageSize=250&page=1'
# response = requests.get(URL)
# soup = BS(response.text)
# pages = int(re.search('class="results-number"> of (\d+)</span>', str(soup.find_all('span', attrs={'class':'results-number'}))).group(1))
# congress = []
#
# for x in tqdm(range(1,pages+1)):
#             response = requests.get(f'https://www.congress.gov/search?pageSort=title&q=%7B%22congress%22%3A%5B%22117%22%2C%22112%22%2C%22113%22%2C%22114%22%2C%22115%22%2C%22116%22%5D%2C%22source%22%3A%22legislation%22%2C%22subject%22%3A%22Health%22%7D&pageSize=250&page={x}')
#             soup = BS(response.text)
#             bill_tags = str(soup.find_all('span', attrs={'class':'result-heading'}))
#             congress.extend(list(re.findall('</a> — (\d+th Congress \\(\d{4}-\d{4}\\))</span>', bill_tags)[1::2]))

# %%
d = {}
for policy in tqdm(url_policy_list):
    URL=f'https://www.congress.gov/search?pageSort=title&q=%7B%22congress%22%3A%5B%22117%22%2C%22112%22%2C%22113%22%2C%22114%22%2C%22115%22%2C%22116%22%5D%2C%22source%22%3A%22legislation%22%2C%22subject%22%3A%22{policy}%22%7D&pageSize=250&page=1'
    response = requests.get(URL)
    soup = BS(response.text)
    pages = int(re.search('class="results-number"> of (\d+)</span>', str(soup.find_all('span', attrs={'class':'results-number'}))).group(1))
    for x in tqdm(range(1,pages+1)):
        response = requests.get(f'https://www.congress.gov/search?pageSort=title&q=%7B%22congress%22%3A%5B%22117%22%2C%22112%22%2C%22113%22%2C%22114%22%2C%22115%22%2C%22116%22%5D%2C%22source%22%3A%22legislation%22%2C%22subject%22%3A%22{policy}%22%7D&pageSize=250&page={x}')
        soup = BS(response.text)
        bill_tags = str(soup.find_all('span', attrs={'class':'result-heading'}))
        if policy in d:
            d[policy].extend(re.findall('</a> — (\d+th Congress \\(\d{4}-\d{4}\\))</span>', bill_tags)[1::2])
        else:
            d[policy] = re.findall('</a> — (\d+th Congress \\(\d{4}-\d{4}\\))</span>', bill_tags)[1::2]
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/36 [00:00<?, ?it/s]
#   0%|          | 0/15 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
d2 = {}
for policy in tqdm(url_policy_list):
    URL=f'https://www.congress.gov/search?pageSort=title&q=%7B%22congress%22%3A%5B%22117%22%2C%22112%22%2C%22113%22%2C%22114%22%2C%22115%22%2C%22116%22%5D%2C%22source%22%3A%22legislation%22%2C%22subject%22%3A%22{policy}%22%7D&pageSize=250&page=1'
    response = requests.get(URL)
    soup = BS(response.text)
    pages = int(re.search('class="results-number"> of (\d+)</span>', str(soup.find_all('span', attrs={'class':'results-number'}))).group(1))
    for x in tqdm(range(1,pages+1)):
        response = requests.get(f'https://www.congress.gov/search?pageSort=title&q=%7B%22congress%22%3A%5B%22117%22%2C%22112%22%2C%22113%22%2C%22114%22%2C%22115%22%2C%22116%22%5D%2C%22source%22%3A%22legislation%22%2C%22subject%22%3A%22{policy}%22%7D&pageSize=250&page={x}')
        soup = BS(response.text)
        bill_tags = str(soup.find_all('span', attrs={'class':'result-heading'}))
        if policy in d2:
            d2[policy].extend(re.findall('r=\d+">(S.\d+|H.R.\d+|S.Res.\d+|H.Res.\d+|S.Con.Res.\d+|H.Con.Res.\d+|S.J.Res.\d+|H.J.Res.\d+)</a>', bill_tags)[1::2])
        else:
            d2[policy] = re.findall('r=\d+">(S.\d+|H.R.\d+|S.Res.\d+|H.Res.\d+|S.Con.Res.\d+|H.Con.Res.\d+|S.J.Res.\d+|H.J.Res.\d+)</a>', bill_tags)[1::2]
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/36 [00:00<?, ?it/s]
#   0%|          | 0/15 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
for policy in url_policy_list:
    print(policy,len(d[policy]))
    print(policy,len(d2[policy]))
# Out:
# Health 8918
# Health 8918
# Public+Lands+and+Natural+Resources 3723
# Public+Lands+and+Natural+Resources 3723
# Agriculture+and+Food 1453
# Agriculture+and+Food 1453
# Economics+and+Public+Finance 1326
# Economics+and+Public+Finance 1326
# Housing+and+Community+Development 1007
# Housing+and+Community+Development 1007
# Water+Resources+Development 552
# Water+Resources+Development 552

# %%
for k, v in d.items():
    for x in range(len(d[k])):
        d[k][x] = {d[k][x]:d2[k][x]}

# %%
d
# Out:
# {'Health': [{'114th Congress (2015-2016)': 'H.R.34'},
#   {'114th Congress (2015-2016)': 'H.R.6'},
#   {'116th Congress (2019-2020)': 'H.R.3558'},
#   {'115th Congress (2017-2018)': 'H.R.5806'},
#   {'114th Congress (2015-2016)': 'S.674'},
#   {'114th Congress (2015-2016)': 'H.R.3652'},
#   {'117th Congress (2021-2022)': 'S.2837'},
#   {'115th Congress (2017-2018)': 'H.R.5598'},
#   {'115th Congress (2017-2018)': 'H.R.4710'},
#   {'112th Congress (2011-2012)': 'H.R.2674'},
#   {'116th Congress (2019-2020)': 'H.R.1559'},
#   {'117th Congress (2021-2022)': 'H.R.7097'},
#   {'116th Congress (2019-2020)': 'H.R.8767'},
#   {'117th Congress (2021-2022)': 'H.R.1859'},
#   {'115th Congress (2017-2018)': 'H.R.3834'},
#   {'117th Congress (2021-2022)': 'H.R.4965'},
#   {'117th Congress (2021-2022)': 'S.2683'},
#   {'117th Congress (2021-2022)': 'H.R.7232'},
#   {'117th Congress (2021-2022)': 'H.R.7116'},
#   {'116th Congress (2019-2020)': 'H.R.8736'},
#   {'114th Congress (2015-2016)': 'S.2423'},
#   {'113th Congress (2013-2014)': 'S.806'},
#   {'112th Congress (2011-2012)': 'S.733'},
#   {'114th Congress (2015-2016)': 'S.506'},
#   {'115th Congress (2017-2018)': 'S.1304'},
#   {'117th Congress (2021-2022)': 'S.3440'},
#   {'114th Congress (2015-2016)': 'H.R.3315'},
#   {'114th Congress (2015-2016)': 'H.R.2898'},
#   {'117th Congress (2021-2022)': 'S.2185'},
#   {'117th Congress (2021-2022)': 'S.2286'},
#   {'116th Congress (2019-2020)': 'H.R.5302'},
#   {'115th Congress (2017-2018)': 'H.R.2799'},
#   {'114th Congress (2015-2016)': 'H.R.5159'},
#   {'116th Congress (2019-2020)': 'S.2718'},
#   {'116th Congress (2019-2020)': 'H.R.4891'},
#   {'116th Congress (2019-2020)': 'H.R.8166'},
#   {'114th Congress (2015-2016)': 'S.2902'},
#   {'114th Congress (2015-2016)': 'S.2488'},
#   {'115th Congress (2017-2018)': 'H.R.5584'},
#   {'115th Congress (2017-2018)': 'S.703'},
#   {'114th Congress (2015-2016)': 'H.R.3756'},
#   {'116th Congress (2019-2020)': 'H.R.8217'},
#   {'114th Congress (2015-2016)': 'S.612'},
#   {'113th Congress (2013-2014)': 'S.566'},
#   {'113th Congress (2013-2014)': 'H.R.1153'},
#   {'116th Congress (2019-2020)': 'H.R.5217'},
#   {'116th Congress (2019-2020)': 'H.R.1048'},
#   {'114th Congress (2015-2016)': 'H.R.4686'},
#   {'114th Congress (2015-2016)': 'S.1694'},
#   {'115th Congress (2017-2018)': 'S.714'},
#   {'116th Congress (2019-2020)': 'H.R.6684'}]}

# %% [markdown]
# ## Roll Call Srape
# =================================================================================

# %% [markdown]
# # Pulling data from individual page

# %% [markdown]
# Pulling data from senate vote #134

# %% [markdown]
# response = requests.get('https://www.govtrack.us/congress/votes/117-2022/s134')

# %% [markdown]
# soup = BS(response.text)

# %% [markdown]
# print(soup.prettify())

# %% [markdown]
# title = soup.find('h1').text.replace('\n  ', '').replace('\n', '')
# title

# %% [markdown]
# date = soup.find('div', attrs={'style':'margin: 2px 0 16px 0; font-size: 12px; font-weight: normal; color: black; line-height: 125%; padding-bottom: 6px; border-bottom: 1px solid #CCA;'}).text.replace('\n  ', '').replace('.\n', '')
# date

# %% [markdown]
# votes_df = pd.read_html('https://www.govtrack.us/congress/votes/117-2022/s134')[0].drop(columns='All Votes').rename(columns={'Unnamed: 0':'Votes', 'All Votes.1':'All Votes'})
# votes_df

# %% [markdown]
# vote_result = soup.find('p', attrs={'style':'margin: 1em 0 0 0; font: 12px/20px serif;'}).text.replace('\n        ','').replace('\n',' ').replace('  Source: senate.gov.     ','').replace('MajorityRequired', 'Majority Required')
# vote_result

# %% [markdown]
# pop_prop = soup.find('p', attrs={'style':'margin: 0; font: 12px/20px serif;'}).text.replace('\n                   ','').replace('\n               ','')
# pop_prop

# %% [markdown]
# soup.find_all('table', attrs={'class':'vote-list stats'})

# %% [markdown]
# table = str(soup.find_all('table', attrs={'class':'vote-list stats'}))

# %% [markdown]
# states = re.findall('voter_group_1="([A-Z][a-z]+|[A-Z][a-z]+ [A-Z][a-z]+)" voter_group_2=', table)
# print(len(states))
# states

# %% [markdown]
# senators = re.findall('#444">([A-Z][a-z]+.+[A-Z][a-z]+)</a>', table)
# print(len(senators))
# senators

# %% [markdown]
# roll_call = re.findall('voter_group_0="([A-Z][a-z]{2})" voter_group_1', table)
# print(len(roll_call))
# roll_call

# %% [markdown]
# party = re.findall('voter_group_2="([A-Z][a-z]+)" voter_sort_1=', table)
# print(len(party))
# party

# %% [markdown]
# c117_2022_s134 = pd.DataFrame(senators, states).reset_index().rename(columns={'index':'States', 0:'Senators'})
# c117_2022_s134['Roll Call'] = roll_call
# c117_2022_s134['Party'] = party
# c117_2022_s134

# %% [markdown]
# type(soup)

# %% [markdown]
# print(title)
# print('------------------------------------------------------------------------------------------------------------')
# print(date)
# print('------------------------------------------------------------------------------------------------------------')
# print(vote_result)
# print('------------------------------------------------------------------------------------------------------------')
# print(pop_prop)
# display(votes_df)
# display(c117_2022_s134)

# %% [markdown]
# c117_2022_s134['Decision'] = title
# c117_2022_s134['Introduced'] = date
# c117_2022_s134['Result'] = vote_result
# c117_2022_s134['Proportion'] = pop_prop
# c117_2022_s134

# %% [markdown]
# Pulling data from senate vote #133

# %% [markdown]
# response = requests.get('https://www.govtrack.us/congress/votes/117-2022/s133')

# %% [markdown]
# soup = BS(response.text)

# %% [markdown]
# title = soup.find('h1').text.replace('\n  ', '').replace('\n', '')

# %% [markdown]
# date = soup.find('div', attrs={'style':'margin: 2px 0 16px 0; font-size: 12px; font-weight: normal; color: black; line-height: 125%; padding-bottom: 6px; border-bottom: 1px solid #CCA;'}).text.replace('\n  ', '').replace('.\n', '')

# %% [markdown]
# votes_df = pd.read_html('https://www.govtrack.us/congress/votes/117-2022/s133')[0].drop(columns='All Votes').rename(columns={'Unnamed: 0':'Votes', 'All Votes.1':'All Votes'})

# %% [markdown]
# vote_result = soup.find('p', attrs={'style':'margin: 1em 0 0 0; font: 12px/20px serif;'}).text.replace('\n        ','').replace('\n',' ').replace('  Source: senate.gov.     ','').replace('MajorityRequired', 'Majority Required')

# %% [markdown]
# pop_prop = soup.find('p', attrs={'style':'margin: 0; font: 12px/20px serif;'}).text.replace('\n                   ','').replace('\n               ','')

# %% [markdown]
# soup.find_all('table', attrs={'class':'vote-list stats'})

# %% [markdown]
# table = str(soup.find_all('table', attrs={'class':'vote-list stats'}))

# %% [markdown]
# states = re.findall('voter_group_1="([A-Z][a-z]+|[A-Z][a-z]+ [A-Z][a-z]+)" voter_group_2=', table)

# %% [markdown]
# senators = re.findall('#444">([A-Z][a-z]+.+[A-Z][a-z]+)</a>', table)

# %% [markdown]
# roll_call = re.findall('voter_group_0="([A-Z][a-z]{2})" voter_group_1', table)

# %% [markdown]
# party = re.findall('voter_group_2="([A-Z][a-z]+)" voter_sort_1=', table)

# %% [markdown]
# c117_2022_s133 = pd.DataFrame(senators, states).reset_index().rename(columns={'index':'States', 0:'Senators'})
# c117_2022_s133['Roll Call'] = roll_call
# c117_2022_s133['Party'] = party
# c117_2022_s133

# %% [markdown]
# print(title)
# print('------------------------------------------------------------------------------------------------------------')
# print(date)
# print('------------------------------------------------------------------------------------------------------------')
# print(vote_result)
# print('------------------------------------------------------------------------------------------------------------')
# print(pop_prop)
# display(votes_df)
# display(c117_2022_s133)

# %% [markdown]
# c117_2022_s133['Decision'] = title
# c117_2022_s133['Introduced'] = date
# c117_2022_s133['Result'] = vote_result
# c117_2022_s133['Proportion'] = pop_prop
# c117_2022_s133

# %% [markdown]
# Troubleshooting errors related to Vice President

# %% [markdown]
# response = requests.get('https://www.govtrack.us/congress/votes/117-2022/s115')

# %% [markdown]
# soup = BS(response.text)

# %% [markdown]
# print(soup.prettify())

# %% [markdown]
# soup.find_all('table', attrs={'class':'vote-list stats'})

# %% [markdown]
# table = str(soup.find_all('table', attrs={'class':'vote-list stats'}))

# %% [markdown]
# table.find('Kamala')

# %% [markdown]
# table[11500:12800]

# %% [markdown]
# states = re.findall('voter_group_1="([A-Z][a-z]+|[A-Z][a-z]+ [A-Z][a-z]+|The Vice President)" voter_group_2=', table)
# print(len(states))
# states

# %% [markdown]
# senators = re.findall('#444">([A-Z][a-z]+.+[A-Z][a-z]+)</a>', table)
# print(len(senators))
# senators

# %% [markdown]
# roll_call = re.findall('voter_group_0="([A-Z][a-z]{2})" voter_group_1', table)
# print(len(roll_call))
# roll_call

# %% [markdown]
# party = re.findall('voter_group_2="([A-Z][a-z]+|Vice President)" voter_sort_1=', table)
# print(len(party))
# party

# %% [markdown]
# c117_2022_s115 = pd.DataFrame(senators, states).reset_index().rename(columns={'index':'States', 0:'Senators'})
# c117_2022_s115['Roll Call'] = roll_call
# c117_2022_s115['Party'] = party
# c117_2022_s115

# %% [markdown]
# print(title)
# print('------------------------------------------------------------------------------------------------------------')
# print(date)
# print('------------------------------------------------------------------------------------------------------------')
# print(vote_result)
# print('------------------------------------------------------------------------------------------------------------')
# print(pop_prop)
# display(votes_df)
# display(c117_2022_s134)

# %% [markdown]
# Troubleshooting errors related to roll_call

# %% [markdown]
# response = requests.get('https://www.govtrack.us/congress/votes/117-2022/s55')
# soup = BS(response.text)
# table = str(soup.find_all('table', attrs={'class':'vote-list stats'}))
# soup.find_all('table', attrs={'class':'vote-list stats'})

# %% [markdown]
# re.findall('voter_group_0="(Yea|Nay|Not Voting|Present)" voter_group_1', table)

# %% [markdown]
# # User-defined function to test each senate vote #

# %% [markdown]
# def sen_vote_df(c, y, x, s_o_h='s'):
#     URL = f'https://www.govtrack.us/congress/votes/{c}-{y}/{s_o_h}{x}'
#     response = requests.get(URL)
#     soup = BS(response.text)
#     title = soup.find('h1').text.replace('\n  ', '').replace('\n', '')
#     date = soup.find('div', attrs={'style':'margin: 2px 0 16px 0; font-size: 12px; font-weight: normal; color: black; line-height: 125%; padding-bottom: 6px; border-bottom: 1px solid #CCA;'}).text.replace('\n  ', '').replace('.\n', '')
#     vote_result = soup.find('p', attrs={'style':'margin: 1em 0 0 0; font: 12px/20px serif;'}).text.replace('\n        ','').replace('\n',' ').replace('  Source: senate.gov.     ','').replace('MajorityRequired', 'Majority Required')
#     pop_prop = soup.find('p', attrs={'style':'margin: 0; font: 12px/20px serif;'}).text.replace('\n                   ','').replace('\n               ','')
#     table = str(soup.find_all('table', attrs={'class':'vote-list stats'}))
#     states = re.findall('voter_group_1="([A-Z][a-z]+|[A-Z][a-z]+ [A-Z][a-z]+|The Vice President)" voter_group_2=', table)
#     senators = re.findall('#444">([A-Z][a-z]+.+[A-Z][a-z]+)</a>', table)
#     roll_call = re.findall('voter_group_0="(Yea|Nay|Not Voting|Present|Guilty|Not Guilty)" voter_group_1', table)
#     party = re.findall('voter_group_2="([A-Z][a-z]+|Vice President)" voter_sort_1=', table)
#     df = pd.DataFrame(senators, states).reset_index().rename(columns={'index':'States', 0:'Senators'})
#     df['Roll Call'] = roll_call
#     df['Party'] = party
#     df['Decision'] = title
#     df['Introduced'] = date
#     df['Result'] = vote_result
#     df['Proportion'] = pop_prop
#     df.reset_index()
#     display(df)

# %% [markdown]
# # Iterating through senate votes

# %% [markdown]
# Way to test code efficacy one year at a time

# %% [markdown]
# #con_years = ['100-1987','100-1988','101-1989','101-1990','102-1991','102-1992','103-1993','103-1994','104-1995','104-1996','105-1997','105-1998','106-1999','106-2000','107-2001','107-2002','108-2003','108-2004','109-2005','109-2006','110-2007','110-2008','111-2009','111-2010','112-2011','112-2012','113-2013','113-2014','114-2015','114-2016','115-2017','115-2018','116-2019','116-2020','117-2021','117-2022']
# congress = '116'
# year = '2020'
#
# vote_no = 1
# URL = f'https://www.govtrack.us/congress/votes/{congress}-{year}/s{vote_no}'
# one_year_df = pd.DataFrame()
#
# while requests.get(URL).status_code == 200:
#     response = requests.get(URL)
#     # code pertinent to individual page goes here v
#     try:
#         soup = BS(response.text)
#         title = soup.find('h1').text.replace('\n  ', '').replace('\n', '')
#         date = soup.find('div', attrs={'style':'margin: 2px 0 16px 0; font-size: 12px; font-weight: normal; color: black; line-height: 125%; padding-bottom: 6px; border-bottom: 1px solid #CCA;'}).text.replace('\n  ', '').replace('.\n', '')
#         vote_result = soup.find('p', attrs={'style':'margin: 1em 0 0 0; font: 12px/20px serif;'}).text.replace('\n        ','').replace('\n',' ').replace('  Source: senate.gov.     ','').replace('MajorityRequired', 'Majority Required')
#         pop_prop = soup.find('p', attrs={'style':'margin: 0; font: 12px/20px serif;'}).text.replace('\n                   ','').replace('\n               ','')
#         table = str(soup.find_all('table', attrs={'class':'vote-list stats'}))
#         states = re.findall('voter_group_1="([A-Z][a-z]+|[A-Z][a-z]+ [A-Z][a-z]+|The Vice President)" voter_group_2=', table)
#         senators = re.findall('#444">([A-Z][a-z]+.+[A-Z][a-z]+)</a>', table)
#         roll_call = re.findall('voter_group_0="(Yea|Nay|Not Voting|Present|Guilty|Not Guilty)" voter_group_1', table)
#         party = re.findall('voter_group_2="([A-Z][a-z]+|Vice President)" voter_sort_1=', table)
#         df = pd.DataFrame(senators, states).reset_index().rename(columns={'index':'States', 0:'Senators'})
#         df['Roll Call'] = roll_call
#         df['Party'] = party
#         df['Decision'] = title
#         df['Introduced'] = date
#         df['Result'] = vote_result
#         df['Proportion'] = pop_prop
#         one_year_df = pd.concat([one_year_df, df], axis=0)
#         print(f'SUCCESS {vote_no}')
#     except:
#         print(f'Operation unsuccessful on senate vote {vote_no}')
#     # code pertinent to individual page goes here ^
#     vote_no += 1
#     URL = f'https://www.govtrack.us/congress/votes/{congress}-{year}/s{vote_no}'
#
# one_year_df

# %% [markdown]
# Getting every roll call at once from multiple congresses/years

# %%
con_years = ['112-2012','113-2013','113-2014','114-2015','114-2016','115-2017','115-2018','116-2019','116-2020','117-2021','117-2022']
filter_df = pd.DataFrame()
for con_year in tqdm(con_years):
    vote_no = 1
    URL = f'https://www.govtrack.us/congress/votes/{con_year}/s{vote_no}'
    while requests.get(URL).status_code == 200:
        response = requests.get(URL)
        # code pertinent to individual page goes here v
        try:
            soup = BS(response.text)
            title = soup.find('h1').text.replace('\n  ', '').replace('\n', '')
            date = soup.find('div', attrs={'style':'margin: 2px 0 16px 0; font-size: 12px; font-weight: normal; color: black; line-height: 125%; padding-bottom: 6px; border-bottom: 1px solid #CCA;'}).text.replace('\n  ', '').replace('.\n', '')
            vote_result = soup.find('p', attrs={'style':'margin: 1em 0 0 0; font: 12px/20px serif;'}).text.replace('\n        ','').replace('\n',' ').replace('  Source: senate.gov.     ','').replace('MajorityRequired', 'Majority Required')
            pop_prop = soup.find('p', attrs={'style':'margin: 0; font: 12px/20px serif;'}).text.replace('\n                   ','').replace('\n               ','')
            table = str(soup.find_all('table', attrs={'class':'vote-list stats'}))
            states = re.findall('voter_group_1="([A-Z][a-z]+|[A-Z][a-z]+ [A-Z][a-z]+|The Vice President)" voter_group_2=', table)
            senators = re.findall('#444">([A-Z][a-z]+.+[A-Z][a-z]+)</a>', table)
            roll_call = re.findall('voter_group_0="(Yea|Nay|Not Voting|Present|Guilty|Not Guilty)" voter_group_1', table)
            party = re.findall('voter_group_2="([A-Z][a-z]+|Vice President)" voter_sort_1=', table)
            df = pd.DataFrame(senators, states).reset_index().rename(columns={'index':'States', 0:'Senators'})
            df['Roll Call'] = roll_call
            df['Party'] = party
            df['Decision'] = title
            df['Introduced'] = date
            df['Result'] = vote_result
            df['Proportion'] = pop_prop
            df['con_year'] = f'{con_year}'
            filter_df = pd.concat([filter_df, df], axis=0)
        except:
            print(f'Unsuccessful on {con_year}, senate vote #{vote_no}')
        # code pertinent to individual page goes here ^
        vote_no += 1
        URL = f'https://www.govtrack.us/congress/votes/{con_year}/s{vote_no}'
    print(f'{con_year}: DONE')
# Out:
#   0%|          | 0/11 [00:00<?, ?it/s]
# 112-2012: DONE
# 113-2013: DONE
# 113-2014: DONE
# 114-2015: DONE
# 114-2016: DONE
# 115-2017: DONE
# 115-2018: DONE
# 116-2019: DONE
# Unsuccessful on 116-2020, senate vote #216
# 116-2020: DONE
# 117-2021: DONE
# 117-2022: DONE

# %% [markdown]
# # Roll Call EDA

# %% [markdown]
# filter_df = pd.read_csv('data/voting_records.csv')

# %%
filter_df
# Out:
#         States            Senators   Roll Call       Party  \
# 0       Hawaii       Akaka, Daniel         Yea    Democrat
# 1      Montana         Baucus, Max         Yea    Democrat
# 2       Alaska        Begich, Mark         Yea    Democrat
# 3     Colorado     Bennet, Michael         Yea    Democrat
# 4   New Mexico      Bingaman, Jeff         Yea    Democrat
# ..         ...                 ...         ...         ...
# 95    Delaware  Coons, Christopher  Not Voting    Democrat
# 96  Washington       Murray, Patty  Not Voting    Democrat
# 97    Michigan        Peters, Gary  Not Voting    Democrat
# 98      Kansas        Moran, Jerry  Not Voting  Republican
# 99      Alaska     Murkowski, Lisa  Not Voting  Republican
#
#                                              Decision  \
# 0   On the Nomination PN468: John M. Gerrard, of N...
# 1   On the Nomination PN468: John M. Gerrard, of N...
# 2   On the Nomination PN468: John M. Gerrard, of N...
# 3   On the Nomination PN468: John M. Gerrard, of N...
# 4   On the Nomination PN468: John M. Gerrard, of N...
# ..                                                ...
# 95  Motion to Invoke Cloture: Lael Brainard to be ...
# 96  Motion to Invoke Cloture: Lael Brainard to be ...
# 97  Motion to Invoke Cloture: Lael Brainard to be ...
# 98  Motion to Invoke Cloture: Lael Brainard to be ...
# 99  Motion to Invoke Cloture: Lael Brainard to be ...
#
#                       Introduced  \
# 0   Jan 23, 2012 at 5:32 p.m. ET
# 1   Jan 23, 2012 at 5:32 p.m. ET
# 2   Jan 23, 2012 at 5:32 p.m. ET
# 3   Jan 23, 2012 at 5:32 p.m. ET
# 4   Jan 23, 2012 at 5:32 p.m. ET
# ..                           ...
# 95  Apr 25, 2022 at 5:31 p.m. ET
# 96  Apr 25, 2022 at 5:31 p.m. ET
# 97  Apr 25, 2022 at 5:31 p.m. ET
# 98  Apr 25, 2022 at 5:31 p.m. ET
# 99  Apr 25, 2022 at 5:31 p.m. ET
#
#                                                Result  \
# 0     Nomination Confirmed. Simple Majority Required.
# 1     Nomination Confirmed. Simple Majority Required.
# 2     Nomination Confirmed. Simple Majority Required.
# 3     Nomination Confirmed. Simple Majority Required.
# 4     Nomination Confirmed. Simple Majority Required.
# ..                                                ...
# 95  Cloture Motion Agreed to. Simple Majority Requ...
# 96  Cloture Motion Agreed to. Simple Majority Requ...
# 97  Cloture Motion Agreed to. Simple Majority Requ...
# 98  Cloture Motion Agreed to. Simple Majority Requ...
# 99  Cloture Motion Agreed to. Simple Majority Requ...
#
#                                            Proportion  con_year
# 0   The Yea votes represented 78% of the country’s...  112-2012
# 1   The Yea votes represented 78% of the country’s...  112-2012
# 2   The Yea votes represented 78% of the country’s...  112-2012
# 3   The Yea votes represented 78% of the country’s...  112-2012
# 4   The Yea votes represented 78% of the country’s...  112-2012
# ..                                                ...       ...
# 95  The Yea votes represented 58% of the country’s...  117-2022
# 96  The Yea votes represented 58% of the country’s...  117-2022
# 97  The Yea votes represented 58% of the country’s...  117-2022
# 98  The Yea votes represented 58% of the country’s...  117-2022
# 99  The Yea votes represented 58% of the country’s...  117-2022
#
# [339110 rows x 9 columns]

# %%
def leg_list(x):
    return list(re.findall('S. \d+|H.R. \d+|S.Res. \d+|H.Res. \d+|S.Con.Res. \d+|H.Con.Res. \d+|S.J.Res. \d+|H.J.Res. \d+', x))
filter_df['Relevant Bills'] = filter_df['Decision'].apply(leg_list)

# %%
filter_df = filter_df[filter_df['Relevant Bills'].apply(lambda x: len(x) != 0)].reset_index().drop(columns=['index'])
filter_df
# Out:
#                 States           Senators Roll Call       Party  \
# 0        West Virginia       Manchin, Joe       Yea    Democrat
# 1             Nebraska        Nelson, Ben       Yea    Democrat
# 2            Tennessee   Alexander, Lamar       Yea  Republican
# 3        New Hampshire      Ayotte, Kelly       Yea  Republican
# 4              Wyoming     Barrasso, John       Yea  Republican
# ...                ...                ...       ...         ...
# 150296  North Carolina       Tillis, Thom       Yea  Republican
# 150297    Pennsylvania        Toomey, Pat       Yea  Republican
# 150298         Alabama  Tuberville, Tommy       Yea  Republican
# 150299     Mississippi      Wicker, Roger       Yea  Republican
# 150300         Indiana        Young, Todd       Yea  Republican
#
#                                                 Decision  \
# 0                   On the Motion to Proceed H.J.Res. 98
# 1                   On the Motion to Proceed H.J.Res. 98
# 2                   On the Motion to Proceed H.J.Res. 98
# 3                   On the Motion to Proceed H.J.Res. 98
# 4                   On the Motion to Proceed H.J.Res. 98
# ...                                                  ...
# 150296  H.R. 6968: Ending Importation of Russian Oil Act
# 150297  H.R. 6968: Ending Importation of Russian Oil Act
# 150298  H.R. 6968: Ending Importation of Russian Oil Act
# 150299  H.R. 6968: Ending Importation of Russian Oil Act
# 150300  H.R. 6968: Ending Importation of Russian Oil Act
#
#                                                Introduced  \
# 0                           Jan 26, 2012 at 11:57 a.m. ET
# 1                           Jan 26, 2012 at 11:57 a.m. ET
# 2                           Jan 26, 2012 at 11:57 a.m. ET
# 3                           Jan 26, 2012 at 11:57 a.m. ET
# 4                           Jan 26, 2012 at 11:57 a.m. ET
# ...                                                   ...
# 150296  Apr 7, 2022 at 10:58 a.m. ET.  On Passage of t...
# 150297  Apr 7, 2022 at 10:58 a.m. ET.  On Passage of t...
# 150298  Apr 7, 2022 at 10:58 a.m. ET.  On Passage of t...
# 150299  Apr 7, 2022 at 10:58 a.m. ET.  On Passage of t...
# 150300  Apr 7, 2022 at 10:58 a.m. ET.  On Passage of t...
#
#                                                    Result  \
# 0       Motion to Proceed Rejected. Simple Majority Re...
# 1       Motion to Proceed Rejected. Simple Majority Re...
# 2       Motion to Proceed Rejected. Simple Majority Re...
# 3       Motion to Proceed Rejected. Simple Majority Re...
# 4       Motion to Proceed Rejected. Simple Majority Re...
# ...                                                   ...
# 150296             Bill Passed. Simple Majority Required.
# 150297             Bill Passed. Simple Majority Required.
# 150298             Bill Passed. Simple Majority Required.
# 150299             Bill Passed. Simple Majority Required.
# 150300             Bill Passed. Simple Majority Required.
#
#                                                Proportion  con_year  \
# 0       The Nay votes represented 58% of the country’s...  112-2012
# 1       The Nay votes represented 58% of the country’s...  112-2012
# 2       The Nay votes represented 58% of the country’s...  112-2012
# 3       The Nay votes represented 58% of the country’s...  112-2012
# 4       The Nay votes represented 58% of the country’s...  112-2012
# ...                                                   ...       ...
# 150296  The Yea votes represented 100% of the country’...  117-2022
# 150297  The Yea votes represented 100% of the country’...  117-2022
# 150298  The Yea votes represented 100% of the country’...  117-2022
# 150299  The Yea votes represented 100% of the country’...  117-2022
# 150300  The Yea votes represented 100% of the country’...  117-2022
#
#        Relevant Bills
# 0       [H.J.Res. 98]
# 1       [H.J.Res. 98]
# 2       [H.J.Res. 98]
# 3       [H.J.Res. 98]
# 4       [H.J.Res. 98]
# ...               ...
# 150296    [H.R. 6968]
# 150297    [H.R. 6968]
# 150298    [H.R. 6968]
# 150299    [H.R. 6968]
# 150300    [H.R. 6968]
#
# [150301 rows x 10 columns]

# %%
for index,row in tqdm(filter_df.iterrows()):
    list_len = len(filter_df.loc[index, 'Relevant Bills'])
    for x in range(list_len):
        bill_list = filter_df.loc[index, 'Relevant Bills']
        bill_list[x] = bill_list[x].replace(' ','')
# Out:
# 0it [00:00, ?it/s]

# %%
filter_df
# Out:
#                 States           Senators Roll Call       Party  \
# 0        West Virginia       Manchin, Joe       Yea    Democrat
# 1             Nebraska        Nelson, Ben       Yea    Democrat
# 2            Tennessee   Alexander, Lamar       Yea  Republican
# 3        New Hampshire      Ayotte, Kelly       Yea  Republican
# 4              Wyoming     Barrasso, John       Yea  Republican
# ...                ...                ...       ...         ...
# 150296  North Carolina       Tillis, Thom       Yea  Republican
# 150297    Pennsylvania        Toomey, Pat       Yea  Republican
# 150298         Alabama  Tuberville, Tommy       Yea  Republican
# 150299     Mississippi      Wicker, Roger       Yea  Republican
# 150300         Indiana        Young, Todd       Yea  Republican
#
#                                                 Decision  \
# 0                   On the Motion to Proceed H.J.Res. 98
# 1                   On the Motion to Proceed H.J.Res. 98
# 2                   On the Motion to Proceed H.J.Res. 98
# 3                   On the Motion to Proceed H.J.Res. 98
# 4                   On the Motion to Proceed H.J.Res. 98
# ...                                                  ...
# 150296  H.R. 6968: Ending Importation of Russian Oil Act
# 150297  H.R. 6968: Ending Importation of Russian Oil Act
# 150298  H.R. 6968: Ending Importation of Russian Oil Act
# 150299  H.R. 6968: Ending Importation of Russian Oil Act
# 150300  H.R. 6968: Ending Importation of Russian Oil Act
#
#                                                Introduced  \
# 0                           Jan 26, 2012 at 11:57 a.m. ET
# 1                           Jan 26, 2012 at 11:57 a.m. ET
# 2                           Jan 26, 2012 at 11:57 a.m. ET
# 3                           Jan 26, 2012 at 11:57 a.m. ET
# 4                           Jan 26, 2012 at 11:57 a.m. ET
# ...                                                   ...
# 150296  Apr 7, 2022 at 10:58 a.m. ET.  On Passage of t...
# 150297  Apr 7, 2022 at 10:58 a.m. ET.  On Passage of t...
# 150298  Apr 7, 2022 at 10:58 a.m. ET.  On Passage of t...
# 150299  Apr 7, 2022 at 10:58 a.m. ET.  On Passage of t...
# 150300  Apr 7, 2022 at 10:58 a.m. ET.  On Passage of t...
#
#                                                    Result  \
# 0       Motion to Proceed Rejected. Simple Majority Re...
# 1       Motion to Proceed Rejected. Simple Majority Re...
# 2       Motion to Proceed Rejected. Simple Majority Re...
# 3       Motion to Proceed Rejected. Simple Majority Re...
# 4       Motion to Proceed Rejected. Simple Majority Re...
# ...                                                   ...
# 150296             Bill Passed. Simple Majority Required.
# 150297             Bill Passed. Simple Majority Required.
# 150298             Bill Passed. Simple Majority Required.
# 150299             Bill Passed. Simple Majority Required.
# 150300             Bill Passed. Simple Majority Required.
#
#                                                Proportion  con_year  \
# 0       The Nay votes represented 58% of the country’s...  112-2012
# 1       The Nay votes represented 58% of the country’s...  112-2012
# 2       The Nay votes represented 58% of the country’s...  112-2012
# 3       The Nay votes represented 58% of the country’s...  112-2012
# 4       The Nay votes represented 58% of the country’s...  112-2012
# ...                                                   ...       ...
# 150296  The Yea votes represented 100% of the country’...  117-2022
# 150297  The Yea votes represented 100% of the country’...  117-2022
# 150298  The Yea votes represented 100% of the country’...  117-2022
# 150299  The Yea votes represented 100% of the country’...  117-2022
# 150300  The Yea votes represented 100% of the country’...  117-2022
#
#        Relevant Bills
# 0        [H.J.Res.98]
# 1        [H.J.Res.98]
# 2        [H.J.Res.98]
# 3        [H.J.Res.98]
# 4        [H.J.Res.98]
# ...               ...
# 150296     [H.R.6968]
# 150297     [H.R.6968]
# 150298     [H.R.6968]
# 150299     [H.R.6968]
# 150300     [H.R.6968]
#
# [150301 rows x 10 columns]

# %%
for index,value in tqdm(filter_df['con_year'].iteritems()):
    if value == '112-2012':
        filter_df.loc[index, 'Congress'] = r'112th Congress (2011-2012)'
    if (value == '113-2013') | (value == '113-2014'):
        filter_df.loc[index, 'Congress'] = r'113th Congress (2013-2014)'
    if (value == '114-2015') | (value == '114-2016'):
        filter_df.loc[index, 'Congress'] = r'114th Congress (2015-2016)'
    if (value == '115-2017') | (value == '115-2018'):
        filter_df.loc[index, 'Congress'] = r'115th Congress (2017-2018)'
    if (value == '116-2019') | (value == '116-2020'):
        filter_df.loc[index, 'Congress'] = r'116th Congress (2019-2020)'
    if (value == '117-2021') | (value == '117-2022'):
        filter_df.loc[index, 'Congress'] = r'117th Congress (2021-2022)'
# Out:
# 0it [00:00, ?it/s]

# %%
for index,row in tqdm(filter_df.iterrows()):
    list_len = len(filter_df.loc[index, 'Relevant Bills'])
    for x in range(list_len):
        bill_list = filter_df.loc[index, 'Relevant Bills']
        bill_list[x] = {filter_df.loc[index, 'Congress']:bill_list[x]}
# Out:
# 0it [00:00, ?it/s]

# %%
for index,value in tqdm(filter_df.iterrows()):
    list_len = len(filter_df.loc[index, 'Relevant Bills'])
    for x in range(list_len):
        bill_list = filter_df.loc[index, 'Relevant Bills']
        if bill_list[x] in d['Health']:
            filter_df.loc[index, 'Policy Area'] = 'Health'
        if bill_list[x] in d['Public+Lands+and+Natural+Resources']:
            filter_df.loc[index, 'Policy Area'] = 'Public Lands and Natural Resources'
        if bill_list[x] in d['Agriculture+and+Food']:
            filter_df.loc[index, 'Policy Area'] = 'Agriculture and Food'
        if bill_list[x] in d['Economics+and+Public+Finance']:
            filter_df.loc[index, 'Policy Area'] = 'Economics and Public Finance'
        if bill_list[x] in d['Housing+and+Community+Development']:
            filter_df.loc[index, 'Policy Area'] = 'Housing and Community Development'
        if bill_list[x] in d['Water+Resources+Development']:
            filter_df.loc[index, 'Policy Area'] = 'Water Resources Development'
# Out:
# 0it [00:00, ?it/s]

# %%
filter_df = filter_df[filter_df['Policy Area'].notna()]
filter_df
# Out:
#                States          Senators   Roll Call        Party  \
# 0       West Virginia      Manchin, Joe         Yea     Democrat
# 1            Nebraska       Nelson, Ben         Yea     Democrat
# 2           Tennessee  Alexander, Lamar         Yea   Republican
# 3       New Hampshire     Ayotte, Kelly         Yea   Republican
# 4             Wyoming    Barrasso, John         Yea   Republican
# ...               ...               ...         ...          ...
# 149596        Vermont   Sanders, Bernie         Nay  Independent
# 149597           Utah      Romney, Mitt         Nay   Republican
# 149598       Illinois  Duckworth, Tammy  Not Voting     Democrat
# 149599     New Jersey     Menendez, Bob  Not Voting     Democrat
[{'117th Congress (2021-2022)': 'S.J.Res.37'}]
# 149600  [{'117th Congress (2021-2022)': 'S.J.Res.37'}]
#
#                           Congress                   Policy Area
# 0       112th Congress (2011-2012)  Economics and Public Finance
# 1       112th Congress (2011-2012)  Economics and Public Finance
# 2       112th Congress (2011-2012)  Economics and Public Finance
# 3       112th Congress (2011-2012)  Economics and Public Finance
# 4       112th Congress (2011-2012)  Economics and Public Finance
# ...                            ...                           ...
# 149596  117th Congress (2021-2022)                        Health
# 149597  117th Congress (2021-2022)                        Health
# 149598  117th Congress (2021-2022)                        Health
# 149599  117th Congress (2021-2022)                        Health
# 149600  117th Congress (2021-2022)                        Health
#
# [68204 rows x 12 columns]

# %%
filter_df['Policy Area'].unique()
# Out:
# array(['Economics and Public Finance', 'Health', 'Agriculture and Food',
#        'Public Lands and Natural Resources',
#        'Water Resources Development'], dtype=object)

# %%
for index,value in tqdm(filter_df['Policy Area'].iteritems()):
    if value == 'Health':
        filter_df.loc[index, 'Sector'] = 'Healthcare'
    if value == 'Public Lands and Natural Resources':
        filter_df.loc[index, 'Sector'] = 'Basic Materials'
    if value == 'Agriculture and Food':
        filter_df.loc[index, 'Sector'] = 'Consumer Defensive'
    if value == 'Economics and Public Finance':
        filter_df.loc[index, 'Sector'] = 'Financial Services'
    if value == 'Housing and Community Development':
        filter_df.loc[index, 'Sector'] = 'Industrials'
    if value == 'Water Resources Development':
        filter_df.loc[index, 'Sector'] = 'Utilities'
# Out:
# 0it [00:00, ?it/s]
# C:\Users\cocat\anaconda3\lib\site-packages\pandas\core\indexing.py:1684: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# C:\Users\cocat\anaconda3\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
votes = filter_df.reset_index().drop(columns=['index', 'con_year', 'Relevant Bills'])
votes
# Out:
#               States          Senators   Roll Call        Party  \
# 0      West Virginia      Manchin, Joe         Yea     Democrat
# 1           Nebraska       Nelson, Ben         Yea     Democrat
# 2          Tennessee  Alexander, Lamar         Yea   Republican
# 3      New Hampshire     Ayotte, Kelly         Yea   Republican
# 4            Wyoming    Barrasso, John         Yea   Republican
# ...              ...               ...         ...          ...
# 68199        Vermont   Sanders, Bernie         Nay  Independent
# 68200           Utah      Romney, Mitt         Nay   Republican
# 68201       Illinois  Duckworth, Tammy  Not Voting     Democrat
# 68202     New Jersey     Menendez, Bob  Not Voting     Democrat
# 68203  New Hampshire   Shaheen, Jeanne  Not Voting     Democrat
#
#                                                 Decision  \
# 0                   On the Motion to Proceed H.J.Res. 98
# 1                   On the Motion to Proceed H.J.Res. 98
# 2                   On the Motion to Proceed H.J.Res. 98
# 3                   On the Motion to Proceed H.J.Res. 98
# 4                   On the Motion to Proceed H.J.Res. 98
# ...                                                  ...
# 68199  S.J.Res. 37: A joint resolution providing for ...
# 68200  S.J.Res. 37: A joint resolution providing for ...
# 68201  S.J.Res. 37: A joint resolution providing for ...
# 68202  S.J.Res. 37: A joint resolution providing for ...
# 68203  S.J.Res. 37: A joint resolution providing for ...
#
#                                               Introduced  \
# 0                          Jan 26, 2012 at 11:57 a.m. ET
# 1                          Jan 26, 2012 at 11:57 a.m. ET
# 2                          Jan 26, 2012 at 11:57 a.m. ET
# 3                          Jan 26, 2012 at 11:57 a.m. ET
# 4                          Jan 26, 2012 at 11:57 a.m. ET
# ...                                                  ...
# 68199  Mar 15, 2022 at 5:30 p.m. ET.  On the Joint Re...
# 68200  Mar 15, 2022 at 5:30 p.m. ET.  On the Joint Re...
# 68201  Mar 15, 2022 at 5:30 p.m. ET.  On the Joint Re...
# 68202  Mar 15, 2022 at 5:30 p.m. ET.  On the Joint Re...
# 68203  Mar 15, 2022 at 5:30 p.m. ET.  On the Joint Re...
#
#                                                   Result  \
# 0      Motion to Proceed Rejected. Simple Majority Re...
# 1      Motion to Proceed Rejected. Simple Majority Re...
# 2      Motion to Proceed Rejected. Simple Majority Re...
# 3      Motion to Proceed Rejected. Simple Majority Re...
# 4      Motion to Proceed Rejected. Simple Majority Re...
# ...                                                  ...
# 68199  Joint Resolution Passed. Simple Majority Requi...
# 68200  Joint Resolution Passed. Simple Majority Requi...
# 68201  Joint Resolution Passed. Simple Majority Requi...
# 68202  Joint Resolution Passed. Simple Majority Requi...
# 68203  Joint Resolution Passed. Simple Majority Requi...
#
#                                               Proportion  \
# 0      The Nay votes represented 58% of the country’s...
# 1      The Nay votes represented 58% of the country’s...
# 2      The Nay votes represented 58% of the country’s...
# 3      The Nay votes represented 58% of the country’s...
# 4      The Nay votes represented 58% of the country’s...
# ...                                                  ...
# 68199  The Yea votes represented 48% of the country’s...
# 68200  The Yea votes represented 48% of the country’s...
# 68201  The Yea votes represented 48% of the country’s...
# 68202  The Yea votes represented 48% of the country’s...
# 68203  The Yea votes represented 48% of the country’s...
#
#                          Congress                   Policy Area  \
# 0      112th Congress (2011-2012)  Economics and Public Finance
# 1      112th Congress (2011-2012)  Economics and Public Finance
# 2      112th Congress (2011-2012)  Economics and Public Finance
# 3      112th Congress (2011-2012)  Economics and Public Finance
# 4      112th Congress (2011-2012)  Economics and Public Finance
# ...                           ...                           ...
# 68199  117th Congress (2021-2022)                        Health
# 68200  117th Congress (2021-2022)                        Health
# 68201  117th Congress (2021-2022)                        Health
# 68202  117th Congress (2021-2022)                        Health
# 68203  117th Congress (2021-2022)                        Health
#
#                    Sector
# 0      Financial Services
# 1      Financial Services
# 2      Financial Services
# 3      Financial Services
# 4      Financial Services
# ...                   ...
# 68199          Healthcare
# 68200          Healthcare
# 68201          Healthcare
# 68202          Healthcare
# 68203          Healthcare
#
# [68204 rows x 11 columns]

# %% [markdown]
# # Stock/Senator Merge

# %%
def leg_list(x):
    return re.search('S. \d+|H.R. \d+|S.Res. \d+|H.Res. \d+|S.Con.Res. \d+|H.Con.Res. \d+|S.J.Res. \d+|H.J.Res. \d+', x).group(0)
votes['Relevant Bill'] = votes['Decision'].apply(leg_list)

# %%
votes['Relevant Stocks Owned'] = [list() for x in range(len(votes.index))]

# %%
for index,row in tqdm(votes.iterrows()):
    if row.Senators in sen_stock_dict:
        stock_list = list(set(sector_dict[row.Sector]) & set(sen_stock_dict[row.Senators]))
        row['Relevant Stocks Owned'].extend(stock_list)
# Out:
# 0it [00:00, ?it/s]

# %%
votes = votes[votes['Relevant Stocks Owned'].apply(lambda x: len(x) != 0)].reset_index().drop(columns='index')

# %%
votes
# Out:
#               States             Senators   Roll Call        Party  \
# 0      West Virginia         Manchin, Joe         Yea     Democrat
# 1              Maine       Collins, Susan         Yea   Republican
#                    Sector Relevant Bill  \
# 0      Financial Services   H.J.Res. 98
# 1      Financial Services   H.J.Res. 98
# 2      Financial Services   H.J.Res. 98
# 3      Financial Services   H.J.Res. 98
# 4      Financial Services   H.J.Res. 98
# ...                   ...           ...
# 12733          Healthcare   S.J.Res. 37
# 12734          Healthcare   S.J.Res. 37
# 12735          Healthcare   S.J.Res. 37
# 12736          Healthcare   S.J.Res. 37
# 12737          Healthcare   S.J.Res. 37
#
#                                    Relevant Stocks Owned
# 0                                                 [HBAN]
# 1                     [WFC, AXP, PX, USB, AON, CFR, JPM]
# 2                                                  [KEY]
# 3                     [WFC, IVZ, MET, USB, PRU, WTW, BX]
# 4        [WFC, C, AIG, DFS, V, PYPL, COF, BAM, SYF, BLK]
# ...                                                  ...
# 12733                                              [JNJ]
# 12734                                             [HALO]
# 12735  [UNH, DHR, ABBV, BIIB, REGN, ILMN, SYK, BMY, A...
# 12736                        [NVS, WAT, GILD, TMO, TEVA]
# 12737                                    [WBA, ABT, JNJ]
#
# [12738 rows x 13 columns]

# %% [markdown]
# votes.to_csv('../data/votes.csv')

# %% [markdown]
# # Adapting 'votes' for Tableau

# %%
votes
# Out:
#               States             Senators   Roll Call        Party  \
# 0      West Virginia         Manchin, Joe         Yea     Democrat
# 1              Maine       Collins, Susan         Yea   Republican
# 2            Wyoming        Enzi, Michael         Yea   Republican
# 3       North Dakota         Hoeven, John         Yea   Republican
# 4           Oklahoma          Inhofe, Jim         Yea   Republican
# ...              ...                  ...         ...          ...
# 12733       Maryland    Van Hollen, Chris         Nay     Democrat
# 12734       Virginia         Warner, Mark         Nay     Democrat
# 12735   Rhode Island  Whitehouse, Sheldon         Nay     Democrat
# 12736          Maine          King, Angus         Nay  Independent
# 12737       Illinois     Duckworth, Tammy  Not Voting     Democrat
#
#                                                 Decision  \
# 0                   On the Motion to Proceed H.J.Res. 98
# 1                   On the Motion to Proceed H.J.Res. 98
# 2                   On the Motion to Proceed H.J.Res. 98
# 3                   On the Motion to Proceed H.J.Res. 98
# 4                   On the Motion to Proceed H.J.Res. 98
# ...                                                  ...
# 12733  S.J.Res. 37: A joint resolution providing for ...
# 12734  S.J.Res. 37: A joint resolution providing for ...
# 12735  S.J.Res. 37: A joint resolution providing for ...
# 12736  S.J.Res. 37: A joint resolution providing for ...
# 12737  S.J.Res. 37: A joint resolution providing for ...
#
#                                               Introduced  \
# 0                          Jan 26, 2012 at 11:57 a.m. ET
# 1                          Jan 26, 2012 at 11:57 a.m. ET
# 2                          Jan 26, 2012 at 11:57 a.m. ET
# 3                          Jan 26, 2012 at 11:57 a.m. ET
# 4                          Jan 26, 2012 at 11:57 a.m. ET
# ...                                                  ...
# 12733  Mar 15, 2022 at 5:30 p.m. ET.  On the Joint Re...
# 12734  Mar 15, 2022 at 5:30 p.m. ET.  On the Joint Re...
# 12735  Mar 15, 2022 at 5:30 p.m. ET.  On the Joint Re...
# 12736  Mar 15, 2022 at 5:30 p.m. ET.  On the Joint Re...
# 12737  Mar 15, 2022 at 5:30 p.m. ET.  On the Joint Re...
#
#                                                   Result  \
# 0      Motion to Proceed Rejected. Simple Majority Re...
# 1      Motion to Proceed Rejected. Simple Majority Re...
# 2      Motion to Proceed Rejected. Simple Majority Re...
# 3      Motion to Proceed Rejected. Simple Majority Re...
# 4      Motion to Proceed Rejected. Simple Majority Re...
# ...                                                  ...
# 12733  Joint Resolution Passed. Simple Majority Requi...
# 12734  Joint Resolution Passed. Simple Majority Requi...
# 12735  Joint Resolution Passed. Simple Majority Requi...
# 12736  Joint Resolution Passed. Simple Majority Requi...
# 12737  Joint Resolution Passed. Simple Majority Requi...
#
#                                               Proportion  \
# 0      The Nay votes represented 58% of the country’s...
# 1      The Nay votes represented 58% of the country’s...
# 2      The Nay votes represented 58% of the country’s...
# 3      The Nay votes represented 58% of the country’s...
# 4      The Nay votes represented 58% of the country’s...
# ...                                                  ...
# 12733  The Yea votes represented 48% of the country’s...
# 12734  The Yea votes represented 48% of the country’s...
# 12735  The Yea votes represented 48% of the country’s...
# 12736  The Yea votes represented 48% of the country’s...
# 12737  The Yea votes represented 48% of the country’s...
#
#                          Congress                   Policy Area  \
# 0      112th Congress (2011-2012)  Economics and Public Finance
# 1      112th Congress (2011-2012)  Economics and Public Finance
# 2      112th Congress (2011-2012)  Economics and Public Finance
# 3      112th Congress (2011-2012)  Economics and Public Finance
# 4      112th Congress (2011-2012)  Economics and Public Finance
# ...                           ...                           ...
# 12733  117th Congress (2021-2022)                        Health
# 12734  117th Congress (2021-2022)                        Health
# 12735  117th Congress (2021-2022)                        Health
# 12736  117th Congress (2021-2022)                        Health
# 12737  117th Congress (2021-2022)                        Health
#
#                    Sector Relevant Bill  \
# 0      Financial Services   H.J.Res. 98
# 1      Financial Services   H.J.Res. 98
# 2      Financial Services   H.J.Res. 98
# 3      Financial Services   H.J.Res. 98
# 4      Financial Services   H.J.Res. 98
# ...                   ...           ...
# 12733          Healthcare   S.J.Res. 37
# 12734          Healthcare   S.J.Res. 37
# 12735          Healthcare   S.J.Res. 37
# 12736          Healthcare   S.J.Res. 37
# 12737          Healthcare   S.J.Res. 37
#
#                                    Relevant Stocks Owned
# 0                                                 [HBAN]
# 1                     [WFC, AXP, PX, USB, AON, CFR, JPM]
# 2                                                  [KEY]
# 3                     [WFC, IVZ, MET, USB, PRU, WTW, BX]
# 4        [WFC, C, AIG, DFS, V, PYPL, COF, BAM, SYF, BLK]
# ...                                                  ...
# 12733                                              [JNJ]
# 12734                                             [HALO]
# 12735  [UNH, DHR, ABBV, BIIB, REGN, ILMN, SYK, BMY, A...
# 12736                        [NVS, WAT, GILD, TMO, TEVA]
# 12737                                    [WBA, ABT, JNJ]
#
# [12738 rows x 13 columns]

# %%
votes_ext = pd.DataFrame()
for index,value in tqdm(votes['Relevant Stocks Owned'].iteritems()):
    for x in value:
        d = {'States':votes.loc[index, 'States'], 'Senators':votes.loc[index, 'Senators'], 'Roll Call':votes.loc[index, 'Roll Call'], 'Party':votes.loc[index, 'Party'], 'Decision':votes.loc[index, 'Decision'], 'Introduced':votes.loc[index, 'Introduced'], 'Result':votes.loc[index, 'Result'], 'Proportion':votes.loc[index, 'Proportion'], 'Congress':votes.loc[index, 'Congress'], 'Policy Area':votes.loc[index, 'Policy Area'], 'Sector':votes.loc[index, 'Sector'], 'Relevant Bill':votes.loc[index, 'Relevant Bill'], 'Relevant Stocks Owned':x}
        votes_ext = votes_ext.append(d, ignore_index=True)
# Out:
# 0it [00:00, ?it/s]

# %%
count = 0
for index,value in tqdm(votes['Relevant Stocks Owned'].iteritems()):
    for x in value:
        count += 1
count
# Out:
# 0it [00:00, ?it/s]
# 92160

# %%
votes_ext
# Out:
#               States          Senators   Roll Call        Party  \
# 0      West Virginia      Manchin, Joe         Yea     Democrat
# 1              Maine    Collins, Susan         Yea   Republican
# 2              Maine    Collins, Susan         Yea   Republican
# 3              Maine    Collins, Susan         Yea   Republican
# 4              Maine    Collins, Susan         Yea   Republican
# ...              ...               ...         ...          ...
# 92155          Maine       King, Angus         Nay  Independent
# 92156          Maine       King, Angus         Nay  Independent
# 92157       Illinois  Duckworth, Tammy  Not Voting     Democrat
# 92158       Illinois  Duckworth, Tammy  Not Voting     Democrat
# 92159       Illinois  Duckworth, Tammy  Not Voting     Democrat
#
#                                                 Decision  \
# 0                   On the Motion to Proceed H.J.Res. 98
# 1                   On the Motion to Proceed H.J.Res. 98
# 2                   On the Motion to Proceed H.J.Res. 98
# 3                   On the Motion to Proceed H.J.Res. 98
# 4                   On the Motion to Proceed H.J.Res. 98
# ...                                                  ...
# 92155  S.J.Res. 37: A joint resolution providing for ...
# 92156  S.J.Res. 37: A joint resolution providing for ...
# 92157  S.J.Res. 37: A joint resolution providing for ...
# 92158  S.J.Res. 37: A joint resolution providing for ...
# 92159  S.J.Res. 37: A joint resolution providing for ...
#
#                                               Introduced  \
# 0                          Jan 26, 2012 at 11:57 a.m. ET
# 1                          Jan 26, 2012 at 11:57 a.m. ET
# 2                          Jan 26, 2012 at 11:57 a.m. ET
# 3                          Jan 26, 2012 at 11:57 a.m. ET
# 4                          Jan 26, 2012 at 11:57 a.m. ET
# ...                                                  ...
# 92155  Mar 15, 2022 at 5:30 p.m. ET.  On the Joint Re...
# 92156  Mar 15, 2022 at 5:30 p.m. ET.  On the Joint Re...
# 92157  Mar 15, 2022 at 5:30 p.m. ET.  On the Joint Re...
# 92158  Mar 15, 2022 at 5:30 p.m. ET.  On the Joint Re...
# 92159  Mar 15, 2022 at 5:30 p.m. ET.  On the Joint Re...
#
#                                                   Result  \
# 0      Motion to Proceed Rejected. Simple Majority Re...
# 1      Motion to Proceed Rejected. Simple Majority Re...
# 2      Motion to Proceed Rejected. Simple Majority Re...
# 3      Motion to Proceed Rejected. Simple Majority Re...
# 4      Motion to Proceed Rejected. Simple Majority Re...
# ...                                                  ...
# 92155  Joint Resolution Passed. Simple Majority Requi...
# 92156  Joint Resolution Passed. Simple Majority Requi...
# 92157  Joint Resolution Passed. Simple Majority Requi...
# 92158  Joint Resolution Passed. Simple Majority Requi...
# 92159  Joint Resolution Passed. Simple Majority Requi...
#
#                                               Proportion  \
# 0      The Nay votes represented 58% of the country’s...
# 1      The Nay votes represented 58% of the country’s...
# 2      The Nay votes represented 58% of the country’s...
# 3      The Nay votes represented 58% of the country’s...
# 4      The Nay votes represented 58% of the country’s...
# ...                                                  ...
# 92155  The Yea votes represented 48% of the country’s...
# 92156  The Yea votes represented 48% of the country’s...
# 92157  The Yea votes represented 48% of the country’s...
# 92158  The Yea votes represented 48% of the country’s...
# 92159  The Yea votes represented 48% of the country’s...
#
#                          Congress                   Policy Area  \
# 0      112th Congress (2011-2012)  Economics and Public Finance
